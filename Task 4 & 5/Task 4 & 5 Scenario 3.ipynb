# %% [markdown]
# ## Scenario 3 - Critical Path
#
# To enhance efficiency we aim to eliminate redundant steps and optimize the overall process by combining certain operations. The removal of unnecessary loops and steps, as well as the consolidation of specific tasks to enhance efficiency in the paper folding process.
#
# Process needs to be eliminated : Paper Loading checking and Paper alignment check.
#
# The efficiency is increased by 4,5 %
#
# The outcomes of the simulation are presented in a detailed table, offering insights into various performance metrics. Following the tabular representation, there are two accompanying bar charts. The first chart visually depicts the total count of folded papers and defective papers, providing a comparative view of these key production aspects. The second bar chart illustrates a comparison of average times associated with different processes.

# %%
import simpy
import random

#Defining Resources (Paper  ,Robot , Operator ,Paper Loading Station)

#defining Paper 

class Paper:
    def __init__(self, env, workstation1):
        self.is_defective = False
        pass

class PaperLoadingstation (object):
    # Initally the paper laodingstation has 100 papers.
    def __init__(self,env):
        self.papers = simpy.PaperLoadingstation (env, init=100, capaciy = 100)

    def check_availability_paperloadingstation(self,operator):
        # check if there is enough paper on the Loading station

        # This takes between 1-3 seconds
         yield self.env.timeout(random.randint(1, 3))

         if self.paperloadingstation == 1:
           # if there are enough paper, return True
           # print("there are enough paper available ")
           return True
         else:
            print("There are not enough paper available on the station , please refill ")
            
            return False
         
    def pick_paper(self,operator,workstation1,Robot):
        while not self.env.process(self.check_availability_paperloadingstation(Robot)):
         yield self.env.timeout(1)
         yield self.pickup_paperloadingstation.get(1) & self.env.process(self.restock())  # & self.env.process(workstation3.pickup_paper(robot))
    
    def restock_paperloadingstation(self):
         #restock the paperdispenser , this takes between 15-25 seconds
          yield self.env.timeout(random.randint(5,10))
          #restock the paper dispenser
          yield self.pickup_paperdispenser.put(100)
          print("The paper dispenser has been restocked")

#defining Robot
    
class Robot(object):
   
    def __init__(self,env,workstation1):
        self.env = env
        
        self.workstation1 = workstation1
        self.robot = simpy.Resource(env,capacity= 1)
        

    #The calibration takes place as a first step, this will takes around 2-3 Seconds
    def actuate(self,workstation1):
        yield self.env.timeout(random.randint(2,3))
        
    #the paper is loaded into the robot
    def load_paper(self,paper,paperloadingstation):
        yield self.env.timeout(random.randint(2,3))
        
     #the paper is loaded into Folding Base by the  robot , where the folding operation takes place
    def load_paper_to_foldingbase(self,paper):
        yield self.env.timeout(random.randint(2,3)) 
        
    
    #the Folding operation takes place by the robot
    def fold_paper(self,paper):
        yield self.env.timeout(random.randint(4,7))
        
    #the paper is unloaded from the Folding Base by the robot
    def unload_paper_from_foldingbase(self,paper):
        yield self.env.timeout(random.randint(2,3))
        
    def return_to_start(self):
        yield self.env.timeout(random.randint(2, 3))
    
    #At the end ,hand over the folded paper to the next station for further operations
    def hand_over_paper(self,workstation2):
        yield self.env.timeout (random.randint(2,3))
        

#defining Operator
        

class Operator (object):
    def __init__(self,env,workstation1,folded_papers):
        self.env = env
        self.workstation1 = workstation1
        self.folded_papers = folded_papers
        
        self.quality_check_times = {'check1': []}
        self.total_idle_time = 0
        
        
    def adjust_paper_loading(self, paper):
        # Check if the paper is loaded properly
        if random.random() < 0.30:  
            print("Paper not loaded properly. Adjusting...")
            yield self.env.timeout(random.randint(1, 3))
            print("Adjustment completed.")
        else:
            print("Paper is loaded properly.")
        
        

    def quality_check_fold(self, paper):
        # Quality check after Folding Operation
        start_time = self.env.now
        yield self.env.timeout(random.randint(2, 3))
        end_time = self.env.now
        self.quality_check_times['check1'].append(end_time - start_time)

        # Assume a 10% chance of a defect
        if random.random() < 0.1:
            paper.is_defective = True

        if paper.is_defective:
            # If the paper is defective, send it to waste
            print("Folded Paper has a defect and goes to waste.")
            yield self.env.process(self.workstation1.WasteStation.dispose(paper))
            robot = Robot(self.env, self.workstation1)
            yield self.env.process(self.workstation1.workstation1_process(self, Paper(self.env, self.workstation1), robot))
            
        else:
            print("Folded Paper passed quality check.")
        
        
        self.idle_start_time = self.env.now
        
    def align_paper(self, paper):
        # Check if the paper is aligned properly
        if random.random() < 0.30: 
            print("Paper misaligned. Aligning...")
            yield self.env.timeout(random.randint(1, 3))
            print("Alignment completed.")
        else:
            print("Paper is aligned properly.")
    
        

#defining Workstation2 
class Workstation2(object):
    def __init__(self,env):
        self.env = env
        
class WasteStation(object):
    def __init__(self, env):
        self.env = env

    def dispose(self,paper):
        # Waste disposal process
        yield self.env.timeout(random.randint(2, 3))
        print("Paper has been disposed of as waste.")

# %%
##2.Environment
#In the 2nd step we will implement the environment in which the simulation takes place.
#Here we will set up the ressources and the genereal process flow.

# %%
#Defining the workstatiion1

class WorkStation1(object):
    def __init__(self,env,paper_list,robot,Workstation2,operator,folded_papers):
        self.env = env
        self.folded_papers = folded_papers
        
        self.operator = operator(env,self, self.folded_papers )
        self.idle_start_time = 0
        
        self.robot = robot(env,self)
        self.workstation2 = Workstation2(env)
        
        self.WasteStation = WasteStation(env) 
         
        self.folded_papers = 0
        self.total_operation_time = 0
        self.totalfolding1_time = 0
        self.paper_loading_verification_time = 0
        self.paper_alignment_verification_time = 0
        self.totalfolding2_time = 0
        self.total_quality_check_time = 0
        self.defective_papers = 0
        self.operator_idle_time = 0
        self.start_idle_time = 0
        self.total_idle_time = 0
        
        
        
        
        
        self.production_rate_data = []
        self.operation_times = []

    def workstation1_process(self,operator,paper,robot):
        
       #Track the time
        arrival_time=self.env.now
        yield self.env.process(self.robot.actuate(self))
        print ("Operator started the process at "+str(self.env.now)+"seconds.")
        #The paper is loaded into the robot
        operator.idle1_start_time = self.env.now 
        #the operator is idle during the paper loading process, and the time is recorded
        yield self.env.process(self.robot.load_paper(paper,PaperLoadingstation))
        print("The Paper " +str(self.folded_papers)+" has been loaded into the robot at "+str(self.env.now)+" seconds.")
        operator.idle1_end_time = self.env.now - operator.idle1_start_time
        
        #the paper loading verification removed from the process
             
             
        #The paper is loaded into the Folding Base by the robot
        operator.idle2_start_time = self.env.now
        yield self.env.process(self.robot.load_paper_to_foldingbase(paper))
        print ("The paper " +str(self.folded_papers)+" has been loaded into the Folding Base at "+str(self.env.now)+" seconds.")
        operator.idle2_end_time = self.env.now - operator.idle2_start_time

        #the paper alignment verification removed from the process
                
        #The Folding operation takes place by the robot , some steps are done by the operator
        folding1_start_time = self.env.now
        yield self.env.process(self.robot.fold_paper(paper))
        folding1_end_time = self.env.now - folding1_start_time
        print ("The paper " +str(self.folded_papers)+" has been folded at "+str(self.env.now)+" seconds.")

        #The paper is unloaded from the Folding Base by the robot
        operator.idle3_start_time = self.env.now
        yield self.env.process(self.robot.unload_paper_from_foldingbase(paper))
        print ("The paper " +str(self.folded_papers)+" has been unloaded from the Folding Base at "+str(self.env.now)+" seconds.")
        
        #Quality check 
        quality_check_start_time = self.env.now 
        print ("The paper has been checked for quality at "+str(self.env.now)+"seconds.")
        yield self.env.process(self.operator.quality_check_fold(paper))
        
        quality_check_end_time = self.env.now - quality_check_start_time
        if paper.is_defective:
            self.defective_papers += 1

        #the paper is handed over to the next station for further operations
        yield self.env.process(self.robot.hand_over_paper(Workstation2))
        print ("The paper "+str(self.folded_papers)+" has been handed over to the next station at "+str(self.env.now)+" seconds.")
        operator.idle3_end_time = self.env.now - operator.idle3_start_time

        
        #the robot returns to the start position
        operator.idle4_start_time = self.env.now
        yield self.env.process(self.robot.return_to_start())
        print ("The robot has returned to the start position at "+str(self.env.now)+"seconds.")
        operator.idle4_end_time = self.env.now - operator.idle4_start_time
        #the operator is idle during the paper loading process, and the time is recorded

        #Operation time
        operation_time = self.env.now - arrival_time
        #Total folding time
        totalfolding1_time = folding1_end_time 
        #operator idle time
        operator_idle_time = operator.idle1_end_time + operator.idle2_end_time + operator.idle3_end_time + operator.idle4_end_time
        # add the operator idle time to the list of operator idle times
        self.operator_idle_time += operator_idle_time     
                
        
       
        total_quality_check_time = quality_check_end_time
        self.total_quality_check_time += total_quality_check_time

        # add the production rate data to the list
        self.production_rate_data.append((self.env.now, self.folded_papers))

        
        # add the folding time to the list of folding times
        self.totalfolding1_time += totalfolding1_time
        
        
    
        # add the process time to the total production time
        self.total_operation_time += operation_time

        # count the produced papers
        self.folded_papers += 1

# %%
###3.Simulation
#In the third step we will run the simulation and therefor define an initial set of parameter to simulate.

# %%
def paper_generator(env, workstation1, paper_list):
    while True:
        interarrival_time = random.randint(2,5)

        paper = Paper(env, workstation1)
        paper_list.append(paper)

        operator = Operator(env, workstation1, workstation1.folded_papers)
        robot = Robot(env, workstation1)

        yield env.process(workstation1.workstation1_process(operator, paper,robot))

        yield env.timeout(interarrival_time)
        print("Next Paper " + str(workstation1.folded_papers) + " arrived at Station 1 at " + str(env.now) + " seconds.")
import simpy
env = simpy.Environment()

paper_list=[]
folded_papers=0
operator = Operator(env,WorkStation1,folded_papers)

workstation1=WorkStation1(env,paper_list,Robot,Workstation2,Operator,folded_papers)


print ("The number of produced papers is "+str(workstation1.folded_papers-1)+".")
print ("the simulation duration is "+str(env.now)+"seconds.")
env.process(paper_generator(env,workstation1,paper_list))
env.run(until=28800)
# Out:
# The number of produced papers is -1.
# the simulation duration is 0seconds.
# Operator started the process at 3seconds.
# The Paper 0 has been loaded into the robot at 5 seconds.
# The paper 0 has been loaded into the Folding Base at 8 seconds.
# The paper 0 has been folded at 13 seconds.
# The paper 0 has been unloaded from the Folding Base at 15 seconds.
# The paper has been checked for quality at 15seconds.
# Folded Paper passed quality check.
# The paper 0 has been handed over to the next station at 20 seconds.
# The robot has returned to the start position at 23seconds.
# Next Paper 1 arrived at Station 1 at 25 seconds.
# Operator started the process at 28seconds.
# The Paper 1 has been loaded into the robot at 30 seconds.
# The paper 1 has been loaded into the Folding Base at 32 seconds.
# The paper 1 has been folded at 36 seconds.
# The paper 1 has been unloaded from the Folding Base at 38 seconds.
# The paper has been checked for quality at 38seconds.
# Folded Paper passed quality check.
# The paper 1 has been handed over to the next station at 43 seconds.
# The robot has returned to the start position at 46seconds.
# Next Paper 2 arrived at Station 1 at 51 seconds.
# Operator started the process at 54seconds.
# The Paper 2 has been loaded into the robot at 56 seconds.
# The paper 2 has been loaded into the Folding Base at 59 seconds.
# The paper 2 has been folded at 63 seconds.
# The paper 2 has been unloaded from the Folding Base at 66 seconds.
# The paper has been checked for quality at 66seconds.
# Folded Paper passed quality check.
# The paper 2 has been handed over to the next station at 71 seconds.
# The robot has returned to the start position at 73seconds.
# Next Paper 3 arrived at Station 1 at 76 seconds.
# Operator started the process at 78seconds.
# The Paper 3 has been loaded into the robot at 80 seconds.
# The paper 3 has been loaded into the Folding Base at 83 seconds.
# The paper 3 has been folded at 89 seconds.
# The paper 3 has been unloaded from the Folding Base at 91 seconds.
# The paper has been checked for quality at 91seconds.
# Folded Paper passed quality check.
# The paper 3 has been handed over to the next station at 97 seconds.
# The robot has returned to the start position at 100seconds.
# Next Paper 4 arrived at Station 1 at 104 seconds.
# Operator started the process at 106seconds.
# The Paper 4 has been loaded into the robot at 109 seconds.
# The paper 4 has been loaded into the Folding Base at 112 seconds.
# The paper 4 has been folded at 118 seconds.
# The paper 4 has been unloaded from the Folding Base at 121 seconds.
# The paper has been checked for quality at 121seconds.
# Folded Paper has a defect and goes to waste.
# Paper has been disposed of as waste.
# Operator started the process at 128seconds.
# The Paper 4 has been loaded into the robot at 131 seconds.
# The paper 4 has been loaded into the Folding Base at 133 seconds.
# The paper 4 has been folded at 140 seconds.
# The paper 4 has been unloaded from the Folding Base at 143 seconds.
# The paper has been checked for quality at 143seconds.
# Folded Paper passed quality check.
# The paper 4 has been handed over to the next station at 148 seconds.
# The robot has returned to the start position at 150seconds.
# The paper 5 has been handed over to the next station at 152 seconds.
# The robot has returned to the start position at 154seconds.
# Next Paper 6 arrived at Station 1 at 157 seconds.
# Operator started the process at 160seconds.
# The Paper 6 has been loaded into the robot at 163 seconds.
# The paper 6 has been loaded into the Folding Base at 166 seconds.
# The paper 6 has been folded at 173 seconds.
# The paper 6 has been unloaded from the Folding Base at 175 seconds.
# The paper has been checked for quality at 175seconds.
# Folded Paper passed quality check.
# The paper 6 has been handed over to the next station at 181 seconds.
# The robot has returned to the start position at 183seconds.
# Next Paper 7 arrived at Station 1 at 185 seconds.
# Operator started the process at 188seconds.
# The Paper 7 has been loaded into the robot at 191 seconds.
# The paper 7 has been loaded into the Folding Base at 194 seconds.
# The paper 7 has been folded at 201 seconds.
# The paper 7 has been unloaded from the Folding Base at 204 seconds.
# The paper has been checked for quality at 204seconds.
# Folded Paper passed quality check.
# The paper 7 has been handed over to the next station at 209 seconds.
# The robot has returned to the start position at 212seconds.
# Next Paper 8 arrived at Station 1 at 214 seconds.
# Operator started the process at 216seconds.
# The Paper 8 has been loaded into the robot at 219 seconds.
# The paper 8 has been loaded into the Folding Base at 222 seconds.
# The paper 8 has been folded at 227 seconds.
# The paper 8 has been unloaded from the Folding Base at 229 seconds.
# The paper has been checked for quality at 229seconds.
# Folded Paper passed quality check.
# The paper 8 has been handed over to the next station at 235 seconds.
# The robot has returned to the start position at 238seconds.
# Next Paper 9 arrived at Station 1 at 242 seconds.
# Operator started the process at 244seconds.
# The Paper 9 has been loaded into the robot at 246 seconds.
# The paper 9 has been loaded into the Folding Base at 248 seconds.
# The paper 9 has been folded at 255 seconds.
# The paper 9 has been unloaded from the Folding Base at 258 seconds.
# The paper has been checked for quality at 258seconds.
# Folded Paper passed quality check.
# The paper 9 has been handed over to the next station at 263 seconds.
# The robot has returned to the start position at 265seconds.
# Next Paper 10 arrived at Station 1 at 268 seconds.
# Operator started the process at 271seconds.
# The Paper 10 has been loaded into the robot at 274 seconds.
# The paper 10 has been loaded into the Folding Base at 277 seconds.
# The paper 10 has been folded at 284 seconds.
# The paper 10 has been unloaded from the Folding Base at 286 seconds.
# The paper has been checked for quality at 286seconds.
# Folded Paper passed quality check.
# The paper 10 has been handed over to the next station at 290 seconds.
# The robot has returned to the start position at 293seconds.
# Next Paper 11 arrived at Station 1 at 296 seconds.
# Operator started the process at 299seconds.
# The Paper 11 has been loaded into the robot at 301 seconds.
# The paper 11 has been loaded into the Folding Base at 303 seconds.
# The paper 11 has been folded at 309 seconds.
# The paper 11 has been unloaded from the Folding Base at 311 seconds.
# The paper has been checked for quality at 311seconds.
# Folded Paper passed quality check.
# The paper 11 has been handed over to the next station at 316 seconds.
# The robot has returned to the start position at 319seconds.
# Next Paper 12 arrived at Station 1 at 321 seconds.
# Operator started the process at 323seconds.
# The Paper 12 has been loaded into the robot at 326 seconds.
# The paper 12 has been loaded into the Folding Base at 329 seconds.
# The paper 12 has been folded at 335 seconds.
# The paper 12 has been unloaded from the Folding Base at 338 seconds.
# The paper has been checked for quality at 338seconds.
# Folded Paper passed quality check.
# The paper 12 has been handed over to the next station at 343 seconds.
# The robot has returned to the start position at 345seconds.
# Next Paper 13 arrived at Station 1 at 347 seconds.
# Operator started the process at 350seconds.
# The Paper 13 has been loaded into the robot at 353 seconds.
# The paper 13 has been loaded into the Folding Base at 356 seconds.
# The paper 13 has been folded at 363 seconds.
# The paper 13 has been unloaded from the Folding Base at 366 seconds.
# The paper has been checked for quality at 366seconds.
# Folded Paper passed quality check.
# The paper 13 has been handed over to the next station at 370 seconds.
# The robot has returned to the start position at 372seconds.
# Next Paper 14 arrived at Station 1 at 376 seconds.
# Operator started the process at 378seconds.
# The Paper 14 has been loaded into the robot at 381 seconds.
# The paper 14 has been loaded into the Folding Base at 384 seconds.
# The paper 14 has been folded at 389 seconds.
# The paper 14 has been unloaded from the Folding Base at 391 seconds.
# The paper has been checked for quality at 391seconds.
# Folded Paper passed quality check.
# The paper 14 has been handed over to the next station at 397 seconds.
# The robot has returned to the start position at 400seconds.
# Next Paper 15 arrived at Station 1 at 403 seconds.
# Operator started the process at 406seconds.
# The Paper 15 has been loaded into the robot at 408 seconds.
# The paper 15 has been loaded into the Folding Base at 410 seconds.
# The paper 15 has been folded at 414 seconds.
# The paper 15 has been unloaded from the Folding Base at 417 seconds.
# The paper has been checked for quality at 417seconds.
# Folded Paper passed quality check.
# The paper 15 has been handed over to the next station at 422 seconds.
# The robot has returned to the start position at 425seconds.
# Next Paper 16 arrived at Station 1 at 429 seconds.
# Operator started the process at 432seconds.
# The Paper 16 has been loaded into the robot at 434 seconds.
# The paper 16 has been loaded into the Folding Base at 436 seconds.
# The paper 16 has been folded at 442 seconds.
# The paper 16 has been unloaded from the Folding Base at 444 seconds.
# The paper has been checked for quality at 444seconds.
# Folded Paper passed quality check.
# The paper 16 has been handed over to the next station at 448 seconds.
# The robot has returned to the start position at 450seconds.
# Next Paper 17 arrived at Station 1 at 455 seconds.
# Operator started the process at 457seconds.
# The Paper 17 has been loaded into the robot at 459 seconds.
# The paper 17 has been loaded into the Folding Base at 462 seconds.
# The paper 17 has been folded at 467 seconds.
# The paper 17 has been unloaded from the Folding Base at 469 seconds.
# The paper has been checked for quality at 469seconds.
# Folded Paper passed quality check.
# The paper 17 has been handed over to the next station at 473 seconds.
# The robot has returned to the start position at 475seconds.
# Next Paper 18 arrived at Station 1 at 480 seconds.
# Operator started the process at 482seconds.
# The Paper 18 has been loaded into the robot at 484 seconds.
# The paper 18 has been loaded into the Folding Base at 487 seconds.
# The paper 18 has been folded at 493 seconds.
# The paper 18 has been unloaded from the Folding Base at 496 seconds.
# The paper has been checked for quality at 496seconds.
# Folded Paper passed quality check.
# The paper 18 has been handed over to the next station at 501 seconds.
# The robot has returned to the start position at 504seconds.
# Next Paper 19 arrived at Station 1 at 508 seconds.
# Operator started the process at 510seconds.
# The Paper 19 has been loaded into the robot at 513 seconds.
# The paper 19 has been loaded into the Folding Base at 515 seconds.
# The paper 19 has been folded at 521 seconds.
# The paper 19 has been unloaded from the Folding Base at 524 seconds.
# The paper has been checked for quality at 524seconds.
# Folded Paper passed quality check.
# The paper 19 has been handed over to the next station at 528 seconds.
# The robot has returned to the start position at 530seconds.
# Next Paper 20 arrived at Station 1 at 533 seconds.
# Operator started the process at 536seconds.
# The Paper 20 has been loaded into the robot at 538 seconds.
# The paper 20 has been loaded into the Folding Base at 541 seconds.
# The paper 20 has been folded at 545 seconds.
# The paper 20 has been unloaded from the Folding Base at 547 seconds.
# The paper has been checked for quality at 547seconds.
# Folded Paper passed quality check.
# The paper 20 has been handed over to the next station at 552 seconds.
# The robot has returned to the start position at 554seconds.
# Next Paper 21 arrived at Station 1 at 557 seconds.
# Operator started the process at 559seconds.
# The Paper 21 has been loaded into the robot at 561 seconds.
# The paper 21 has been loaded into the Folding Base at 564 seconds.
# The paper 21 has been folded at 571 seconds.
# The paper 21 has been unloaded from the Folding Base at 574 seconds.
# The paper has been checked for quality at 574seconds.
# Folded Paper passed quality check.
# The paper 21 has been handed over to the next station at 580 seconds.
# The robot has returned to the start position at 582seconds.
# Next Paper 22 arrived at Station 1 at 586 seconds.
# Operator started the process at 589seconds.
# The Paper 22 has been loaded into the robot at 591 seconds.
# The paper 22 has been loaded into the Folding Base at 593 seconds.
# The paper 22 has been folded at 598 seconds.
# The paper 22 has been unloaded from the Folding Base at 600 seconds.
# The paper has been checked for quality at 600seconds.
# Folded Paper passed quality check.
# The paper 22 has been handed over to the next station at 605 seconds.
# The robot has returned to the start position at 608seconds.
# Next Paper 23 arrived at Station 1 at 611 seconds.
# Operator started the process at 613seconds.
# The Paper 23 has been loaded into the robot at 616 seconds.
# The paper 23 has been loaded into the Folding Base at 618 seconds.
# The paper 23 has been folded at 622 seconds.
# The paper 23 has been unloaded from the Folding Base at 624 seconds.
# The paper has been checked for quality at 624seconds.
# Folded Paper passed quality check.
# The paper 23 has been handed over to the next station at 629 seconds.
# The robot has returned to the start position at 632seconds.
# Next Paper 24 arrived at Station 1 at 636 seconds.
# Operator started the process at 639seconds.
# The Paper 24 has been loaded into the robot at 641 seconds.
# The paper 24 has been loaded into the Folding Base at 644 seconds.
# The paper 24 has been folded at 651 seconds.
# The paper 24 has been unloaded from the Folding Base at 653 seconds.
# The paper has been checked for quality at 653seconds.
# Folded Paper passed quality check.
# The paper 24 has been handed over to the next station at 658 seconds.
# The robot has returned to the start position at 661seconds.
# Next Paper 25 arrived at Station 1 at 666 seconds.
# Operator started the process at 668seconds.
# The Paper 25 has been loaded into the robot at 671 seconds.
# The paper 25 has been loaded into the Folding Base at 673 seconds.
# The paper 25 has been folded at 677 seconds.
# The paper 25 has been unloaded from the Folding Base at 680 seconds.
# The paper has been checked for quality at 680seconds.
# Folded Paper passed quality check.
# The paper 25 has been handed over to the next station at 686 seconds.
# The robot has returned to the start position at 689seconds.
# Next Paper 26 arrived at Station 1 at 694 seconds.
# Operator started the process at 697seconds.
# The Paper 26 has been loaded into the robot at 700 seconds.
# The paper 26 has been loaded into the Folding Base at 702 seconds.
# The paper 26 has been folded at 709 seconds.
# The paper 26 has been unloaded from the Folding Base at 711 seconds.
# The paper has been checked for quality at 711seconds.
# Folded Paper passed quality check.
# The paper 26 has been handed over to the next station at 717 seconds.
# The robot has returned to the start position at 720seconds.
# Next Paper 27 arrived at Station 1 at 722 seconds.
# Operator started the process at 724seconds.
# The Paper 27 has been loaded into the robot at 726 seconds.
# The paper 27 has been loaded into the Folding Base at 729 seconds.
# The paper 27 has been folded at 734 seconds.
# The paper 27 has been unloaded from the Folding Base at 736 seconds.
# The paper has been checked for quality at 736seconds.
# Folded Paper passed quality check.
# The paper 27 has been handed over to the next station at 741 seconds.
# The robot has returned to the start position at 744seconds.
# Next Paper 28 arrived at Station 1 at 747 seconds.
# Operator started the process at 749seconds.
# The Paper 28 has been loaded into the robot at 751 seconds.
# The paper 28 has been loaded into the Folding Base at 753 seconds.
# The paper 28 has been folded at 757 seconds.
# The paper 28 has been unloaded from the Folding Base at 760 seconds.
# The paper has been checked for quality at 760seconds.
# Folded Paper passed quality check.
# The paper 28 has been handed over to the next station at 765 seconds.
# The robot has returned to the start position at 768seconds.
# Next Paper 29 arrived at Station 1 at 772 seconds.
# Operator started the process at 774seconds.
# The Paper 29 has been loaded into the robot at 777 seconds.
# The paper 29 has been loaded into the Folding Base at 780 seconds.
# The paper 29 has been folded at 785 seconds.
# The paper 29 has been unloaded from the Folding Base at 788 seconds.
# The paper has been checked for quality at 788seconds.
# Folded Paper passed quality check.
# The paper 29 has been handed over to the next station at 792 seconds.
# The robot has returned to the start position at 794seconds.
# Next Paper 30 arrived at Station 1 at 799 seconds.
# Operator started the process at 801seconds.
# The Paper 30 has been loaded into the robot at 803 seconds.
# The paper 30 has been loaded into the Folding Base at 805 seconds.
# The paper 30 has been folded at 812 seconds.
# The paper 30 has been unloaded from the Folding Base at 814 seconds.
# The paper has been checked for quality at 814seconds.
# Folded Paper passed quality check.
# The paper 30 has been handed over to the next station at 819 seconds.
# The robot has returned to the start position at 821seconds.
# Next Paper 31 arrived at Station 1 at 826 seconds.
# Operator started the process at 829seconds.
# The Paper 31 has been loaded into the robot at 832 seconds.
# The paper 31 has been loaded into the Folding Base at 834 seconds.
# The paper 31 has been folded at 838 seconds.
# The paper 31 has been unloaded from the Folding Base at 840 seconds.
# The paper has been checked for quality at 840seconds.
# Folded Paper passed quality check.
# The paper 31 has been handed over to the next station at 844 seconds.
# The robot has returned to the start position at 847seconds.
# Next Paper 32 arrived at Station 1 at 850 seconds.
# Operator started the process at 853seconds.
# The Paper 32 has been loaded into the robot at 855 seconds.
# The paper 32 has been loaded into the Folding Base at 857 seconds.
# The paper 32 has been folded at 864 seconds.
# The paper 32 has been unloaded from the Folding Base at 867 seconds.
# The paper has been checked for quality at 867seconds.
# Folded Paper passed quality check.
# The paper 32 has been handed over to the next station at 871 seconds.
# The robot has returned to the start position at 873seconds.
# Next Paper 33 arrived at Station 1 at 877 seconds.
# Operator started the process at 880seconds.
# The Paper 33 has been loaded into the robot at 883 seconds.
# The paper 33 has been loaded into the Folding Base at 886 seconds.
# The paper 33 has been folded at 890 seconds.
# The paper 33 has been unloaded from the Folding Base at 892 seconds.
# The paper has been checked for quality at 892seconds.
# Folded Paper passed quality check.
# The paper 33 has been handed over to the next station at 897 seconds.
# The robot has returned to the start position at 899seconds.
# Next Paper 34 arrived at Station 1 at 903 seconds.
# Operator started the process at 905seconds.
# The Paper 34 has been loaded into the robot at 907 seconds.
# The paper 34 has been loaded into the Folding Base at 909 seconds.
# The paper 34 has been folded at 916 seconds.
# The paper 34 has been unloaded from the Folding Base at 919 seconds.
# The paper has been checked for quality at 919seconds.
# Folded Paper passed quality check.
# The paper 34 has been handed over to the next station at 923 seconds.
# The robot has returned to the start position at 926seconds.
# Next Paper 35 arrived at Station 1 at 930 seconds.
# Operator started the process at 932seconds.
# The Paper 35 has been loaded into the robot at 934 seconds.
# The paper 35 has been loaded into the Folding Base at 936 seconds.
# The paper 35 has been folded at 943 seconds.
# The paper 35 has been unloaded from the Folding Base at 945 seconds.
# The paper has been checked for quality at 945seconds.
# Folded Paper passed quality check.
# The paper 35 has been handed over to the next station at 949 seconds.
# The robot has returned to the start position at 952seconds.
# Next Paper 36 arrived at Station 1 at 956 seconds.
# Operator started the process at 959seconds.
# The Paper 36 has been loaded into the robot at 962 seconds.
# The paper 36 has been loaded into the Folding Base at 965 seconds.
# The paper 36 has been folded at 971 seconds.
# The paper 36 has been unloaded from the Folding Base at 973 seconds.
# The paper has been checked for quality at 973seconds.
# Folded Paper passed quality check.
# The paper 36 has been handed over to the next station at 978 seconds.
# The robot has returned to the start position at 980seconds.
# Next Paper 37 arrived at Station 1 at 982 seconds.
# Operator started the process at 984seconds.
# The Paper 37 has been loaded into the robot at 986 seconds.
# The paper 37 has been loaded into the Folding Base at 988 seconds.
# The paper 37 has been folded at 995 seconds.
# The paper 37 has been unloaded from the Folding Base at 998 seconds.
# The paper has been checked for quality at 998seconds.
# Folded Paper has a defect and goes to waste.
# Paper has been disposed of as waste.
# Operator started the process at 1005seconds.
# The Paper 37 has been loaded into the robot at 1007 seconds.
# The paper 37 has been loaded into the Folding Base at 1010 seconds.
# The paper 37 has been folded at 1014 seconds.
# The paper 37 has been unloaded from the Folding Base at 1017 seconds.
# The paper has been checked for quality at 1017seconds.
# Folded Paper passed quality check.
# The paper 37 has been handed over to the next station at 1023 seconds.
# The robot has returned to the start position at 1025seconds.
# The paper 38 has been handed over to the next station at 1027 seconds.
# The robot has returned to the start position at 1029seconds.
# Next Paper 39 arrived at Station 1 at 1034 seconds.
# Operator started the process at 1037seconds.
# The Paper 39 has been loaded into the robot at 1039 seconds.
# The paper 39 has been loaded into the Folding Base at 1042 seconds.
# The paper 39 has been folded at 1048 seconds.
# The paper 39 has been unloaded from the Folding Base at 1050 seconds.
# The paper has been checked for quality at 1050seconds.
# Folded Paper passed quality check.
# The paper 39 has been handed over to the next station at 1055 seconds.
# The robot has returned to the start position at 1058seconds.
# Next Paper 40 arrived at Station 1 at 1061 seconds.
# Operator started the process at 1063seconds.
# The Paper 40 has been loaded into the robot at 1066 seconds.
# The paper 40 has been loaded into the Folding Base at 1069 seconds.
# The paper 40 has been folded at 1075 seconds.
# The paper 40 has been unloaded from the Folding Base at 1078 seconds.
# The paper has been checked for quality at 1078seconds.
# Folded Paper passed quality check.
# The paper 40 has been handed over to the next station at 1082 seconds.
# The robot has returned to the start position at 1085seconds.
# Next Paper 41 arrived at Station 1 at 1090 seconds.
# Operator started the process at 1093seconds.
# The Paper 41 has been loaded into the robot at 1095 seconds.
# The paper 41 has been loaded into the Folding Base at 1097 seconds.
# The paper 41 has been folded at 1102 seconds.
# The paper 41 has been unloaded from the Folding Base at 1105 seconds.
# The paper has been checked for quality at 1105seconds.
# Folded Paper has a defect and goes to waste.
# Paper has been disposed of as waste.
# Operator started the process at 1113seconds.
# The Paper 41 has been loaded into the robot at 1115 seconds.
# The paper 41 has been loaded into the Folding Base at 1118 seconds.
# The paper 41 has been folded at 1124 seconds.
# The paper 41 has been unloaded from the Folding Base at 1127 seconds.
# The paper has been checked for quality at 1127seconds.
# Folded Paper has a defect and goes to waste.
# Paper has been disposed of as waste.
# Operator started the process at 1136seconds.
# The Paper 41 has been loaded into the robot at 1138 seconds.
# The paper 41 has been loaded into the Folding Base at 1140 seconds.
# The paper 41 has been folded at 1147 seconds.
# The paper 41 has been unloaded from the Folding Base at 1150 seconds.
# The paper has been checked for quality at 1150seconds.
# Folded Paper passed quality check.
# The paper 41 has been handed over to the next station at 1156 seconds.
# The robot has returned to the start position at 1159seconds.
# The paper 42 has been handed over to the next station at 1161 seconds.
# The robot has returned to the start position at 1164seconds.
# The paper 43 has been handed over to the next station at 1167 seconds.
# The robot has returned to the start position at 1170seconds.
# Next Paper 44 arrived at Station 1 at 1173 seconds.
# Operator started the process at 1175seconds.
# The Paper 44 has been loaded into the robot at 1178 seconds.
# The paper 44 has been loaded into the Folding Base at 1181 seconds.
# The paper 44 has been folded at 1185 seconds.
# The paper 44 has been unloaded from the Folding Base at 1187 seconds.
# The paper has been checked for quality at 1187seconds.
# Folded Paper passed quality check.
# The paper 44 has been handed over to the next station at 1192 seconds.
# The robot has returned to the start position at 1194seconds.
# Next Paper 45 arrived at Station 1 at 1199 seconds.
# Operator started the process at 1201seconds.
# The Paper 45 has been loaded into the robot at 1203 seconds.
# The paper 45 has been loaded into the Folding Base at 1206 seconds.
# The paper 45 has been folded at 1212 seconds.
# The paper 45 has been unloaded from the Folding Base at 1215 seconds.
# The paper has been checked for quality at 1215seconds.
# Folded Paper passed quality check.
# The paper 45 has been handed over to the next station at 1221 seconds.
# The robot has returned to the start position at 1223seconds.
# Next Paper 46 arrived at Station 1 at 1228 seconds.
# Operator started the process at 1231seconds.
# The Paper 46 has been loaded into the robot at 1233 seconds.
# The paper 46 has been loaded into the Folding Base at 1235 seconds.
# The paper 46 has been folded at 1240 seconds.
# The paper 46 has been unloaded from the Folding Base at 1242 seconds.
# The paper has been checked for quality at 1242seconds.
# Folded Paper passed quality check.
# The paper 46 has been handed over to the next station at 1246 seconds.
# The robot has returned to the start position at 1249seconds.
# Next Paper 47 arrived at Station 1 at 1254 seconds.
# Operator started the process at 1257seconds.
# The Paper 47 has been loaded into the robot at 1260 seconds.
# The paper 47 has been loaded into the Folding Base at 1263 seconds.
# The paper 47 has been folded at 1270 seconds.
# The paper 47 has been unloaded from the Folding Base at 1273 seconds.
# The paper has been checked for quality at 1273seconds.
# Folded Paper passed quality check.
# The paper 47 has been handed over to the next station at 1277 seconds.
# The robot has returned to the start position at 1280seconds.
# Next Paper 48 arrived at Station 1 at 1285 seconds.
# Operator started the process at 1288seconds.
# The Paper 48 has been loaded into the robot at 1290 seconds.
# The paper 48 has been loaded into the Folding Base at 1293 seconds.
# The paper 48 has been folded at 1298 seconds.
# The paper 48 has been unloaded from the Folding Base at 1301 seconds.
# The paper has been checked for quality at 1301seconds.
# Folded Paper passed quality check.
# The paper 48 has been handed over to the next station at 1305 seconds.
# The robot has returned to the start position at 1307seconds.
# Next Paper 49 arrived at Station 1 at 1312 seconds.
# Operator started the process at 1315seconds.
# The Paper 49 has been loaded into the robot at 1317 seconds.
# The paper 49 has been loaded into the Folding Base at 1320 seconds.
# The paper 49 has been folded at 1327 seconds.
# The paper 49 has been unloaded from the Folding Base at 1329 seconds.
# The paper has been checked for quality at 1329seconds.
# Folded Paper has a defect and goes to waste.
# Paper has been disposed of as waste.
# Operator started the process at 1336seconds.
# The Paper 49 has been loaded into the robot at 1338 seconds.
# The paper 49 has been loaded into the Folding Base at 1340 seconds.
# The paper 49 has been folded at 1347 seconds.
# The paper 49 has been unloaded from the Folding Base at 1349 seconds.
# The paper has been checked for quality at 1349seconds.
# Folded Paper passed quality check.
# The paper 49 has been handed over to the next station at 1353 seconds.
# The robot has returned to the start position at 1355seconds.
# The paper 50 has been handed over to the next station at 1358 seconds.
# The robot has returned to the start position at 1361seconds.
# Next Paper 51 arrived at Station 1 at 1363 seconds.
# Operator started the process at 1366seconds.
# The Paper 51 has been loaded into the robot at 1369 seconds.
# The paper 51 has been loaded into the Folding Base at 1372 seconds.
# The paper 51 has been folded at 1376 seconds.
# The paper 51 has been unloaded from the Folding Base at 1378 seconds.
# The paper has been checked for quality at 1378seconds.
# Folded Paper passed quality check.
# The paper 51 has been handed over to the next station at 1384 seconds.
# The robot has returned to the start position at 1387seconds.
# Next Paper 52 arrived at Station 1 at 1392 seconds.
# Operator started the process at 1394seconds.
# The Paper 52 has been loaded into the robot at 1396 seconds.
# The paper 52 has been loaded into the Folding Base at 1398 seconds.
# The paper 52 has been folded at 1405 seconds.
# The paper 52 has been unloaded from the Folding Base at 1408 seconds.
# The paper has been checked for quality at 1408seconds.
# Folded Paper passed quality check.
# The paper 52 has been handed over to the next station at 1412 seconds.
# The robot has returned to the start position at 1415seconds.
# Next Paper 53 arrived at Station 1 at 1418 seconds.
# Operator started the process at 1421seconds.
# The Paper 53 has been loaded into the robot at 1424 seconds.
# The paper 53 has been loaded into the Folding Base at 1426 seconds.
# The paper 53 has been folded at 1430 seconds.
# The paper 53 has been unloaded from the Folding Base at 1432 seconds.
# The paper has been checked for quality at 1432seconds.
# Folded Paper has a defect and goes to waste.
# Paper has been disposed of as waste.
# Operator started the process at 1440seconds.
# The Paper 53 has been loaded into the robot at 1442 seconds.
# The paper 53 has been loaded into the Folding Base at 1444 seconds.
# The paper 53 has been folded at 1448 seconds.
# The paper 53 has been unloaded from the Folding Base at 1451 seconds.
# The paper has been checked for quality at 1451seconds.
# Folded Paper passed quality check.
# The paper 53 has been handed over to the next station at 1455 seconds.
# The robot has returned to the start position at 1458seconds.
# The paper 54 has been handed over to the next station at 1461 seconds.
# The robot has returned to the start position at 1464seconds.
# Next Paper 55 arrived at Station 1 at 1467 seconds.
# Operator started the process at 1470seconds.
# The Paper 55 has been loaded into the robot at 1473 seconds.
# The paper 55 has been loaded into the Folding Base at 1476 seconds.
# The paper 55 has been folded at 1482 seconds.
# The paper 55 has been unloaded from the Folding Base at 1484 seconds.
# The paper has been checked for quality at 1484seconds.
# Folded Paper passed quality check.
# The paper 55 has been handed over to the next station at 1488 seconds.
# The robot has returned to the start position at 1491seconds.
# Next Paper 56 arrived at Station 1 at 1494 seconds.
# Operator started the process at 1497seconds.
# The Paper 56 has been loaded into the robot at 1500 seconds.
# The paper 56 has been loaded into the Folding Base at 1503 seconds.
# The paper 56 has been folded at 1507 seconds.
# The paper 56 has been unloaded from the Folding Base at 1509 seconds.
# The paper has been checked for quality at 1509seconds.
# Folded Paper passed quality check.
# The paper 56 has been handed over to the next station at 1514 seconds.
# The robot has returned to the start position at 1517seconds.
# Next Paper 57 arrived at Station 1 at 1522 seconds.
# Operator started the process at 1525seconds.
# The Paper 57 has been loaded into the robot at 1527 seconds.
# The paper 57 has been loaded into the Folding Base at 1529 seconds.
# The paper 57 has been folded at 1535 seconds.
# The paper 57 has been unloaded from the Folding Base at 1538 seconds.
# The paper has been checked for quality at 1538seconds.
# Folded Paper passed quality check.
# The paper 57 has been handed over to the next station at 1542 seconds.
# The robot has returned to the start position at 1544seconds.
# Next Paper 58 arrived at Station 1 at 1547 seconds.
# Operator started the process at 1550seconds.
# The Paper 58 has been loaded into the robot at 1553 seconds.
# The paper 58 has been loaded into the Folding Base at 1556 seconds.
# The paper 58 has been folded at 1560 seconds.
# The paper 58 has been unloaded from the Folding Base at 1563 seconds.
# The paper has been checked for quality at 1563seconds.
# Folded Paper passed quality check.
# The paper 58 has been handed over to the next station at 1568 seconds.
# The robot has returned to the start position at 1570seconds.
# Next Paper 59 arrived at Station 1 at 1572 seconds.
# Operator started the process at 1575seconds.
# The Paper 59 has been loaded into the robot at 1577 seconds.
# The paper 59 has been loaded into the Folding Base at 1579 seconds.
# The paper 59 has been folded at 1583 seconds.
# The paper 59 has been unloaded from the Folding Base at 1585 seconds.
# The paper has been checked for quality at 1585seconds.
# Folded Paper passed quality check.
# The paper 59 has been handed over to the next station at 1591 seconds.
# The robot has returned to the start position at 1594seconds.
# Next Paper 60 arrived at Station 1 at 1598 seconds.
# Operator started the process at 1600seconds.
# The Paper 60 has been loaded into the robot at 1602 seconds.
# The paper 60 has been loaded into the Folding Base at 1605 seconds.
# The paper 60 has been folded at 1609 seconds.
# The paper 60 has been unloaded from the Folding Base at 1612 seconds.
# The paper has been checked for quality at 1612seconds.
# Folded Paper passed quality check.
# The paper 60 has been handed over to the next station at 1617 seconds.
# The robot has returned to the start position at 1619seconds.
# Next Paper 61 arrived at Station 1 at 1622 seconds.
# Operator started the process at 1625seconds.
# The Paper 61 has been loaded into the robot at 1627 seconds.
# The paper 61 has been loaded into the Folding Base at 1630 seconds.
# The paper 61 has been folded at 1634 seconds.
# The paper 61 has been unloaded from the Folding Base at 1636 seconds.
# The paper has been checked for quality at 1636seconds.
# Folded Paper passed quality check.
# The paper 61 has been handed over to the next station at 1642 seconds.
# The robot has returned to the start position at 1644seconds.
# Next Paper 62 arrived at Station 1 at 1648 seconds.
# Operator started the process at 1651seconds.
# The Paper 62 has been loaded into the robot at 1654 seconds.
# The paper 62 has been loaded into the Folding Base at 1657 seconds.
# The paper 62 has been folded at 1663 seconds.
# The paper 62 has been unloaded from the Folding Base at 1666 seconds.
# The paper has been checked for quality at 1666seconds.
# Folded Paper passed quality check.
# The paper 62 has been handed over to the next station at 1671 seconds.
# The robot has returned to the start position at 1673seconds.
# Next Paper 63 arrived at Station 1 at 1678 seconds.
# Operator started the process at 1681seconds.
# The Paper 63 has been loaded into the robot at 1683 seconds.
# The paper 63 has been loaded into the Folding Base at 1686 seconds.
# The paper 63 has been folded at 1692 seconds.
# The paper 63 has been unloaded from the Folding Base at 1694 seconds.
# The paper has been checked for quality at 1694seconds.
# Folded Paper passed quality check.
# The paper 63 has been handed over to the next station at 1699 seconds.
# The robot has returned to the start position at 1701seconds.
# Next Paper 64 arrived at Station 1 at 1703 seconds.
# Operator started the process at 1706seconds.
# The Paper 64 has been loaded into the robot at 1709 seconds.
# The paper 64 has been loaded into the Folding Base at 1712 seconds.
# The paper 64 has been folded at 1719 seconds.
# The paper 64 has been unloaded from the Folding Base at 1722 seconds.
# The paper has been checked for quality at 1722seconds.
# Folded Paper passed quality check.
# The paper 64 has been handed over to the next station at 1728 seconds.
# The robot has returned to the start position at 1731seconds.
# Next Paper 65 arrived at Station 1 at 1735 seconds.
# Operator started the process at 1738seconds.
# The Paper 65 has been loaded into the robot at 1740 seconds.
# The paper 65 has been loaded into the Folding Base at 1743 seconds.
# The paper 65 has been folded at 1749 seconds.
# The paper 65 has been unloaded from the Folding Base at 1752 seconds.
# The paper has been checked for quality at 1752seconds.
# Folded Paper has a defect and goes to waste.
# Paper has been disposed of as waste.
# Operator started the process at 1760seconds.
# The Paper 65 has been loaded into the robot at 1763 seconds.
# The paper 65 has been loaded into the Folding Base at 1765 seconds.
# The paper 65 has been folded at 1771 seconds.
# The paper 65 has been unloaded from the Folding Base at 1773 seconds.
# The paper has been checked for quality at 1773seconds.
# Folded Paper passed quality check.
# The paper 65 has been handed over to the next station at 1778 seconds.
# The robot has returned to the start position at 1781seconds.
# The paper 66 has been handed over to the next station at 1784 seconds.
# The robot has returned to the start position at 1787seconds.
# Next Paper 67 arrived at Station 1 at 1792 seconds.
# Operator started the process at 1794seconds.
# The Paper 67 has been loaded into the robot at 1796 seconds.
# The paper 67 has been loaded into the Folding Base at 1798 seconds.
# The paper 67 has been folded at 1803 seconds.
# The paper 67 has been unloaded from the Folding Base at 1806 seconds.
# The paper has been checked for quality at 1806seconds.
# Folded Paper passed quality check.
# The paper 67 has been handed over to the next station at 1812 seconds.
# The robot has returned to the start position at 1814seconds.
# Next Paper 68 arrived at Station 1 at 1819 seconds.
# Operator started the process at 1822seconds.
# The Paper 68 has been loaded into the robot at 1824 seconds.
# The paper 68 has been loaded into the Folding Base at 1826 seconds.
# The paper 68 has been folded at 1831 seconds.
# The paper 68 has been unloaded from the Folding Base at 1833 seconds.
# The paper has been checked for quality at 1833seconds.
# Folded Paper passed quality check.
# The paper 68 has been handed over to the next station at 1837 seconds.
# The robot has returned to the start position at 1839seconds.
# Next Paper 69 arrived at Station 1 at 1844 seconds.
# Operator started the process at 1847seconds.
# The Paper 69 has been loaded into the robot at 1850 seconds.
# The paper 69 has been loaded into the Folding Base at 1852 seconds.
# The paper 69 has been folded at 1858 seconds.
# The paper 69 has been unloaded from the Folding Base at 1861 seconds.
# The paper has been checked for quality at 1861seconds.
# Folded Paper passed quality check.
# The paper 69 has been handed over to the next station at 1867 seconds.
# The robot has returned to the start position at 1870seconds.
# Next Paper 70 arrived at Station 1 at 1874 seconds.
# Operator started the process at 1876seconds.
# The Paper 70 has been loaded into the robot at 1878 seconds.
# The paper 70 has been loaded into the Folding Base at 1881 seconds.
# The paper 70 has been folded at 1886 seconds.
# The paper 70 has been unloaded from the Folding Base at 1888 seconds.
# The paper has been checked for quality at 1888seconds.
# Folded Paper passed quality check.
# The paper 70 has been handed over to the next station at 1893 seconds.
# The robot has returned to the start position at 1895seconds.
# Next Paper 71 arrived at Station 1 at 1899 seconds.
# Operator started the process at 1902seconds.
# The Paper 71 has been loaded into the robot at 1905 seconds.
# The paper 71 has been loaded into the Folding Base at 1908 seconds.
# The paper 71 has been folded at 1915 seconds.
# The paper 71 has been unloaded from the Folding Base at 1917 seconds.
# The paper has been checked for quality at 1917seconds.
# Folded Paper passed quality check.
# The paper 71 has been handed over to the next station at 1921 seconds.
# The robot has returned to the start position at 1924seconds.
# Next Paper 72 arrived at Station 1 at 1929 seconds.
# Operator started the process at 1932seconds.
# The Paper 72 has been loaded into the robot at 1934 seconds.
# The paper 72 has been loaded into the Folding Base at 1936 seconds.
# The paper 72 has been folded at 1941 seconds.
# The paper 72 has been unloaded from the Folding Base at 1943 seconds.
# The paper has been checked for quality at 1943seconds.
# Folded Paper passed quality check.
# The paper 72 has been handed over to the next station at 1947 seconds.
# The robot has returned to the start position at 1949seconds.
# Next Paper 73 arrived at Station 1 at 1951 seconds.
# Operator started the process at 1953seconds.
# The Paper 73 has been loaded into the robot at 1955 seconds.
# The paper 73 has been loaded into the Folding Base at 1958 seconds.
# The paper 73 has been folded at 1965 seconds.
# The paper 73 has been unloaded from the Folding Base at 1968 seconds.
# The paper has been checked for quality at 1968seconds.
# Folded Paper has a defect and goes to waste.
# Paper has been disposed of as waste.
# Operator started the process at 1975seconds.
# The Paper 73 has been loaded into the robot at 1977 seconds.
# The paper 73 has been loaded into the Folding Base at 1980 seconds.
# The paper 73 has been folded at 1987 seconds.
# The paper 73 has been unloaded from the Folding Base at 1989 seconds.
# The paper has been checked for quality at 1989seconds.
# Folded Paper passed quality check.
# The paper 73 has been handed over to the next station at 1994 seconds.
# The robot has returned to the start position at 1997seconds.
# The paper 74 has been handed over to the next station at 2000 seconds.
# The robot has returned to the start position at 2002seconds.
# Next Paper 75 arrived at Station 1 at 2006 seconds.
# Operator started the process at 2008seconds.
# The Paper 75 has been loaded into the robot at 2011 seconds.
# The paper 75 has been loaded into the Folding Base at 2014 seconds.
# The paper 75 has been folded at 2020 seconds.
# The paper 75 has been unloaded from the Folding Base at 2023 seconds.
# The paper has been checked for quality at 2023seconds.
# Folded Paper passed quality check.
# The paper 75 has been handed over to the next station at 2029 seconds.
# The robot has returned to the start position at 2032seconds.
# Next Paper 76 arrived at Station 1 at 2036 seconds.
# Operator started the process at 2039seconds.
# The Paper 76 has been loaded into the robot at 2041 seconds.
# The paper 76 has been loaded into the Folding Base at 2043 seconds.
# The paper 76 has been folded at 2050 seconds.
# The paper 76 has been unloaded from the Folding Base at 2052 seconds.
# The paper has been checked for quality at 2052seconds.
# Folded Paper passed quality check.
# The paper 76 has been handed over to the next station at 2057 seconds.
# The robot has returned to the start position at 2059seconds.
# Next Paper 77 arrived at Station 1 at 2063 seconds.
# Operator started the process at 2066seconds.
# The Paper 77 has been loaded into the robot at 2068 seconds.
# The paper 77 has been loaded into the Folding Base at 2070 seconds.
# The paper 77 has been folded at 2076 seconds.
# The paper 77 has been unloaded from the Folding Base at 2078 seconds.
# The paper has been checked for quality at 2078seconds.
# Folded Paper passed quality check.
# The paper 77 has been handed over to the next station at 2083 seconds.
# The robot has returned to the start position at 2085seconds.
# Next Paper 78 arrived at Station 1 at 2090 seconds.
# Operator started the process at 2093seconds.
# The Paper 78 has been loaded into the robot at 2096 seconds.
# The paper 78 has been loaded into the Folding Base at 2098 seconds.
# The paper 78 has been folded at 2102 seconds.
# The paper 78 has been unloaded from the Folding Base at 2104 seconds.
# The paper has been checked for quality at 2104seconds.
# Folded Paper passed quality check.
# The paper 78 has been handed over to the next station at 2109 seconds.
# The robot has returned to the start position at 2112seconds.
# Next Paper 79 arrived at Station 1 at 2115 seconds.
# Operator started the process at 2118seconds.
# The Paper 79 has been loaded into the robot at 2121 seconds.
# The paper 79 has been loaded into the Folding Base at 2123 seconds.
# The paper 79 has been folded at 2129 seconds.
# The paper 79 has been unloaded from the Folding Base at 2131 seconds.
# The paper has been checked for quality at 2131seconds.
# Folded Paper passed quality check.
# The paper 79 has been handed over to the next station at 2137 seconds.
# The robot has returned to the start position at 2140seconds.
# Next Paper 80 arrived at Station 1 at 2142 seconds.
# Operator started the process at 2144seconds.
# The Paper 80 has been loaded into the robot at 2146 seconds.
# The paper 80 has been loaded into the Folding Base at 2148 seconds.
# The paper 80 has been folded at 2154 seconds.
# The paper 80 has been unloaded from the Folding Base at 2156 seconds.
# The paper has been checked for quality at 2156seconds.
# Folded Paper passed quality check.
# The paper 80 has been handed over to the next station at 2161 seconds.
# The robot has returned to the start position at 2163seconds.
# Next Paper 81 arrived at Station 1 at 2167 seconds.
# Operator started the process at 2170seconds.
# The Paper 81 has been loaded into the robot at 2173 seconds.
# The paper 81 has been loaded into the Folding Base at 2175 seconds.
# The paper 81 has been folded at 2179 seconds.
# The paper 81 has been unloaded from the Folding Base at 2182 seconds.
# The paper has been checked for quality at 2182seconds.
# Folded Paper passed quality check.
# The paper 81 has been handed over to the next station at 2187 seconds.
# The robot has returned to the start position at 2190seconds.
# Next Paper 82 arrived at Station 1 at 2193 seconds.
# Operator started the process at 2195seconds.
# The Paper 82 has been loaded into the robot at 2197 seconds.
# The paper 82 has been loaded into the Folding Base at 2200 seconds.
# The paper 82 has been folded at 2206 seconds.
# The paper 82 has been unloaded from the Folding Base at 2209 seconds.
# The paper has been checked for quality at 2209seconds.
# Folded Paper passed quality check.
# The paper 82 has been handed over to the next station at 2214 seconds.
# The robot has returned to the start position at 2217seconds.
# Next Paper 83 arrived at Station 1 at 2219 seconds.
# Operator started the process at 2221seconds.
# The Paper 83 has been loaded into the robot at 2224 seconds.
# The paper 83 has been loaded into the Folding Base at 2226 seconds.
# The paper 83 has been folded at 2231 seconds.
# The paper 83 has been unloaded from the Folding Base at 2233 seconds.
# The paper has been checked for quality at 2233seconds.
# Folded Paper has a defect and goes to waste.
# Paper has been disposed of as waste.
# Operator started the process at 2242seconds.
# The Paper 83 has been loaded into the robot at 2245 seconds.
# The paper 83 has been loaded into the Folding Base at 2248 seconds.
# The paper 83 has been folded at 2252 seconds.
# The paper 83 has been unloaded from the Folding Base at 2254 seconds.
# The paper has been checked for quality at 2254seconds.
# Folded Paper passed quality check.
# The paper 83 has been handed over to the next station at 2258 seconds.
# The robot has returned to the start position at 2261seconds.
# The paper 84 has been handed over to the next station at 2263 seconds.
# The robot has returned to the start position at 2265seconds.
# Next Paper 85 arrived at Station 1 at 2270 seconds.
# Operator started the process at 2273seconds.
# The Paper 85 has been loaded into the robot at 2276 seconds.
# The paper 85 has been loaded into the Folding Base at 2279 seconds.
# The paper 85 has been folded at 2284 seconds.
# The paper 85 has been unloaded from the Folding Base at 2287 seconds.
# The paper has been checked for quality at 2287seconds.
# Folded Paper has a defect and goes to waste.
# Paper has been disposed of as waste.
# ...
# The paper 1061 has been handed over to the next station at 28082 seconds.
# The robot has returned to the start position at 28084seconds.
# Next Paper 1062 arrived at Station 1 at 28088 seconds.
# Operator started the process at 28090seconds.
# The Paper 1062 has been loaded into the robot at 28093 seconds.
# The paper 1062 has been loaded into the Folding Base at 28096 seconds.
# The paper 1062 has been folded at 28100 seconds.
# The paper 1062 has been unloaded from the Folding Base at 28102 seconds.
# The paper has been checked for quality at 28102seconds.
# Folded Paper passed quality check.
# The paper 1062 has been handed over to the next station at 28107 seconds.
# The robot has returned to the start position at 28109seconds.
# Next Paper 1063 arrived at Station 1 at 28112 seconds.
# Operator started the process at 28115seconds.
# The Paper 1063 has been loaded into the robot at 28117 seconds.
# The paper 1063 has been loaded into the Folding Base at 28119 seconds.
# The paper 1063 has been folded at 28126 seconds.
# The paper 1063 has been unloaded from the Folding Base at 28128 seconds.
# The paper has been checked for quality at 28128seconds.
# Folded Paper passed quality check.
# The paper 1063 has been handed over to the next station at 28133 seconds.
# The robot has returned to the start position at 28136seconds.
# Next Paper 1064 arrived at Station 1 at 28141 seconds.
# Operator started the process at 28144seconds.
# The Paper 1064 has been loaded into the robot at 28147 seconds.
# The paper 1064 has been loaded into the Folding Base at 28150 seconds.
# The paper 1064 has been folded at 28156 seconds.
# The paper 1064 has been unloaded from the Folding Base at 28159 seconds.
# The paper has been checked for quality at 28159seconds.
# Folded Paper passed quality check.
# The paper 1064 has been handed over to the next station at 28164 seconds.
# The robot has returned to the start position at 28166seconds.
# Next Paper 1065 arrived at Station 1 at 28171 seconds.
# Operator started the process at 28174seconds.
# The Paper 1065 has been loaded into the robot at 28177 seconds.
# The paper 1065 has been loaded into the Folding Base at 28179 seconds.
# The paper 1065 has been folded at 28184 seconds.
# The paper 1065 has been unloaded from the Folding Base at 28187 seconds.
# The paper has been checked for quality at 28187seconds.
# Folded Paper passed quality check.
# The paper 1065 has been handed over to the next station at 28193 seconds.
# The robot has returned to the start position at 28196seconds.
# Next Paper 1066 arrived at Station 1 at 28198 seconds.
# Operator started the process at 28201seconds.
# The Paper 1066 has been loaded into the robot at 28204 seconds.
# The paper 1066 has been loaded into the Folding Base at 28206 seconds.
# The paper 1066 has been folded at 28210 seconds.
# The paper 1066 has been unloaded from the Folding Base at 28212 seconds.
# The paper has been checked for quality at 28212seconds.
# Folded Paper passed quality check.
# The paper 1066 has been handed over to the next station at 28217 seconds.
# The robot has returned to the start position at 28219seconds.
# Next Paper 1067 arrived at Station 1 at 28224 seconds.
# Operator started the process at 28227seconds.
# The Paper 1067 has been loaded into the robot at 28230 seconds.
# The paper 1067 has been loaded into the Folding Base at 28232 seconds.
# The paper 1067 has been folded at 28239 seconds.
# The paper 1067 has been unloaded from the Folding Base at 28242 seconds.
# The paper has been checked for quality at 28242seconds.
# Folded Paper passed quality check.
# The paper 1067 has been handed over to the next station at 28247 seconds.
# The robot has returned to the start position at 28249seconds.
# Next Paper 1068 arrived at Station 1 at 28252 seconds.
# Operator started the process at 28254seconds.
# The Paper 1068 has been loaded into the robot at 28257 seconds.
# The paper 1068 has been loaded into the Folding Base at 28260 seconds.
# The paper 1068 has been folded at 28266 seconds.
# The paper 1068 has been unloaded from the Folding Base at 28268 seconds.
# The paper has been checked for quality at 28268seconds.
# Folded Paper passed quality check.
# The paper 1068 has been handed over to the next station at 28273 seconds.
# The robot has returned to the start position at 28276seconds.
# Next Paper 1069 arrived at Station 1 at 28278 seconds.
# Operator started the process at 28280seconds.
# The Paper 1069 has been loaded into the robot at 28282 seconds.
# The paper 1069 has been loaded into the Folding Base at 28284 seconds.
# The paper 1069 has been folded at 28288 seconds.
# The paper 1069 has been unloaded from the Folding Base at 28291 seconds.
# The paper has been checked for quality at 28291seconds.
# Folded Paper passed quality check.
# The paper 1069 has been handed over to the next station at 28297 seconds.
# The robot has returned to the start position at 28300seconds.
# Next Paper 1070 arrived at Station 1 at 28305 seconds.
# Operator started the process at 28308seconds.
# The Paper 1070 has been loaded into the robot at 28310 seconds.
# The paper 1070 has been loaded into the Folding Base at 28313 seconds.
# The paper 1070 has been folded at 28318 seconds.
# The paper 1070 has been unloaded from the Folding Base at 28320 seconds.
# The paper has been checked for quality at 28320seconds.
# Folded Paper passed quality check.
# The paper 1070 has been handed over to the next station at 28325 seconds.
# The robot has returned to the start position at 28328seconds.
# Next Paper 1071 arrived at Station 1 at 28330 seconds.
# Operator started the process at 28332seconds.
# The Paper 1071 has been loaded into the robot at 28335 seconds.
# The paper 1071 has been loaded into the Folding Base at 28338 seconds.
# The paper 1071 has been folded at 28345 seconds.
# The paper 1071 has been unloaded from the Folding Base at 28348 seconds.
# The paper has been checked for quality at 28348seconds.
# Folded Paper passed quality check.
# The paper 1071 has been handed over to the next station at 28353 seconds.
# The robot has returned to the start position at 28356seconds.
# Next Paper 1072 arrived at Station 1 at 28361 seconds.
# Operator started the process at 28363seconds.
# The Paper 1072 has been loaded into the robot at 28365 seconds.
# The paper 1072 has been loaded into the Folding Base at 28367 seconds.
# The paper 1072 has been folded at 28373 seconds.
# The paper 1072 has been unloaded from the Folding Base at 28376 seconds.
# The paper has been checked for quality at 28376seconds.
# Folded Paper passed quality check.
# The paper 1072 has been handed over to the next station at 28382 seconds.
# The robot has returned to the start position at 28384seconds.
# Next Paper 1073 arrived at Station 1 at 28389 seconds.
# Operator started the process at 28392seconds.
# The Paper 1073 has been loaded into the robot at 28395 seconds.
# The paper 1073 has been loaded into the Folding Base at 28397 seconds.
# The paper 1073 has been folded at 28401 seconds.
# The paper 1073 has been unloaded from the Folding Base at 28404 seconds.
# The paper has been checked for quality at 28404seconds.
# Folded Paper passed quality check.
# The paper 1073 has been handed over to the next station at 28409 seconds.
# The robot has returned to the start position at 28411seconds.
# Next Paper 1074 arrived at Station 1 at 28413 seconds.
# Operator started the process at 28416seconds.
# The Paper 1074 has been loaded into the robot at 28418 seconds.
# The paper 1074 has been loaded into the Folding Base at 28421 seconds.
# The paper 1074 has been folded at 28425 seconds.
# The paper 1074 has been unloaded from the Folding Base at 28428 seconds.
# The paper has been checked for quality at 28428seconds.
# Folded Paper passed quality check.
# The paper 1074 has been handed over to the next station at 28432 seconds.
# The robot has returned to the start position at 28435seconds.
# Next Paper 1075 arrived at Station 1 at 28438 seconds.
# Operator started the process at 28441seconds.
# The Paper 1075 has been loaded into the robot at 28443 seconds.
# The paper 1075 has been loaded into the Folding Base at 28445 seconds.
# The paper 1075 has been folded at 28451 seconds.
# The paper 1075 has been unloaded from the Folding Base at 28453 seconds.
# The paper has been checked for quality at 28453seconds.
# Folded Paper passed quality check.
# The paper 1075 has been handed over to the next station at 28459 seconds.
# The robot has returned to the start position at 28462seconds.
# Next Paper 1076 arrived at Station 1 at 28464 seconds.
# Operator started the process at 28466seconds.
# The Paper 1076 has been loaded into the robot at 28468 seconds.
# The paper 1076 has been loaded into the Folding Base at 28470 seconds.
# The paper 1076 has been folded at 28476 seconds.
# The paper 1076 has been unloaded from the Folding Base at 28479 seconds.
# The paper has been checked for quality at 28479seconds.
# Folded Paper passed quality check.
# The paper 1076 has been handed over to the next station at 28484 seconds.
# The robot has returned to the start position at 28486seconds.
# Next Paper 1077 arrived at Station 1 at 28488 seconds.
# Operator started the process at 28490seconds.
# The Paper 1077 has been loaded into the robot at 28492 seconds.
# The paper 1077 has been loaded into the Folding Base at 28494 seconds.
# The paper 1077 has been folded at 28499 seconds.
# The paper 1077 has been unloaded from the Folding Base at 28501 seconds.
# The paper has been checked for quality at 28501seconds.
# Folded Paper passed quality check.
# The paper 1077 has been handed over to the next station at 28505 seconds.
# The robot has returned to the start position at 28507seconds.
# Next Paper 1078 arrived at Station 1 at 28509 seconds.
# Operator started the process at 28511seconds.
# The Paper 1078 has been loaded into the robot at 28514 seconds.
# The paper 1078 has been loaded into the Folding Base at 28516 seconds.
# The paper 1078 has been folded at 28523 seconds.
# The paper 1078 has been unloaded from the Folding Base at 28526 seconds.
# The paper has been checked for quality at 28526seconds.
# Folded Paper passed quality check.
# The paper 1078 has been handed over to the next station at 28530 seconds.
# The robot has returned to the start position at 28532seconds.
# Next Paper 1079 arrived at Station 1 at 28534 seconds.
# Operator started the process at 28536seconds.
# The Paper 1079 has been loaded into the robot at 28538 seconds.
# The paper 1079 has been loaded into the Folding Base at 28541 seconds.
# The paper 1079 has been folded at 28546 seconds.
# The paper 1079 has been unloaded from the Folding Base at 28548 seconds.
# The paper has been checked for quality at 28548seconds.
# Folded Paper passed quality check.
# The paper 1079 has been handed over to the next station at 28553 seconds.
# The robot has returned to the start position at 28555seconds.
# Next Paper 1080 arrived at Station 1 at 28557 seconds.
# Operator started the process at 28559seconds.
# The Paper 1080 has been loaded into the robot at 28561 seconds.
# The paper 1080 has been loaded into the Folding Base at 28564 seconds.
# The paper 1080 has been folded at 28570 seconds.
# The paper 1080 has been unloaded from the Folding Base at 28572 seconds.
# The paper has been checked for quality at 28572seconds.
# Folded Paper passed quality check.
# The paper 1080 has been handed over to the next station at 28577 seconds.
# The robot has returned to the start position at 28580seconds.
# Next Paper 1081 arrived at Station 1 at 28585 seconds.
# Operator started the process at 28587seconds.
# The Paper 1081 has been loaded into the robot at 28589 seconds.
# The paper 1081 has been loaded into the Folding Base at 28592 seconds.
# The paper 1081 has been folded at 28598 seconds.
# The paper 1081 has been unloaded from the Folding Base at 28601 seconds.
# The paper has been checked for quality at 28601seconds.
# Folded Paper passed quality check.
# The paper 1081 has been handed over to the next station at 28606 seconds.
# The robot has returned to the start position at 28608seconds.
# Next Paper 1082 arrived at Station 1 at 28611 seconds.
# Operator started the process at 28613seconds.
# The Paper 1082 has been loaded into the robot at 28615 seconds.
# The paper 1082 has been loaded into the Folding Base at 28618 seconds.
# The paper 1082 has been folded at 28625 seconds.
# The paper 1082 has been unloaded from the Folding Base at 28628 seconds.
# The paper has been checked for quality at 28628seconds.
# Folded Paper passed quality check.
# The paper 1082 has been handed over to the next station at 28632 seconds.
# The robot has returned to the start position at 28634seconds.
# Next Paper 1083 arrived at Station 1 at 28639 seconds.
# Operator started the process at 28642seconds.
# The Paper 1083 has been loaded into the robot at 28644 seconds.
# The paper 1083 has been loaded into the Folding Base at 28646 seconds.
# The paper 1083 has been folded at 28651 seconds.
# The paper 1083 has been unloaded from the Folding Base at 28654 seconds.
# The paper has been checked for quality at 28654seconds.
# Folded Paper passed quality check.
# The paper 1083 has been handed over to the next station at 28659 seconds.
# The robot has returned to the start position at 28661seconds.
# Next Paper 1084 arrived at Station 1 at 28664 seconds.
# Operator started the process at 28667seconds.
# The Paper 1084 has been loaded into the robot at 28670 seconds.
# The paper 1084 has been loaded into the Folding Base at 28672 seconds.
# The paper 1084 has been folded at 28679 seconds.
# The paper 1084 has been unloaded from the Folding Base at 28681 seconds.
# The paper has been checked for quality at 28681seconds.
# Folded Paper passed quality check.
# The paper 1084 has been handed over to the next station at 28685 seconds.
# The robot has returned to the start position at 28687seconds.
# Next Paper 1085 arrived at Station 1 at 28692 seconds.
# Operator started the process at 28695seconds.
# The Paper 1085 has been loaded into the robot at 28697 seconds.
# The paper 1085 has been loaded into the Folding Base at 28699 seconds.
# The paper 1085 has been folded at 28706 seconds.
# The paper 1085 has been unloaded from the Folding Base at 28709 seconds.
# The paper has been checked for quality at 28709seconds.
# Folded Paper passed quality check.
# The paper 1085 has been handed over to the next station at 28713 seconds.
# The robot has returned to the start position at 28715seconds.
# Next Paper 1086 arrived at Station 1 at 28719 seconds.
# Operator started the process at 28722seconds.
# The Paper 1086 has been loaded into the robot at 28725 seconds.
# The paper 1086 has been loaded into the Folding Base at 28727 seconds.
# The paper 1086 has been folded at 28732 seconds.
# The paper 1086 has been unloaded from the Folding Base at 28735 seconds.
# The paper has been checked for quality at 28735seconds.
# Folded Paper passed quality check.
# The paper 1086 has been handed over to the next station at 28739 seconds.
# The robot has returned to the start position at 28741seconds.
# Next Paper 1087 arrived at Station 1 at 28746 seconds.
# Operator started the process at 28748seconds.
# The Paper 1087 has been loaded into the robot at 28750 seconds.
# The paper 1087 has been loaded into the Folding Base at 28752 seconds.
# The paper 1087 has been folded at 28756 seconds.
# The paper 1087 has been unloaded from the Folding Base at 28758 seconds.
# The paper has been checked for quality at 28758seconds.
# Folded Paper passed quality check.
# The paper 1087 has been handed over to the next station at 28764 seconds.
# The robot has returned to the start position at 28767seconds.
# Next Paper 1088 arrived at Station 1 at 28770 seconds.
# Operator started the process at 28773seconds.
# The Paper 1088 has been loaded into the robot at 28775 seconds.
# The paper 1088 has been loaded into the Folding Base at 28778 seconds.
# The paper 1088 has been folded at 28782 seconds.
# The paper 1088 has been unloaded from the Folding Base at 28785 seconds.
# The paper has been checked for quality at 28785seconds.
# Folded Paper passed quality check.
# The paper 1088 has been handed over to the next station at 28791 seconds.
# The robot has returned to the start position at 28794seconds.
# Next Paper 1089 arrived at Station 1 at 28799 seconds.

# %% [markdown]
# ## Results of the Simulation
# The outcomes of the simulation are presented in a detailed table, offering insights into various performance metrics. Following the tabular representation, there are two accompanying bar charts. The first chart visually depicts the total count of folded papers and defective papers, providing a comparative view of these key production aspects. The second bar chart illustrates a comparison of average times associated with different processes.

# %%
print ("The Simulation is ended and the results are shown below")
print ("The number of produced papers is "+str(workstation1.folded_papers-1)+".")
print ("the simulation duration is "+str(env.now)+"seconds.")
print ("The number of produced papers is "+str(workstation1.folded_papers-1)+".")
# Calculate the average folding time

produced_papers = len(paper_list)
simulation_time = 28800
average_process_time = simulation_time/produced_papers
average_folding1_time = workstation1.totalfolding1_time/produced_papers
average_folding2_time = workstation1.totalfolding2_time/produced_papers
average_folding_time = average_folding1_time + average_folding2_time
average_paper_loading_verification_time = workstation1.paper_loading_verification_time/produced_papers
average_paper_alignment_verification_time = workstation1.paper_alignment_verification_time/produced_papers
average_quality_check_time = workstation1.total_quality_check_time/produced_papers
average_operator_idle_time = workstation1.operator_idle_time/produced_papers

print ("The average process time of the produced papers is {:.2f} seconds.".format(average_process_time))
# After running the simulation, calculate and print the average folding 1 time
print ("The average Folding process time is {:.2f} seconds.".format(average_folding1_time))
print ("The average Quality check time is {:.2f} seconds.".format(average_quality_check_time))
print ("The average paper loading verification time is {:.2f} seconds.".format(average_paper_loading_verification_time))
print ("The average paper alignment verification time is {:.2f} seconds.".format(average_paper_alignment_verification_time))
print ("The number of defective papers is "+str(workstation1.defective_papers)+".")
print ("The average operator idle time is {:.2f} seconds.".format(average_operator_idle_time))

#The presented table provides a comprehensive summary of key performance metrics and 
# outcomes from a simulated production process. It includes essential information such as the total number of produced papers, the overall simulation duration, and various average times associated with different stages of the production workflow. 

from tabulate import tabulate

table_data = [
    ("Produced Papers", workstation1.folded_papers-1),
    ("Simulation Duration", f"{env.now} seconds"),
    ("Average Process Time (Cycle Time)", "{:.2f} seconds".format(average_process_time)),
    ("Average Folding  Time", "{:.2f} seconds".format(average_folding1_time)),
    ("Average Paper Loading Verification Time", "{:.2f} seconds".format(average_paper_loading_verification_time)),
    ("Average Paper Alignment Verification Time", "{:.2f} seconds".format(average_paper_alignment_verification_time)),
    ("Average Quality Check Time", "{:.2f} seconds".format(average_quality_check_time)),
    ("Defective Papers", workstation1.defective_papers),
    ("Average Operator Idle Time during the process", "{:.2f} seconds".format(average_operator_idle_time)
    ),
]


# Print the table
print(tabulate(table_data, headers=["Metric", "Value"], tablefmt="grid"))

# bar chart , Categories and corresponding average times
categories = ['Folded Papers ', 'Defective Papers ']
average_times = [produced_papers, workstation1.defective_papers]

import matplotlib.pyplot as plt
import numpy as np
# Plotting the bar chart
plt.bar(categories, average_times, color=['blue', 'green'])
plt.xlabel('Processes')
plt.ylabel('Number of Papers')
plt.title('Folded Papers and Defective Papers')
plt.show()
# Out:
# The Simulation is ended and the results are shown below
# The number of produced papers is 1088.
# the simulation duration is 28800seconds.
# The number of produced papers is 1088.
# The average process time of the produced papers is 29.24 seconds.
# The average Folding process time is 6.13 seconds.
# The average Quality check time is 5.63 seconds.
# The average paper loading verification time is 0.00 seconds.
# The average paper alignment verification time is 0.00 seconds.
# The number of defective papers is 105.
# The average operator idle time is 19.33 seconds.
# +-----------------------------------------------+---------------+
# | Metric                                        | Value         |
# +===============================================+===============+
# | Produced Papers                               | 1088          |
# +-----------------------------------------------+---------------+
# | Simulation Duration                           | 28800 seconds |
# +-----------------------------------------------+---------------+
# | Average Process Time (Cycle Time)             | 29.24 seconds |
# +-----------------------------------------------+---------------+
# | Average Folding  Time                         | 6.13 seconds  |
# +-----------------------------------------------+---------------+
# | Average Paper Loading Verification Time       | 0.00 seconds  |
# +-----------------------------------------------+---------------+
# | Average Paper Alignment Verification Time     | 0.00 seconds  |
# +-----------------------------------------------+---------------+
# | Average Quality Check Time                    | 5.63 seconds  |
# +-----------------------------------------------+---------------+
# | Defective Papers                              | 105           |
# +-----------------------------------------------+---------------+
# | Average Operator Idle Time during the process | 19.33 seconds |
# +-----------------------------------------------+---------------+

# %%
#This Bar chart that visually compares the average times for different processes.

import matplotlib.pyplot as plt
import numpy as np



# Categories and corresponding average times
categories = ['Folding ', 'Quality Check' ]
average_times = [average_folding1_time, average_quality_check_time]

# Plotting the bar chart
plt.bar(categories, average_times, color=['blue', 'green'])
plt.xlabel('Processes')
plt.ylabel('Average Time (seconds)')
plt.title('Comparison of Average Times for Different Processes')
plt.show()
