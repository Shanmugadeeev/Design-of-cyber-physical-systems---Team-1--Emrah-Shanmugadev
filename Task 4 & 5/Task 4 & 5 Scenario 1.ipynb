# %% [markdown]
# ## Scenario 1 - Varying Paper Density
#
# In this scenario, the key parameter under consideration is the density of paper, which represents the mass or thickness of the paper being processed.
# Notable changes include adjustments to the probabilities of loading errors and misalignments due to varying paper sizes. These changes aim to reflect the variability encountered in real-world scenarios.
#
# Updated Parameters :(The probabilities of errors and misalignments are determined , after closely documented the real-world testings with the help of Twente-Team ).
#
# PaperLoadingStation
# Loading Error Probability: 32% (previously 30%)
# Misalignment Probability: 32% (previously 30%)
#
# Operator
# Loading Error Adjustment Probability: 32% (previously 30%)
# Misalignment Adjustment Probability: 32% (previously 30%)
#
# Robot
# No significant changes in robot behavior.
#
# Quality Check
# Defective Paper Probability: 10%
#
# By paper density have a minimal impact on the efficiency of loading, unloading, and folding operations. In other words, the loading and unloading processes, as well as the folding operation, appear to be less sensitive to changes in paper density during real-world applications.
#
# "Short summary of the result :
#  The efficiency is decreased by approximately 0.38 % .
#
# The outcomes of the simulation are presented in a detailed table, offering insights into various performance metrics. Following the tabular representation, there are two accompanying bar charts. The first chart visually depicts the total count of folded papers and defective papers, providing a comparative view of these key production aspects. The second bar chart illustrates a comparison of average times associated with different processes.

# %%
import simpy
import random

#Defining Resources (Paper  ,Robot , Operator ,Paper Loading Station)

#defining Paper 

class Paper:
    def __init__(self, env, workstation1):
        self.is_defective = False
        pass

class PaperLoadingstation (object):
    # Initally the paper laodingstation has 100 papers.
    def __init__(self,env):
        self.papers = simpy.PaperLoadingstation (env, init=100, capaciy = 100)

    def check_availability_paperloadingstation(self,operator):
        # check if there is enough paper on the Loading station

        # This takes between 1-3 seconds
         yield self.env.timeout(random.randint(1, 3))

         if self.paperloadingstation == 1:
           # if there are enough paper, return True
           # print("there are enough paper available ")
           return True
         else:
            print("There are not enough paper available on the station , please refill ")
            
            return False
         
    def pick_paper(self,operator,workstation1,Robot):
        while not self.env.process(self.check_availability_paperloadingstation(Robot)):
         yield self.env.timeout(1)
         yield self.pickup_paperloadingstation.get(1) & self.env.process(self.restock())  # & self.env.process(workstation3.pickup_paper(robot))
    
    def restock_paperloadingstation(self):
         #restock the paperdispenser , this takes between 15-25 seconds
          yield self.env.timeout(random.randint(5,10))
          #restock the paper dispenser
          yield self.pickup_paperdispenser.put(100)
          print("The paper dispenser has been restocked")

#defining Robot
    
class Robot(object):
   
    def __init__(self,env,workstation1):
        self.env = env
        
        self.workstation1 = workstation1
        self.robot = simpy.Resource(env,capacity= 1)
        

    #The calibration takes place as a first step, this will takes around 2-3 Seconds
    def actuate(self,workstation1):
        yield self.env.timeout(random.randint(2,3))
        
    #the paper is loaded into the robot
    def load_paper(self,paper,paperloadingstation):
        yield self.env.timeout(random.randint(2,3))
        
     #the paper is loaded into Folding Base by the  robot , where the folding operation takes place
    def load_paper_to_foldingbase(self,paper):
        yield self.env.timeout(random.randint(2,3)) 
        
    
    #the Folding operation takes place by the robot
    def fold_paper(self,paper):
        yield self.env.timeout(random.randint(4,7))
        
    #the paper is unloaded from the Folding Base by the robot
    def unload_paper_from_foldingbase(self,paper):
        yield self.env.timeout(random.randint(2,3))
        
    def return_to_start(self):
        yield self.env.timeout(random.randint(2, 3))
    
    #At the end ,hand over the folded paper to the next station for further operations
    def hand_over_paper(self,workstation2):
        yield self.env.timeout (random.randint(2,3))
        

#defining Operator
        

class Operator (object):
    def __init__(self,env,workstation1,folded_papers):
        self.env = env
        self.workstation1 = workstation1
        self.folded_papers = folded_papers
        
        self.quality_check_times = {'check1': []}
        self.total_idle_time = 0
        
        
    def adjust_paper_loading(self, paper):
        # Check if the paper is loaded properly
        if random.random() < 0.32:  # 35% chance of loading error because of varying paper sizes
            print("Paper not loaded properly. Adjusting...")
            yield self.env.timeout(random.randint(1, 3))
            print("Adjustment completed.")
        else:
            print("Paper is loaded properly.")
        
        

    def quality_check_fold(self, paper):
        # Quality check after Folding Operation
        start_time = self.env.now
        yield self.env.timeout(random.randint(2, 3))
        end_time = self.env.now
        self.quality_check_times['check1'].append(end_time - start_time)

        # Assume a 10% chance of a defect
        if random.random() < 0.1:
            paper.is_defective = True

        if paper.is_defective:
            # If the paper is defective, send it to waste
            print("Folded Paper has a defect and goes to waste.")
            yield self.env.process(self.workstation1.WasteStation.dispose(paper))
            robot = Robot(self.env, self.workstation1)
            yield self.env.process(self.workstation1.workstation1_process(self, Paper(self.env, self.workstation1), robot))
            
        else:
            print("Folded Paper passed quality check.")
        
        
        self.idle_start_time = self.env.now
        
    def align_paper(self, paper):
        # Check if the paper is aligned properly
        if random.random() < 0.32:  # 32% chance of misalignment , because of vaeing paper sizes
            print("Paper misaligned. Aligning...")
            yield self.env.timeout(random.randint(1, 3))
            print("Alignment completed.")
        else:
            print("Paper is aligned properly.")
    
        

#defining Workstation2 
class Workstation2(object):
    def __init__(self,env):
        self.env = env
        
class WasteStation(object):
    def __init__(self, env):
        self.env = env

    def dispose(self,paper):
        # Waste disposal process
        yield self.env.timeout(random.randint(2, 3))
        print("Paper has been disposed of as waste.")

# %%
##2.Environment
#In the 2nd step we will implement the environment in which the simulation takes place.
#Here we will set up the ressources and the genereal process flow.

# %%
#Defining the workstatiion1

class WorkStation1(object):
    def __init__(self,env,paper_list,robot,Workstation2,operator,folded_papers):
        self.env = env
        self.folded_papers = folded_papers
        
        self.operator = operator(env,self, self.folded_papers )
        self.idle_start_time = 0
        
        self.robot = robot(env,self)
        self.workstation2 = Workstation2(env)
        
        self.WasteStation = WasteStation(env) 
         
        self.folded_papers = 0
        self.total_operation_time = 0
        self.totalfolding1_time = 0
        self.paper_loading_verification_time = 0
        self.paper_alignment_verification_time = 0
        self.totalfolding2_time = 0
        self.total_quality_check_time = 0
        self.defective_papers = 0
        self.operator_idle_time = 0
        self.start_idle_time = 0
        self.total_idle_time = 0
        
        
        
        
        
        self.production_rate_data = []
        self.operation_times = []

    def workstation1_process(self,operator,paper,robot):
        
       #Track the time
        arrival_time=self.env.now
        yield self.env.process(self.robot.actuate(self))
        print ("Operator started the process at "+str(self.env.now)+"seconds.")
        #The paper is loaded into the robot
        operator.idle1_start_time = self.env.now 
        #the operator is idle during the paper loading process, and the time is recorded
        yield self.env.process(self.robot.load_paper(paper,PaperLoadingstation))
        print("The Paper " +str(self.folded_papers)+" has been loaded into the robot at "+str(self.env.now)+" seconds.")
        operator.idle1_end_time = self.env.now - operator.idle1_start_time
        

        #the error is checked by the operator
        paper_loading_verification_start_time = self.env.now
        yield self.env.process(self.operator.adjust_paper_loading(paper))
        print("The Paper " +str(self.folded_papers)+" has been checked for loading errors at "+str(self.env.now)+" seconds.")
        paper_loading_verification_end_time = self.env.now - paper_loading_verification_start_time
       
        

        #The paper is loaded into the Folding Base by the robot
        operator.idle2_start_time = self.env.now
        yield self.env.process(self.robot.load_paper_to_foldingbase(paper))
        print ("The paper " +str(self.folded_papers)+" has been loaded into the Folding Base at "+str(self.env.now)+" seconds.")
        operator.idle2_end_time = self.env.now - operator.idle2_start_time

        #the paper alignment is checked by the operator
        paper_alignment_verification_start_time = self.env.now
        print ("The paper " +str(self.folded_papers)+" has been checked for alignment at "+str(self.env.now)+" seconds.")
        yield self.env.process(self.operator.align_paper(paper))
               
        paper_alignment_verification_end_time = self.env.now - paper_alignment_verification_start_time
                
        #The Folding operation takes place by the robot , some steps are done by the operator
        folding1_start_time = self.env.now
        yield self.env.process(self.robot.fold_paper(paper))
        folding1_end_time = self.env.now - folding1_start_time
        print ("The paper " +str(self.folded_papers)+" has been folded at "+str(self.env.now)+" seconds.")

        #The paper is unloaded from the Folding Base by the robot
        operator.idle3_start_time = self.env.now
        yield self.env.process(self.robot.unload_paper_from_foldingbase(paper))
        print ("The paper " +str(self.folded_papers)+" has been unloaded from the Folding Base at "+str(self.env.now)+" seconds.")
        
        #Quality check 
        quality_check_start_time = self.env.now 
        print ("The paper has been checked for quality at "+str(self.env.now)+"seconds.")
        yield self.env.process(self.operator.quality_check_fold(paper))
        
        quality_check_end_time = self.env.now - quality_check_start_time
        if paper.is_defective:
            self.defective_papers += 1

        #the paper is handed over to the next station for further operations
        yield self.env.process(self.robot.hand_over_paper(Workstation2))
        print ("The paper "+str(self.folded_papers)+" has been handed over to the next station at "+str(self.env.now)+" seconds.")
        operator.idle3_end_time = self.env.now - operator.idle3_start_time

        
        #the robot returns to the start position
        operator.idle4_start_time = self.env.now
        yield self.env.process(self.robot.return_to_start())
        print ("The robot has returned to the start position at "+str(self.env.now)+"seconds.")
        operator.idle4_end_time = self.env.now - operator.idle4_start_time
        #the operator is idle during the paper loading process, and the time is recorded

        #Operation time
        operation_time = self.env.now - arrival_time
        #Total folding time
        totalfolding1_time = folding1_end_time 
        #operator idle time
        operator_idle_time = operator.idle1_end_time + operator.idle2_end_time + operator.idle3_end_time + operator.idle4_end_time
        # add the operator idle time to the list of operator idle times
        self.operator_idle_time += operator_idle_time     
                
        # add the paper loading verification time to the list of paper loading verification times
        self.paper_loading_verification_time += paper_loading_verification_end_time
        # add the paper alignment verification time to the list of paper alignment verification times
        self.paper_alignment_verification_time += paper_alignment_verification_end_time
        total_quality_check_time = quality_check_end_time
        self.total_quality_check_time += total_quality_check_time

        # add the production rate data to the list
        self.production_rate_data.append((self.env.now, self.folded_papers))

        
        # add the folding time to the list of folding times
        self.totalfolding1_time += totalfolding1_time
        
        
    
        # add the process time to the total production time
        self.total_operation_time += operation_time

        # count the produced papers
        self.folded_papers += 1

# %%
###3.Simulation
#In the third step we will run the simulation and therefor define an initial set of parameter to simulate.

# %%
def paper_generator(env, workstation1, paper_list):
    while True:
        interarrival_time = random.randint(2,5)

        paper = Paper(env, workstation1)
        paper_list.append(paper)

        operator = Operator(env, workstation1, workstation1.folded_papers)
        robot = Robot(env, workstation1)

        yield env.process(workstation1.workstation1_process(operator, paper,robot))

        yield env.timeout(interarrival_time)
        print("Next Paper " + str(workstation1.folded_papers) + " arrived at Station 1 at " + str(env.now) + " seconds.")
import simpy
env = simpy.Environment()

paper_list=[]
folded_papers=0
operator = Operator(env,WorkStation1,folded_papers)

workstation1=WorkStation1(env,paper_list,Robot,Workstation2,Operator,folded_papers)


print ("The number of produced papers is "+str(workstation1.folded_papers-1)+".")
print ("the simulation duration is "+str(env.now)+"seconds.")
env.process(paper_generator(env,workstation1,paper_list))
env.run(until=28800)
# Out:
# The number of produced papers is -1.
# the simulation duration is 0seconds.
# Operator started the process at 3seconds.
# The Paper 0 has been loaded into the robot at 5 seconds.
# Paper is loaded properly.
# The Paper 0 has been checked for loading errors at 5 seconds.
# The paper 0 has been loaded into the Folding Base at 8 seconds.
# The paper 0 has been checked for alignment at 8 seconds.
# Paper is aligned properly.
# The paper 0 has been folded at 13 seconds.
# The paper 0 has been unloaded from the Folding Base at 16 seconds.
# The paper has been checked for quality at 16seconds.
# Folded Paper passed quality check.
# The paper 0 has been handed over to the next station at 20 seconds.
# The robot has returned to the start position at 22seconds.
# Next Paper 1 arrived at Station 1 at 27 seconds.
# Operator started the process at 30seconds.
# The Paper 1 has been loaded into the robot at 32 seconds.
# Paper is loaded properly.
# The Paper 1 has been checked for loading errors at 32 seconds.
# The paper 1 has been loaded into the Folding Base at 35 seconds.
# The paper 1 has been checked for alignment at 35 seconds.
# Paper is aligned properly.
# The paper 1 has been folded at 42 seconds.
# The paper 1 has been unloaded from the Folding Base at 44 seconds.
# The paper has been checked for quality at 44seconds.
# Folded Paper passed quality check.
# The paper 1 has been handed over to the next station at 48 seconds.
# The robot has returned to the start position at 51seconds.
# Next Paper 2 arrived at Station 1 at 55 seconds.
# Operator started the process at 58seconds.
# The Paper 2 has been loaded into the robot at 60 seconds.
# Paper not loaded properly. Adjusting...
# Adjustment completed.
# The Paper 2 has been checked for loading errors at 61 seconds.
# The paper 2 has been loaded into the Folding Base at 64 seconds.
# The paper 2 has been checked for alignment at 64 seconds.
# Paper is aligned properly.
# The paper 2 has been folded at 71 seconds.
# The paper 2 has been unloaded from the Folding Base at 74 seconds.
# The paper has been checked for quality at 74seconds.
# Folded Paper passed quality check.
# The paper 2 has been handed over to the next station at 80 seconds.
# The robot has returned to the start position at 83seconds.
# Next Paper 3 arrived at Station 1 at 86 seconds.
# Operator started the process at 88seconds.
# The Paper 3 has been loaded into the robot at 90 seconds.
# Paper is loaded properly.
# The Paper 3 has been checked for loading errors at 90 seconds.
# The paper 3 has been loaded into the Folding Base at 92 seconds.
# The paper 3 has been checked for alignment at 92 seconds.
# Paper is aligned properly.
# The paper 3 has been folded at 97 seconds.
# The paper 3 has been unloaded from the Folding Base at 99 seconds.
# The paper has been checked for quality at 99seconds.
# Folded Paper passed quality check.
# The paper 3 has been handed over to the next station at 105 seconds.
# The robot has returned to the start position at 107seconds.
# Next Paper 4 arrived at Station 1 at 110 seconds.
# Operator started the process at 113seconds.
# The Paper 4 has been loaded into the robot at 116 seconds.
# Paper is loaded properly.
# The Paper 4 has been checked for loading errors at 116 seconds.
# The paper 4 has been loaded into the Folding Base at 118 seconds.
# The paper 4 has been checked for alignment at 118 seconds.
# Paper misaligned. Aligning...
# Alignment completed.
# The paper 4 has been folded at 127 seconds.
# The paper 4 has been unloaded from the Folding Base at 130 seconds.
# The paper has been checked for quality at 130seconds.
# Folded Paper passed quality check.
# The paper 4 has been handed over to the next station at 135 seconds.
# The robot has returned to the start position at 138seconds.
# Next Paper 5 arrived at Station 1 at 142 seconds.
# Operator started the process at 145seconds.
# The Paper 5 has been loaded into the robot at 147 seconds.
# Paper is loaded properly.
# The Paper 5 has been checked for loading errors at 147 seconds.
# The paper 5 has been loaded into the Folding Base at 149 seconds.
# The paper 5 has been checked for alignment at 149 seconds.
# Paper is aligned properly.
# The paper 5 has been folded at 155 seconds.
# The paper 5 has been unloaded from the Folding Base at 157 seconds.
# The paper has been checked for quality at 157seconds.
# Folded Paper passed quality check.
# The paper 5 has been handed over to the next station at 162 seconds.
# The robot has returned to the start position at 164seconds.
# Next Paper 6 arrived at Station 1 at 168 seconds.
# Operator started the process at 170seconds.
# The Paper 6 has been loaded into the robot at 172 seconds.
# Paper is loaded properly.
# The Paper 6 has been checked for loading errors at 172 seconds.
# The paper 6 has been loaded into the Folding Base at 174 seconds.
# The paper 6 has been checked for alignment at 174 seconds.
# Paper is aligned properly.
# The paper 6 has been folded at 180 seconds.
# The paper 6 has been unloaded from the Folding Base at 182 seconds.
# The paper has been checked for quality at 182seconds.
# Folded Paper passed quality check.
# The paper 6 has been handed over to the next station at 187 seconds.
# The robot has returned to the start position at 190seconds.
# Next Paper 7 arrived at Station 1 at 194 seconds.
# Operator started the process at 197seconds.
# The Paper 7 has been loaded into the robot at 200 seconds.
# Paper is loaded properly.
# The Paper 7 has been checked for loading errors at 200 seconds.
# The paper 7 has been loaded into the Folding Base at 203 seconds.
# The paper 7 has been checked for alignment at 203 seconds.
# Paper misaligned. Aligning...
# Alignment completed.
# The paper 7 has been folded at 212 seconds.
# The paper 7 has been unloaded from the Folding Base at 214 seconds.
# The paper has been checked for quality at 214seconds.
# Folded Paper passed quality check.
# The paper 7 has been handed over to the next station at 218 seconds.
# The robot has returned to the start position at 220seconds.
# Next Paper 8 arrived at Station 1 at 225 seconds.
# Operator started the process at 227seconds.
# The Paper 8 has been loaded into the robot at 229 seconds.
# Paper is loaded properly.
# The Paper 8 has been checked for loading errors at 229 seconds.
# The paper 8 has been loaded into the Folding Base at 231 seconds.
# The paper 8 has been checked for alignment at 231 seconds.
# Paper misaligned. Aligning...
# Alignment completed.
# The paper 8 has been folded at 237 seconds.
# The paper 8 has been unloaded from the Folding Base at 240 seconds.
# The paper has been checked for quality at 240seconds.
# Folded Paper passed quality check.
# The paper 8 has been handed over to the next station at 245 seconds.
# The robot has returned to the start position at 247seconds.
# Next Paper 9 arrived at Station 1 at 250 seconds.
# Operator started the process at 253seconds.
# The Paper 9 has been loaded into the robot at 255 seconds.
# Paper is loaded properly.
# The Paper 9 has been checked for loading errors at 255 seconds.
# The paper 9 has been loaded into the Folding Base at 257 seconds.
# The paper 9 has been checked for alignment at 257 seconds.
# Paper is aligned properly.
# The paper 9 has been folded at 261 seconds.
# The paper 9 has been unloaded from the Folding Base at 264 seconds.
# The paper has been checked for quality at 264seconds.
# Folded Paper passed quality check.
# The paper 9 has been handed over to the next station at 270 seconds.
# The robot has returned to the start position at 273seconds.
# Next Paper 10 arrived at Station 1 at 277 seconds.
# Operator started the process at 280seconds.
# The Paper 10 has been loaded into the robot at 283 seconds.
# Paper not loaded properly. Adjusting...
# Adjustment completed.
# The Paper 10 has been checked for loading errors at 286 seconds.
# The paper 10 has been loaded into the Folding Base at 289 seconds.
# The paper 10 has been checked for alignment at 289 seconds.
# Paper is aligned properly.
# The paper 10 has been folded at 294 seconds.
# The paper 10 has been unloaded from the Folding Base at 296 seconds.
# The paper has been checked for quality at 296seconds.
# Folded Paper passed quality check.
# The paper 10 has been handed over to the next station at 301 seconds.
# The robot has returned to the start position at 303seconds.
# Next Paper 11 arrived at Station 1 at 307 seconds.
# Operator started the process at 309seconds.
# The Paper 11 has been loaded into the robot at 312 seconds.
# Paper is loaded properly.
# The Paper 11 has been checked for loading errors at 312 seconds.
# The paper 11 has been loaded into the Folding Base at 315 seconds.
# The paper 11 has been checked for alignment at 315 seconds.
# Paper is aligned properly.
# The paper 11 has been folded at 322 seconds.
# The paper 11 has been unloaded from the Folding Base at 325 seconds.
# The paper has been checked for quality at 325seconds.
# Folded Paper passed quality check.
# The paper 11 has been handed over to the next station at 329 seconds.
# The robot has returned to the start position at 332seconds.
# Next Paper 12 arrived at Station 1 at 337 seconds.
# Operator started the process at 339seconds.
# The Paper 12 has been loaded into the robot at 341 seconds.
# Paper is loaded properly.
# The Paper 12 has been checked for loading errors at 341 seconds.
# The paper 12 has been loaded into the Folding Base at 343 seconds.
# The paper 12 has been checked for alignment at 343 seconds.
# Paper is aligned properly.
# The paper 12 has been folded at 350 seconds.
# The paper 12 has been unloaded from the Folding Base at 353 seconds.
# The paper has been checked for quality at 353seconds.
# Folded Paper passed quality check.
# The paper 12 has been handed over to the next station at 357 seconds.
# The robot has returned to the start position at 359seconds.
# Next Paper 13 arrived at Station 1 at 363 seconds.
# Operator started the process at 365seconds.
# The Paper 13 has been loaded into the robot at 368 seconds.
# Paper is loaded properly.
# The Paper 13 has been checked for loading errors at 368 seconds.
# The paper 13 has been loaded into the Folding Base at 370 seconds.
# The paper 13 has been checked for alignment at 370 seconds.
# Paper misaligned. Aligning...
# Alignment completed.
# The paper 13 has been folded at 376 seconds.
# The paper 13 has been unloaded from the Folding Base at 378 seconds.
# The paper has been checked for quality at 378seconds.
# Folded Paper passed quality check.
# The paper 13 has been handed over to the next station at 382 seconds.
# The robot has returned to the start position at 384seconds.
# Next Paper 14 arrived at Station 1 at 388 seconds.
# Operator started the process at 391seconds.
# The Paper 14 has been loaded into the robot at 394 seconds.
# Paper not loaded properly. Adjusting...
# Adjustment completed.
# The Paper 14 has been checked for loading errors at 397 seconds.
# The paper 14 has been loaded into the Folding Base at 399 seconds.
# The paper 14 has been checked for alignment at 399 seconds.
# Paper misaligned. Aligning...
# Alignment completed.
# The paper 14 has been folded at 406 seconds.
# The paper 14 has been unloaded from the Folding Base at 408 seconds.
# The paper has been checked for quality at 408seconds.
# Folded Paper passed quality check.
# The paper 14 has been handed over to the next station at 413 seconds.
# The robot has returned to the start position at 415seconds.
# Next Paper 15 arrived at Station 1 at 420 seconds.
# Operator started the process at 423seconds.
# The Paper 15 has been loaded into the robot at 426 seconds.
# Paper not loaded properly. Adjusting...
# Adjustment completed.
# The Paper 15 has been checked for loading errors at 427 seconds.
# The paper 15 has been loaded into the Folding Base at 430 seconds.
# The paper 15 has been checked for alignment at 430 seconds.
# Paper is aligned properly.
# The paper 15 has been folded at 436 seconds.
# The paper 15 has been unloaded from the Folding Base at 439 seconds.
# The paper has been checked for quality at 439seconds.
# Folded Paper passed quality check.
# The paper 15 has been handed over to the next station at 444 seconds.
# The robot has returned to the start position at 447seconds.
# Next Paper 16 arrived at Station 1 at 450 seconds.
# Operator started the process at 452seconds.
# The Paper 16 has been loaded into the robot at 454 seconds.
# Paper is loaded properly.
# The Paper 16 has been checked for loading errors at 454 seconds.
# The paper 16 has been loaded into the Folding Base at 456 seconds.
# The paper 16 has been checked for alignment at 456 seconds.
# Paper is aligned properly.
# The paper 16 has been folded at 461 seconds.
# The paper 16 has been unloaded from the Folding Base at 464 seconds.
# The paper has been checked for quality at 464seconds.
# Folded Paper passed quality check.
# The paper 16 has been handed over to the next station at 468 seconds.
# The robot has returned to the start position at 471seconds.
# Next Paper 17 arrived at Station 1 at 475 seconds.
# Operator started the process at 477seconds.
# The Paper 17 has been loaded into the robot at 480 seconds.
# Paper is loaded properly.
# The Paper 17 has been checked for loading errors at 480 seconds.
# The paper 17 has been loaded into the Folding Base at 482 seconds.
# The paper 17 has been checked for alignment at 482 seconds.
# Paper misaligned. Aligning...
# Alignment completed.
# The paper 17 has been folded at 490 seconds.
# The paper 17 has been unloaded from the Folding Base at 493 seconds.
# The paper has been checked for quality at 493seconds.
# Folded Paper passed quality check.
# The paper 17 has been handed over to the next station at 498 seconds.
# The robot has returned to the start position at 501seconds.
# Next Paper 18 arrived at Station 1 at 505 seconds.
# Operator started the process at 508seconds.
# The Paper 18 has been loaded into the robot at 511 seconds.
# Paper is loaded properly.
# The Paper 18 has been checked for loading errors at 511 seconds.
# The paper 18 has been loaded into the Folding Base at 513 seconds.
# The paper 18 has been checked for alignment at 513 seconds.
# Paper is aligned properly.
# The paper 18 has been folded at 519 seconds.
# The paper 18 has been unloaded from the Folding Base at 522 seconds.
# The paper has been checked for quality at 522seconds.
# Folded Paper passed quality check.
# The paper 18 has been handed over to the next station at 527 seconds.
# The robot has returned to the start position at 529seconds.
# Next Paper 19 arrived at Station 1 at 534 seconds.
# Operator started the process at 536seconds.
# The Paper 19 has been loaded into the robot at 538 seconds.
# Paper is loaded properly.
# The Paper 19 has been checked for loading errors at 538 seconds.
# The paper 19 has been loaded into the Folding Base at 540 seconds.
# The paper 19 has been checked for alignment at 540 seconds.
# Paper is aligned properly.
# The paper 19 has been folded at 547 seconds.
# The paper 19 has been unloaded from the Folding Base at 549 seconds.
# The paper has been checked for quality at 549seconds.
# Folded Paper passed quality check.
# The paper 19 has been handed over to the next station at 554 seconds.
# The robot has returned to the start position at 556seconds.
# Next Paper 20 arrived at Station 1 at 558 seconds.
# Operator started the process at 561seconds.
# The Paper 20 has been loaded into the robot at 563 seconds.
# Paper is loaded properly.
# The Paper 20 has been checked for loading errors at 563 seconds.
# The paper 20 has been loaded into the Folding Base at 566 seconds.
# The paper 20 has been checked for alignment at 566 seconds.
# Paper misaligned. Aligning...
# Alignment completed.
# The paper 20 has been folded at 574 seconds.
# The paper 20 has been unloaded from the Folding Base at 576 seconds.
# The paper has been checked for quality at 576seconds.
# Folded Paper passed quality check.
# The paper 20 has been handed over to the next station at 582 seconds.
# The robot has returned to the start position at 585seconds.
# Next Paper 21 arrived at Station 1 at 589 seconds.
# Operator started the process at 592seconds.
# The Paper 21 has been loaded into the robot at 595 seconds.
# Paper is loaded properly.
# The Paper 21 has been checked for loading errors at 595 seconds.
# The paper 21 has been loaded into the Folding Base at 598 seconds.
# The paper 21 has been checked for alignment at 598 seconds.
# Paper is aligned properly.
# The paper 21 has been folded at 603 seconds.
# The paper 21 has been unloaded from the Folding Base at 606 seconds.
# The paper has been checked for quality at 606seconds.
# Folded Paper passed quality check.
# The paper 21 has been handed over to the next station at 612 seconds.
# The robot has returned to the start position at 614seconds.
# Next Paper 22 arrived at Station 1 at 619 seconds.
# Operator started the process at 622seconds.
# The Paper 22 has been loaded into the robot at 624 seconds.
# Paper is loaded properly.
# The Paper 22 has been checked for loading errors at 624 seconds.
# The paper 22 has been loaded into the Folding Base at 627 seconds.
# The paper 22 has been checked for alignment at 627 seconds.
# Paper is aligned properly.
# The paper 22 has been folded at 632 seconds.
# The paper 22 has been unloaded from the Folding Base at 635 seconds.
# The paper has been checked for quality at 635seconds.
# Folded Paper has a defect and goes to waste.
# Paper has been disposed of as waste.
# Operator started the process at 643seconds.
# The Paper 22 has been loaded into the robot at 646 seconds.
# Paper is loaded properly.
# The Paper 22 has been checked for loading errors at 646 seconds.
# The paper 22 has been loaded into the Folding Base at 649 seconds.
# The paper 22 has been checked for alignment at 649 seconds.
# Paper is aligned properly.
# The paper 22 has been folded at 655 seconds.
# The paper 22 has been unloaded from the Folding Base at 657 seconds.
# The paper has been checked for quality at 657seconds.
# Folded Paper passed quality check.
# The paper 22 has been handed over to the next station at 663 seconds.
# The robot has returned to the start position at 666seconds.
# The paper 23 has been handed over to the next station at 668 seconds.
# The robot has returned to the start position at 671seconds.
# Next Paper 24 arrived at Station 1 at 676 seconds.
# Operator started the process at 678seconds.
# The Paper 24 has been loaded into the robot at 681 seconds.
# Paper not loaded properly. Adjusting...
# Adjustment completed.
# The Paper 24 has been checked for loading errors at 684 seconds.
# The paper 24 has been loaded into the Folding Base at 686 seconds.
# The paper 24 has been checked for alignment at 686 seconds.
# Paper is aligned properly.
# The paper 24 has been folded at 693 seconds.
# The paper 24 has been unloaded from the Folding Base at 696 seconds.
# The paper has been checked for quality at 696seconds.
# Folded Paper passed quality check.
# The paper 24 has been handed over to the next station at 701 seconds.
# The robot has returned to the start position at 703seconds.
# Next Paper 25 arrived at Station 1 at 706 seconds.
# Operator started the process at 708seconds.
# The Paper 25 has been loaded into the robot at 710 seconds.
# Paper is loaded properly.
# The Paper 25 has been checked for loading errors at 710 seconds.
# The paper 25 has been loaded into the Folding Base at 713 seconds.
# The paper 25 has been checked for alignment at 713 seconds.
# Paper is aligned properly.
# The paper 25 has been folded at 718 seconds.
# The paper 25 has been unloaded from the Folding Base at 721 seconds.
# The paper has been checked for quality at 721seconds.
# Folded Paper passed quality check.
# The paper 25 has been handed over to the next station at 726 seconds.
# The robot has returned to the start position at 729seconds.
# Next Paper 26 arrived at Station 1 at 733 seconds.
# Operator started the process at 736seconds.
# The Paper 26 has been loaded into the robot at 739 seconds.
# Paper is loaded properly.
# The Paper 26 has been checked for loading errors at 739 seconds.
# The paper 26 has been loaded into the Folding Base at 741 seconds.
# The paper 26 has been checked for alignment at 741 seconds.
# Paper is aligned properly.
# The paper 26 has been folded at 748 seconds.
# The paper 26 has been unloaded from the Folding Base at 750 seconds.
# The paper has been checked for quality at 750seconds.
# Folded Paper passed quality check.
# The paper 26 has been handed over to the next station at 754 seconds.
# The robot has returned to the start position at 756seconds.
# Next Paper 27 arrived at Station 1 at 758 seconds.
# Operator started the process at 761seconds.
# The Paper 27 has been loaded into the robot at 764 seconds.
# Paper not loaded properly. Adjusting...
# Adjustment completed.
# The Paper 27 has been checked for loading errors at 766 seconds.
# The paper 27 has been loaded into the Folding Base at 768 seconds.
# The paper 27 has been checked for alignment at 768 seconds.
# Paper is aligned properly.
# The paper 27 has been folded at 773 seconds.
# The paper 27 has been unloaded from the Folding Base at 776 seconds.
# The paper has been checked for quality at 776seconds.
# Folded Paper passed quality check.
# The paper 27 has been handed over to the next station at 781 seconds.
# The robot has returned to the start position at 784seconds.
# Next Paper 28 arrived at Station 1 at 786 seconds.
# Operator started the process at 789seconds.
# The Paper 28 has been loaded into the robot at 792 seconds.
# Paper is loaded properly.
# The Paper 28 has been checked for loading errors at 792 seconds.
# The paper 28 has been loaded into the Folding Base at 795 seconds.
# The paper 28 has been checked for alignment at 795 seconds.
# Paper misaligned. Aligning...
# Alignment completed.
# The paper 28 has been folded at 803 seconds.
# The paper 28 has been unloaded from the Folding Base at 806 seconds.
# The paper has been checked for quality at 806seconds.
# Folded Paper passed quality check.
# The paper 28 has been handed over to the next station at 810 seconds.
# The robot has returned to the start position at 812seconds.
# Next Paper 29 arrived at Station 1 at 816 seconds.
# Operator started the process at 818seconds.
# The Paper 29 has been loaded into the robot at 820 seconds.
# Paper is loaded properly.
# The Paper 29 has been checked for loading errors at 820 seconds.
# The paper 29 has been loaded into the Folding Base at 823 seconds.
# The paper 29 has been checked for alignment at 823 seconds.
# Paper is aligned properly.
# The paper 29 has been folded at 829 seconds.
# The paper 29 has been unloaded from the Folding Base at 832 seconds.
# The paper has been checked for quality at 832seconds.
# Folded Paper passed quality check.
# The paper 29 has been handed over to the next station at 838 seconds.
# The robot has returned to the start position at 840seconds.
# Next Paper 30 arrived at Station 1 at 843 seconds.
# Operator started the process at 846seconds.
# The Paper 30 has been loaded into the robot at 848 seconds.
# Paper is loaded properly.
# The Paper 30 has been checked for loading errors at 848 seconds.
# The paper 30 has been loaded into the Folding Base at 851 seconds.
# The paper 30 has been checked for alignment at 851 seconds.
# Paper is aligned properly.
# The paper 30 has been folded at 856 seconds.
# The paper 30 has been unloaded from the Folding Base at 858 seconds.
# The paper has been checked for quality at 858seconds.
# Folded Paper passed quality check.
# The paper 30 has been handed over to the next station at 863 seconds.
# The robot has returned to the start position at 866seconds.
# Next Paper 31 arrived at Station 1 at 871 seconds.
# Operator started the process at 873seconds.
# The Paper 31 has been loaded into the robot at 875 seconds.
# Paper is loaded properly.
# The Paper 31 has been checked for loading errors at 875 seconds.
# The paper 31 has been loaded into the Folding Base at 878 seconds.
# The paper 31 has been checked for alignment at 878 seconds.
# Paper misaligned. Aligning...
# Alignment completed.
# The paper 31 has been folded at 887 seconds.
# The paper 31 has been unloaded from the Folding Base at 890 seconds.
# The paper has been checked for quality at 890seconds.
# Folded Paper passed quality check.
# The paper 31 has been handed over to the next station at 895 seconds.
# The robot has returned to the start position at 897seconds.
# Next Paper 32 arrived at Station 1 at 900 seconds.
# Operator started the process at 902seconds.
# The Paper 32 has been loaded into the robot at 905 seconds.
# Paper not loaded properly. Adjusting...
# Adjustment completed.
# The Paper 32 has been checked for loading errors at 908 seconds.
# The paper 32 has been loaded into the Folding Base at 911 seconds.
# The paper 32 has been checked for alignment at 911 seconds.
# Paper is aligned properly.
# The paper 32 has been folded at 917 seconds.
# The paper 32 has been unloaded from the Folding Base at 920 seconds.
# The paper has been checked for quality at 920seconds.
# Folded Paper passed quality check.
# The paper 32 has been handed over to the next station at 925 seconds.
# The robot has returned to the start position at 928seconds.
# Next Paper 33 arrived at Station 1 at 933 seconds.
# Operator started the process at 935seconds.
# The Paper 33 has been loaded into the robot at 937 seconds.
# Paper is loaded properly.
# The Paper 33 has been checked for loading errors at 937 seconds.
# The paper 33 has been loaded into the Folding Base at 940 seconds.
# The paper 33 has been checked for alignment at 940 seconds.
# Paper is aligned properly.
# The paper 33 has been folded at 945 seconds.
# The paper 33 has been unloaded from the Folding Base at 948 seconds.
# The paper has been checked for quality at 948seconds.
# Folded Paper passed quality check.
# The paper 33 has been handed over to the next station at 953 seconds.
# The robot has returned to the start position at 956seconds.
# Next Paper 34 arrived at Station 1 at 961 seconds.
# Operator started the process at 963seconds.
# The Paper 34 has been loaded into the robot at 965 seconds.
# Paper is loaded properly.
# The Paper 34 has been checked for loading errors at 965 seconds.
# The paper 34 has been loaded into the Folding Base at 968 seconds.
# The paper 34 has been checked for alignment at 968 seconds.
# Paper is aligned properly.
# The paper 34 has been folded at 975 seconds.
# The paper 34 has been unloaded from the Folding Base at 977 seconds.
# The paper has been checked for quality at 977seconds.
# Folded Paper passed quality check.
# The paper 34 has been handed over to the next station at 982 seconds.
# The robot has returned to the start position at 984seconds.
# Next Paper 35 arrived at Station 1 at 989 seconds.
# Operator started the process at 991seconds.
# The Paper 35 has been loaded into the robot at 993 seconds.
# Paper is loaded properly.
# The Paper 35 has been checked for loading errors at 993 seconds.
# The paper 35 has been loaded into the Folding Base at 996 seconds.
# The paper 35 has been checked for alignment at 996 seconds.
# Paper is aligned properly.
# The paper 35 has been folded at 1001 seconds.
# The paper 35 has been unloaded from the Folding Base at 1004 seconds.
# The paper has been checked for quality at 1004seconds.
# Folded Paper passed quality check.
# The paper 35 has been handed over to the next station at 1009 seconds.
# The robot has returned to the start position at 1012seconds.
# Next Paper 36 arrived at Station 1 at 1016 seconds.
# Operator started the process at 1018seconds.
# The Paper 36 has been loaded into the robot at 1020 seconds.
# Paper is loaded properly.
# The Paper 36 has been checked for loading errors at 1020 seconds.
# The paper 36 has been loaded into the Folding Base at 1022 seconds.
# The paper 36 has been checked for alignment at 1022 seconds.
# Paper is aligned properly.
# The paper 36 has been folded at 1026 seconds.
# The paper 36 has been unloaded from the Folding Base at 1029 seconds.
# The paper has been checked for quality at 1029seconds.
# Folded Paper has a defect and goes to waste.
# Paper has been disposed of as waste.
# Operator started the process at 1037seconds.
# The Paper 36 has been loaded into the robot at 1040 seconds.
# Paper is loaded properly.
# The Paper 36 has been checked for loading errors at 1040 seconds.
# The paper 36 has been loaded into the Folding Base at 1042 seconds.
# The paper 36 has been checked for alignment at 1042 seconds.
# Paper misaligned. Aligning...
# Alignment completed.
# The paper 36 has been folded at 1051 seconds.
# The paper 36 has been unloaded from the Folding Base at 1054 seconds.
# The paper has been checked for quality at 1054seconds.
# Folded Paper passed quality check.
# The paper 36 has been handed over to the next station at 1060 seconds.
# The robot has returned to the start position at 1063seconds.
# The paper 37 has been handed over to the next station at 1065 seconds.
# The robot has returned to the start position at 1068seconds.
# Next Paper 38 arrived at Station 1 at 1071 seconds.
# Operator started the process at 1073seconds.
# The Paper 38 has been loaded into the robot at 1076 seconds.
# Paper not loaded properly. Adjusting...
# Adjustment completed.
# The Paper 38 has been checked for loading errors at 1079 seconds.
# The paper 38 has been loaded into the Folding Base at 1081 seconds.
# The paper 38 has been checked for alignment at 1081 seconds.
# Paper is aligned properly.
# The paper 38 has been folded at 1087 seconds.
# The paper 38 has been unloaded from the Folding Base at 1090 seconds.
# The paper has been checked for quality at 1090seconds.
# Folded Paper passed quality check.
# The paper 38 has been handed over to the next station at 1094 seconds.
# The robot has returned to the start position at 1096seconds.
# Next Paper 39 arrived at Station 1 at 1100 seconds.
# Operator started the process at 1102seconds.
# The Paper 39 has been loaded into the robot at 1104 seconds.
# Paper not loaded properly. Adjusting...
# Adjustment completed.
# The Paper 39 has been checked for loading errors at 1107 seconds.
# The paper 39 has been loaded into the Folding Base at 1110 seconds.
# The paper 39 has been checked for alignment at 1110 seconds.
# Paper is aligned properly.
# The paper 39 has been folded at 1114 seconds.
# The paper 39 has been unloaded from the Folding Base at 1116 seconds.
# The paper has been checked for quality at 1116seconds.
# Folded Paper passed quality check.
# The paper 39 has been handed over to the next station at 1121 seconds.
# The robot has returned to the start position at 1124seconds.
# Next Paper 40 arrived at Station 1 at 1127 seconds.
# Operator started the process at 1129seconds.
# The Paper 40 has been loaded into the robot at 1132 seconds.
# Paper not loaded properly. Adjusting...
# Adjustment completed.
# The Paper 40 has been checked for loading errors at 1133 seconds.
# The paper 40 has been loaded into the Folding Base at 1135 seconds.
# The paper 40 has been checked for alignment at 1135 seconds.
# Paper is aligned properly.
# The paper 40 has been folded at 1142 seconds.
# The paper 40 has been unloaded from the Folding Base at 1145 seconds.
# The paper has been checked for quality at 1145seconds.
# Folded Paper passed quality check.
# The paper 40 has been handed over to the next station at 1150 seconds.
# The robot has returned to the start position at 1152seconds.
# Next Paper 41 arrived at Station 1 at 1157 seconds.
# Operator started the process at 1159seconds.
# The Paper 41 has been loaded into the robot at 1162 seconds.
# Paper not loaded properly. Adjusting...
# Adjustment completed.
# The Paper 41 has been checked for loading errors at 1164 seconds.
# The paper 41 has been loaded into the Folding Base at 1166 seconds.
# The paper 41 has been checked for alignment at 1166 seconds.
# Paper is aligned properly.
# The paper 41 has been folded at 1172 seconds.
# The paper 41 has been unloaded from the Folding Base at 1175 seconds.
# The paper has been checked for quality at 1175seconds.
# Folded Paper passed quality check.
# The paper 41 has been handed over to the next station at 1180 seconds.
# The robot has returned to the start position at 1182seconds.
# Next Paper 42 arrived at Station 1 at 1187 seconds.
# Operator started the process at 1190seconds.
# The Paper 42 has been loaded into the robot at 1193 seconds.
# Paper not loaded properly. Adjusting...
# Adjustment completed.
# The Paper 42 has been checked for loading errors at 1194 seconds.
# The paper 42 has been loaded into the Folding Base at 1196 seconds.
# The paper 42 has been checked for alignment at 1196 seconds.
# Paper misaligned. Aligning...
# Alignment completed.
# The paper 42 has been folded at 1203 seconds.
# The paper 42 has been unloaded from the Folding Base at 1205 seconds.
# The paper has been checked for quality at 1205seconds.
# Folded Paper passed quality check.
# The paper 42 has been handed over to the next station at 1211 seconds.
# The robot has returned to the start position at 1213seconds.
# Next Paper 43 arrived at Station 1 at 1216 seconds.
# Operator started the process at 1218seconds.
# The Paper 43 has been loaded into the robot at 1220 seconds.
# Paper is loaded properly.
# The Paper 43 has been checked for loading errors at 1220 seconds.
# The paper 43 has been loaded into the Folding Base at 1223 seconds.
# The paper 43 has been checked for alignment at 1223 seconds.
# Paper is aligned properly.
# The paper 43 has been folded at 1228 seconds.
# The paper 43 has been unloaded from the Folding Base at 1231 seconds.
# The paper has been checked for quality at 1231seconds.
# Folded Paper passed quality check.
# The paper 43 has been handed over to the next station at 1235 seconds.
# The robot has returned to the start position at 1237seconds.
# Next Paper 44 arrived at Station 1 at 1241 seconds.
# Operator started the process at 1243seconds.
# The Paper 44 has been loaded into the robot at 1246 seconds.
# Paper is loaded properly.
# The Paper 44 has been checked for loading errors at 1246 seconds.
# The paper 44 has been loaded into the Folding Base at 1249 seconds.
# The paper 44 has been checked for alignment at 1249 seconds.
# Paper is aligned properly.
# The paper 44 has been folded at 1254 seconds.
# The paper 44 has been unloaded from the Folding Base at 1256 seconds.
# The paper has been checked for quality at 1256seconds.
# Folded Paper passed quality check.
# The paper 44 has been handed over to the next station at 1260 seconds.
# The robot has returned to the start position at 1262seconds.
# Next Paper 45 arrived at Station 1 at 1266 seconds.
# Operator started the process at 1269seconds.
# The Paper 45 has been loaded into the robot at 1271 seconds.
# Paper is loaded properly.
# The Paper 45 has been checked for loading errors at 1271 seconds.
# The paper 45 has been loaded into the Folding Base at 1274 seconds.
# The paper 45 has been checked for alignment at 1274 seconds.
# Paper is aligned properly.
# The paper 45 has been folded at 1279 seconds.
# The paper 45 has been unloaded from the Folding Base at 1281 seconds.
# The paper has been checked for quality at 1281seconds.
# Folded Paper passed quality check.
# The paper 45 has been handed over to the next station at 1287 seconds.
# The robot has returned to the start position at 1290seconds.
# Next Paper 46 arrived at Station 1 at 1293 seconds.
# Operator started the process at 1295seconds.
# The Paper 46 has been loaded into the robot at 1298 seconds.
# Paper is loaded properly.
# The Paper 46 has been checked for loading errors at 1298 seconds.
# The paper 46 has been loaded into the Folding Base at 1300 seconds.
# The paper 46 has been checked for alignment at 1300 seconds.
# Paper is aligned properly.
# The paper 46 has been folded at 1304 seconds.
# The paper 46 has been unloaded from the Folding Base at 1307 seconds.
# The paper has been checked for quality at 1307seconds.
# Folded Paper passed quality check.
# The paper 46 has been handed over to the next station at 1313 seconds.
# The robot has returned to the start position at 1316seconds.
# Next Paper 47 arrived at Station 1 at 1321 seconds.
# Operator started the process at 1324seconds.
# The Paper 47 has been loaded into the robot at 1327 seconds.
# Paper not loaded properly. Adjusting...
# Adjustment completed.
# The Paper 47 has been checked for loading errors at 1329 seconds.
# The paper 47 has been loaded into the Folding Base at 1332 seconds.
# The paper 47 has been checked for alignment at 1332 seconds.
# Paper is aligned properly.
# The paper 47 has been folded at 1337 seconds.
# The paper 47 has been unloaded from the Folding Base at 1340 seconds.
# The paper has been checked for quality at 1340seconds.
# Folded Paper passed quality check.
# The paper 47 has been handed over to the next station at 1345 seconds.
# The robot has returned to the start position at 1347seconds.
# Next Paper 48 arrived at Station 1 at 1352 seconds.
# Operator started the process at 1355seconds.
# The Paper 48 has been loaded into the robot at 1357 seconds.
# Paper not loaded properly. Adjusting...
# Adjustment completed.
# The Paper 48 has been checked for loading errors at 1360 seconds.
# The paper 48 has been loaded into the Folding Base at 1363 seconds.
# The paper 48 has been checked for alignment at 1363 seconds.
# Paper misaligned. Aligning...
# Alignment completed.
# The paper 48 has been folded at 1371 seconds.
# The paper 48 has been unloaded from the Folding Base at 1373 seconds.
# The paper has been checked for quality at 1373seconds.
# Folded Paper has a defect and goes to waste.
# Paper has been disposed of as waste.
# Operator started the process at 1380seconds.
# The Paper 48 has been loaded into the robot at 1383 seconds.
# Paper is loaded properly.
# The Paper 48 has been checked for loading errors at 1383 seconds.
# The paper 48 has been loaded into the Folding Base at 1386 seconds.
# The paper 48 has been checked for alignment at 1386 seconds.
# Paper is aligned properly.
# The paper 48 has been folded at 1391 seconds.
# The paper 48 has been unloaded from the Folding Base at 1394 seconds.
# The paper has been checked for quality at 1394seconds.
# Folded Paper passed quality check.
# The paper 48 has been handed over to the next station at 1399 seconds.
# The robot has returned to the start position at 1402seconds.
# The paper 49 has been handed over to the next station at 1405 seconds.
# The robot has returned to the start position at 1407seconds.
# Next Paper 50 arrived at Station 1 at 1409 seconds.
# Operator started the process at 1412seconds.
# The Paper 50 has been loaded into the robot at 1415 seconds.
# Paper not loaded properly. Adjusting...
# Adjustment completed.
# The Paper 50 has been checked for loading errors at 1418 seconds.
# The paper 50 has been loaded into the Folding Base at 1421 seconds.
# The paper 50 has been checked for alignment at 1421 seconds.
# Paper is aligned properly.
# The paper 50 has been folded at 1426 seconds.
# The paper 50 has been unloaded from the Folding Base at 1429 seconds.
# The paper has been checked for quality at 1429seconds.
# Folded Paper passed quality check.
# The paper 50 has been handed over to the next station at 1434 seconds.
# The robot has returned to the start position at 1437seconds.
# Next Paper 51 arrived at Station 1 at 1442 seconds.
# Operator started the process at 1445seconds.
# The Paper 51 has been loaded into the robot at 1448 seconds.
# Paper is loaded properly.
# The Paper 51 has been checked for loading errors at 1448 seconds.
# The paper 51 has been loaded into the Folding Base at 1451 seconds.
# The paper 51 has been checked for alignment at 1451 seconds.
# Paper is aligned properly.
# The paper 51 has been folded at 1455 seconds.
# The paper 51 has been unloaded from the Folding Base at 1457 seconds.
# The paper has been checked for quality at 1457seconds.
# Folded Paper passed quality check.
# The paper 51 has been handed over to the next station at 1462 seconds.
# The robot has returned to the start position at 1465seconds.
# Next Paper 52 arrived at Station 1 at 1467 seconds.
# Operator started the process at 1469seconds.
# The Paper 52 has been loaded into the robot at 1472 seconds.
# Paper is loaded properly.
# The Paper 52 has been checked for loading errors at 1472 seconds.
# The paper 52 has been loaded into the Folding Base at 1475 seconds.
# The paper 52 has been checked for alignment at 1475 seconds.
# Paper is aligned properly.
# The paper 52 has been folded at 1481 seconds.
# The paper 52 has been unloaded from the Folding Base at 1483 seconds.
# The paper has been checked for quality at 1483seconds.
# Folded Paper passed quality check.
# The paper 52 has been handed over to the next station at 1489 seconds.
# The robot has returned to the start position at 1491seconds.
# Next Paper 53 arrived at Station 1 at 1493 seconds.
# Operator started the process at 1496seconds.
# The Paper 53 has been loaded into the robot at 1499 seconds.
# Paper is loaded properly.
# The Paper 53 has been checked for loading errors at 1499 seconds.
# The paper 53 has been loaded into the Folding Base at 1502 seconds.
# The paper 53 has been checked for alignment at 1502 seconds.
# Paper is aligned properly.
# The paper 53 has been folded at 1506 seconds.
# The paper 53 has been unloaded from the Folding Base at 1508 seconds.
# The paper has been checked for quality at 1508seconds.
# Folded Paper passed quality check.
# The paper 53 has been handed over to the next station at 1513 seconds.
# The robot has returned to the start position at 1515seconds.
# Next Paper 54 arrived at Station 1 at 1517 seconds.
# Operator started the process at 1519seconds.
# The Paper 54 has been loaded into the robot at 1521 seconds.
# Paper is loaded properly.
# The Paper 54 has been checked for loading errors at 1521 seconds.
# The paper 54 has been loaded into the Folding Base at 1524 seconds.
# The paper 54 has been checked for alignment at 1524 seconds.
# Paper is aligned properly.
# The paper 54 has been folded at 1531 seconds.
# The paper 54 has been unloaded from the Folding Base at 1533 seconds.
# The paper has been checked for quality at 1533seconds.
# Folded Paper passed quality check.
# The paper 54 has been handed over to the next station at 1537 seconds.
# The robot has returned to the start position at 1539seconds.
# Next Paper 55 arrived at Station 1 at 1544 seconds.
# Operator started the process at 1547seconds.
# The Paper 55 has been loaded into the robot at 1550 seconds.
# Paper is loaded properly.
# The Paper 55 has been checked for loading errors at 1550 seconds.
# The paper 55 has been loaded into the Folding Base at 1553 seconds.
# The paper 55 has been checked for alignment at 1553 seconds.
# Paper misaligned. Aligning...
# Alignment completed.
# The paper 55 has been folded at 1562 seconds.
# The paper 55 has been unloaded from the Folding Base at 1564 seconds.
# The paper has been checked for quality at 1564seconds.
# Folded Paper passed quality check.
# The paper 55 has been handed over to the next station at 1569 seconds.
# The robot has returned to the start position at 1571seconds.
# Next Paper 56 arrived at Station 1 at 1573 seconds.
# Operator started the process at 1575seconds.
# The Paper 56 has been loaded into the robot at 1578 seconds.
# Paper not loaded properly. Adjusting...
# Adjustment completed.
# The Paper 56 has been checked for loading errors at 1579 seconds.
# The paper 56 has been loaded into the Folding Base at 1581 seconds.
# The paper 56 has been checked for alignment at 1581 seconds.
# Paper is aligned properly.
# The paper 56 has been folded at 1586 seconds.
# The paper 56 has been unloaded from the Folding Base at 1589 seconds.
# The paper has been checked for quality at 1589seconds.
# Folded Paper passed quality check.
# The paper 56 has been handed over to the next station at 1594 seconds.
# The robot has returned to the start position at 1596seconds.
# Next Paper 57 arrived at Station 1 at 1601 seconds.
# Operator started the process at 1604seconds.
# The Paper 57 has been loaded into the robot at 1607 seconds.
# Paper is loaded properly.
# The Paper 57 has been checked for loading errors at 1607 seconds.
# The paper 57 has been loaded into the Folding Base at 1609 seconds.
# The paper 57 has been checked for alignment at 1609 seconds.
# Paper is aligned properly.
# The paper 57 has been folded at 1614 seconds.
# The paper 57 has been unloaded from the Folding Base at 1616 seconds.
# The paper has been checked for quality at 1616seconds.
# Folded Paper passed quality check.
# The paper 57 has been handed over to the next station at 1622 seconds.
# The robot has returned to the start position at 1624seconds.
# Next Paper 58 arrived at Station 1 at 1626 seconds.
# Operator started the process at 1629seconds.
# The Paper 58 has been loaded into the robot at 1632 seconds.
# Paper is loaded properly.
# The Paper 58 has been checked for loading errors at 1632 seconds.
# The paper 58 has been loaded into the Folding Base at 1634 seconds.
# The paper 58 has been checked for alignment at 1634 seconds.
# Paper is aligned properly.
# The paper 58 has been folded at 1640 seconds.
# The paper 58 has been unloaded from the Folding Base at 1643 seconds.
# The paper has been checked for quality at 1643seconds.
# Folded Paper passed quality check.
# The paper 58 has been handed over to the next station at 1649 seconds.
# The robot has returned to the start position at 1652seconds.
# Next Paper 59 arrived at Station 1 at 1655 seconds.
# Operator started the process at 1657seconds.
# The Paper 59 has been loaded into the robot at 1660 seconds.
# Paper is loaded properly.
# The Paper 59 has been checked for loading errors at 1660 seconds.
# The paper 59 has been loaded into the Folding Base at 1662 seconds.
# The paper 59 has been checked for alignment at 1662 seconds.
# Paper is aligned properly.
# The paper 59 has been folded at 1668 seconds.
# The paper 59 has been unloaded from the Folding Base at 1671 seconds.
# The paper has been checked for quality at 1671seconds.
# Folded Paper passed quality check.
# The paper 59 has been handed over to the next station at 1676 seconds.
# The robot has returned to the start position at 1678seconds.
# Next Paper 60 arrived at Station 1 at 1681 seconds.
# Operator started the process at 1683seconds.
# The Paper 60 has been loaded into the robot at 1685 seconds.
# Paper is loaded properly.
# The Paper 60 has been checked for loading errors at 1685 seconds.
# The paper 60 has been loaded into the Folding Base at 1688 seconds.
# The paper 60 has been checked for alignment at 1688 seconds.
# Paper is aligned properly.
# The paper 60 has been folded at 1695 seconds.
# The paper 60 has been unloaded from the Folding Base at 1697 seconds.
# The paper has been checked for quality at 1697seconds.
# Folded Paper passed quality check.
# The paper 60 has been handed over to the next station at 1703 seconds.
# The robot has returned to the start position at 1706seconds.
# Next Paper 61 arrived at Station 1 at 1711 seconds.
# Operator started the process at 1713seconds.
# The Paper 61 has been loaded into the robot at 1716 seconds.
# Paper is loaded properly.
# The Paper 61 has been checked for loading errors at 1716 seconds.
# The paper 61 has been loaded into the Folding Base at 1719 seconds.
# The paper 61 has been checked for alignment at 1719 seconds.
# Paper is aligned properly.
# The paper 61 has been folded at 1725 seconds.
# The paper 61 has been unloaded from the Folding Base at 1728 seconds.
# The paper has been checked for quality at 1728seconds.
# Folded Paper passed quality check.
# The paper 61 has been handed over to the next station at 1733 seconds.
# The robot has returned to the start position at 1736seconds.
# Next Paper 62 arrived at Station 1 at 1741 seconds.
# Operator started the process at 1743seconds.
# The Paper 62 has been loaded into the robot at 1745 seconds.
# Paper is loaded properly.
# The Paper 62 has been checked for loading errors at 1745 seconds.
# The paper 62 has been loaded into the Folding Base at 1747 seconds.
# The paper 62 has been checked for alignment at 1747 seconds.
# Paper is aligned properly.
# The paper 62 has been folded at 1752 seconds.
# The paper 62 has been unloaded from the Folding Base at 1754 seconds.
# The paper has been checked for quality at 1754seconds.
# Folded Paper passed quality check.
# The paper 62 has been handed over to the next station at 1758 seconds.
# The robot has returned to the start position at 1760seconds.
# Next Paper 63 arrived at Station 1 at 1763 seconds.
# Operator started the process at 1765seconds.
# The Paper 63 has been loaded into the robot at 1768 seconds.
# Paper is loaded properly.
# The Paper 63 has been checked for loading errors at 1768 seconds.
# The paper 63 has been loaded into the Folding Base at 1770 seconds.
# The paper 63 has been checked for alignment at 1770 seconds.
# Paper is aligned properly.
# The paper 63 has been folded at 1777 seconds.
# The paper 63 has been unloaded from the Folding Base at 1780 seconds.
# The paper has been checked for quality at 1780seconds.
# Folded Paper passed quality check.
# The paper 63 has been handed over to the next station at 1785 seconds.
# The robot has returned to the start position at 1788seconds.
# ...
# The paper 1021 has been unloaded from the Folding Base at 28245 seconds.
# The paper has been checked for quality at 28245seconds.
# Folded Paper passed quality check.
# The paper 1021 has been handed over to the next station at 28250 seconds.
# The robot has returned to the start position at 28253seconds.
# Next Paper 1022 arrived at Station 1 at 28255 seconds.
# Operator started the process at 28258seconds.
# The Paper 1022 has been loaded into the robot at 28260 seconds.
# Paper is loaded properly.
# The Paper 1022 has been checked for loading errors at 28260 seconds.
# The paper 1022 has been loaded into the Folding Base at 28263 seconds.
# The paper 1022 has been checked for alignment at 28263 seconds.
# Paper is aligned properly.
# The paper 1022 has been folded at 28267 seconds.
# The paper 1022 has been unloaded from the Folding Base at 28269 seconds.
# The paper has been checked for quality at 28269seconds.
# Folded Paper passed quality check.
# The paper 1022 has been handed over to the next station at 28274 seconds.
# The robot has returned to the start position at 28277seconds.
# Next Paper 1023 arrived at Station 1 at 28281 seconds.
# Operator started the process at 28284seconds.
# The Paper 1023 has been loaded into the robot at 28286 seconds.
# Paper not loaded properly. Adjusting...
# Adjustment completed.
# The Paper 1023 has been checked for loading errors at 28289 seconds.
# The paper 1023 has been loaded into the Folding Base at 28292 seconds.
# The paper 1023 has been checked for alignment at 28292 seconds.
# Paper misaligned. Aligning...
# Alignment completed.
# The paper 1023 has been folded at 28297 seconds.
# The paper 1023 has been unloaded from the Folding Base at 28299 seconds.
# The paper has been checked for quality at 28299seconds.
# Folded Paper passed quality check.
# The paper 1023 has been handed over to the next station at 28305 seconds.
# The robot has returned to the start position at 28308seconds.
# Next Paper 1024 arrived at Station 1 at 28311 seconds.
# Operator started the process at 28313seconds.
# The Paper 1024 has been loaded into the robot at 28316 seconds.
# Paper is loaded properly.
# The Paper 1024 has been checked for loading errors at 28316 seconds.
# The paper 1024 has been loaded into the Folding Base at 28319 seconds.
# The paper 1024 has been checked for alignment at 28319 seconds.
# Paper is aligned properly.
# The paper 1024 has been folded at 28325 seconds.
# The paper 1024 has been unloaded from the Folding Base at 28327 seconds.
# The paper has been checked for quality at 28327seconds.
# Folded Paper passed quality check.
# The paper 1024 has been handed over to the next station at 28331 seconds.
# The robot has returned to the start position at 28333seconds.
# Next Paper 1025 arrived at Station 1 at 28337 seconds.
# Operator started the process at 28339seconds.
# The Paper 1025 has been loaded into the robot at 28341 seconds.
# Paper not loaded properly. Adjusting...
# Adjustment completed.
# The Paper 1025 has been checked for loading errors at 28342 seconds.
# The paper 1025 has been loaded into the Folding Base at 28344 seconds.
# The paper 1025 has been checked for alignment at 28344 seconds.
# Paper is aligned properly.
# The paper 1025 has been folded at 28348 seconds.
# The paper 1025 has been unloaded from the Folding Base at 28351 seconds.
# The paper has been checked for quality at 28351seconds.
# Folded Paper passed quality check.
# The paper 1025 has been handed over to the next station at 28356 seconds.
# The robot has returned to the start position at 28359seconds.
# Next Paper 1026 arrived at Station 1 at 28364 seconds.
# Operator started the process at 28366seconds.
# The Paper 1026 has been loaded into the robot at 28369 seconds.
# Paper is loaded properly.
# The Paper 1026 has been checked for loading errors at 28369 seconds.
# The paper 1026 has been loaded into the Folding Base at 28371 seconds.
# The paper 1026 has been checked for alignment at 28371 seconds.
# Paper is aligned properly.
# The paper 1026 has been folded at 28375 seconds.
# The paper 1026 has been unloaded from the Folding Base at 28377 seconds.
# The paper has been checked for quality at 28377seconds.
# Folded Paper passed quality check.
# The paper 1026 has been handed over to the next station at 28383 seconds.
# The robot has returned to the start position at 28385seconds.
# Next Paper 1027 arrived at Station 1 at 28388 seconds.
# Operator started the process at 28391seconds.
# The Paper 1027 has been loaded into the robot at 28394 seconds.
# Paper is loaded properly.
# The Paper 1027 has been checked for loading errors at 28394 seconds.
# The paper 1027 has been loaded into the Folding Base at 28397 seconds.
# The paper 1027 has been checked for alignment at 28397 seconds.
# Paper is aligned properly.
# The paper 1027 has been folded at 28403 seconds.
# The paper 1027 has been unloaded from the Folding Base at 28405 seconds.
# The paper has been checked for quality at 28405seconds.
# Folded Paper passed quality check.
# The paper 1027 has been handed over to the next station at 28409 seconds.
# The robot has returned to the start position at 28412seconds.
# Next Paper 1028 arrived at Station 1 at 28415 seconds.
# Operator started the process at 28418seconds.
# The Paper 1028 has been loaded into the robot at 28420 seconds.
# Paper is loaded properly.
# The Paper 1028 has been checked for loading errors at 28420 seconds.
# The paper 1028 has been loaded into the Folding Base at 28422 seconds.
# The paper 1028 has been checked for alignment at 28422 seconds.
# Paper is aligned properly.
# The paper 1028 has been folded at 28427 seconds.
# The paper 1028 has been unloaded from the Folding Base at 28429 seconds.
# The paper has been checked for quality at 28429seconds.
# Folded Paper passed quality check.
# The paper 1028 has been handed over to the next station at 28433 seconds.
# The robot has returned to the start position at 28435seconds.
# Next Paper 1029 arrived at Station 1 at 28437 seconds.
# Operator started the process at 28439seconds.
# The Paper 1029 has been loaded into the robot at 28441 seconds.
# Paper not loaded properly. Adjusting...
# Adjustment completed.
# The Paper 1029 has been checked for loading errors at 28442 seconds.
# The paper 1029 has been loaded into the Folding Base at 28445 seconds.
# The paper 1029 has been checked for alignment at 28445 seconds.
# Paper misaligned. Aligning...
# Alignment completed.
# The paper 1029 has been folded at 28453 seconds.
# The paper 1029 has been unloaded from the Folding Base at 28455 seconds.
# The paper has been checked for quality at 28455seconds.
# Folded Paper passed quality check.
# The paper 1029 has been handed over to the next station at 28461 seconds.
# The robot has returned to the start position at 28464seconds.
# Next Paper 1030 arrived at Station 1 at 28467 seconds.
# Operator started the process at 28470seconds.
# The Paper 1030 has been loaded into the robot at 28472 seconds.
# Paper is loaded properly.
# The Paper 1030 has been checked for loading errors at 28472 seconds.
# The paper 1030 has been loaded into the Folding Base at 28474 seconds.
# The paper 1030 has been checked for alignment at 28474 seconds.
# Paper is aligned properly.
# The paper 1030 has been folded at 28478 seconds.
# The paper 1030 has been unloaded from the Folding Base at 28481 seconds.
# The paper has been checked for quality at 28481seconds.
# Folded Paper passed quality check.
# The paper 1030 has been handed over to the next station at 28485 seconds.
# The robot has returned to the start position at 28487seconds.
# Next Paper 1031 arrived at Station 1 at 28492 seconds.
# Operator started the process at 28495seconds.
# The Paper 1031 has been loaded into the robot at 28498 seconds.
# Paper is loaded properly.
# The Paper 1031 has been checked for loading errors at 28498 seconds.
# The paper 1031 has been loaded into the Folding Base at 28500 seconds.
# The paper 1031 has been checked for alignment at 28500 seconds.
# Paper is aligned properly.
# The paper 1031 has been folded at 28507 seconds.
# The paper 1031 has been unloaded from the Folding Base at 28509 seconds.
# The paper has been checked for quality at 28509seconds.
# Folded Paper passed quality check.
# The paper 1031 has been handed over to the next station at 28513 seconds.
# The robot has returned to the start position at 28515seconds.
# Next Paper 1032 arrived at Station 1 at 28518 seconds.
# Operator started the process at 28521seconds.
# The Paper 1032 has been loaded into the robot at 28524 seconds.
# Paper is loaded properly.
# The Paper 1032 has been checked for loading errors at 28524 seconds.
# The paper 1032 has been loaded into the Folding Base at 28527 seconds.
# The paper 1032 has been checked for alignment at 28527 seconds.
# Paper is aligned properly.
# The paper 1032 has been folded at 28534 seconds.
# The paper 1032 has been unloaded from the Folding Base at 28537 seconds.
# The paper has been checked for quality at 28537seconds.
# Folded Paper passed quality check.
# The paper 1032 has been handed over to the next station at 28541 seconds.
# The robot has returned to the start position at 28543seconds.
# Next Paper 1033 arrived at Station 1 at 28546 seconds.
# Operator started the process at 28548seconds.
# The Paper 1033 has been loaded into the robot at 28551 seconds.
# Paper is loaded properly.
# The Paper 1033 has been checked for loading errors at 28551 seconds.
# The paper 1033 has been loaded into the Folding Base at 28554 seconds.
# The paper 1033 has been checked for alignment at 28554 seconds.
# Paper is aligned properly.
# The paper 1033 has been folded at 28561 seconds.
# The paper 1033 has been unloaded from the Folding Base at 28563 seconds.
# The paper has been checked for quality at 28563seconds.
# Folded Paper passed quality check.
# The paper 1033 has been handed over to the next station at 28569 seconds.
# The robot has returned to the start position at 28572seconds.
# Next Paper 1034 arrived at Station 1 at 28574 seconds.
# Operator started the process at 28576seconds.
# The Paper 1034 has been loaded into the robot at 28579 seconds.
# Paper is loaded properly.
# The Paper 1034 has been checked for loading errors at 28579 seconds.
# The paper 1034 has been loaded into the Folding Base at 28581 seconds.
# The paper 1034 has been checked for alignment at 28581 seconds.
# Paper is aligned properly.
# The paper 1034 has been folded at 28586 seconds.
# The paper 1034 has been unloaded from the Folding Base at 28589 seconds.
# The paper has been checked for quality at 28589seconds.
# Folded Paper passed quality check.
# The paper 1034 has been handed over to the next station at 28594 seconds.
# The robot has returned to the start position at 28597seconds.
# Next Paper 1035 arrived at Station 1 at 28600 seconds.
# Operator started the process at 28602seconds.
# The Paper 1035 has been loaded into the robot at 28605 seconds.
# Paper is loaded properly.
# The Paper 1035 has been checked for loading errors at 28605 seconds.
# The paper 1035 has been loaded into the Folding Base at 28607 seconds.
# The paper 1035 has been checked for alignment at 28607 seconds.
# Paper misaligned. Aligning...
# Alignment completed.
# The paper 1035 has been folded at 28617 seconds.
# The paper 1035 has been unloaded from the Folding Base at 28620 seconds.
# The paper has been checked for quality at 28620seconds.
# Folded Paper passed quality check.
# The paper 1035 has been handed over to the next station at 28626 seconds.
# The robot has returned to the start position at 28628seconds.
# Next Paper 1036 arrived at Station 1 at 28633 seconds.
# Operator started the process at 28635seconds.
# The Paper 1036 has been loaded into the robot at 28637 seconds.
# Paper is loaded properly.
# The Paper 1036 has been checked for loading errors at 28637 seconds.
# The paper 1036 has been loaded into the Folding Base at 28640 seconds.
# The paper 1036 has been checked for alignment at 28640 seconds.
# Paper is aligned properly.
# The paper 1036 has been folded at 28645 seconds.
# The paper 1036 has been unloaded from the Folding Base at 28647 seconds.
# The paper has been checked for quality at 28647seconds.
# Folded Paper passed quality check.
# The paper 1036 has been handed over to the next station at 28653 seconds.
# The robot has returned to the start position at 28655seconds.
# Next Paper 1037 arrived at Station 1 at 28660 seconds.
# Operator started the process at 28663seconds.
# The Paper 1037 has been loaded into the robot at 28665 seconds.
# Paper is loaded properly.
# The Paper 1037 has been checked for loading errors at 28665 seconds.
# The paper 1037 has been loaded into the Folding Base at 28668 seconds.
# The paper 1037 has been checked for alignment at 28668 seconds.
# Paper is aligned properly.
# The paper 1037 has been folded at 28674 seconds.
# The paper 1037 has been unloaded from the Folding Base at 28677 seconds.
# The paper has been checked for quality at 28677seconds.
# Folded Paper passed quality check.
# The paper 1037 has been handed over to the next station at 28683 seconds.
# The robot has returned to the start position at 28686seconds.
# Next Paper 1038 arrived at Station 1 at 28691 seconds.
# Operator started the process at 28693seconds.
# The Paper 1038 has been loaded into the robot at 28695 seconds.
# Paper is loaded properly.
# The Paper 1038 has been checked for loading errors at 28695 seconds.
# The paper 1038 has been loaded into the Folding Base at 28698 seconds.
# The paper 1038 has been checked for alignment at 28698 seconds.
# Paper is aligned properly.
# The paper 1038 has been folded at 28704 seconds.
# The paper 1038 has been unloaded from the Folding Base at 28707 seconds.
# The paper has been checked for quality at 28707seconds.
# Folded Paper passed quality check.
# The paper 1038 has been handed over to the next station at 28711 seconds.
# The robot has returned to the start position at 28713seconds.
# Next Paper 1039 arrived at Station 1 at 28716 seconds.
# Operator started the process at 28719seconds.
# The Paper 1039 has been loaded into the robot at 28722 seconds.
# Paper is loaded properly.
# The Paper 1039 has been checked for loading errors at 28722 seconds.
# The paper 1039 has been loaded into the Folding Base at 28724 seconds.
# The paper 1039 has been checked for alignment at 28724 seconds.
# Paper misaligned. Aligning...
# Alignment completed.
# The paper 1039 has been folded at 28732 seconds.
# The paper 1039 has been unloaded from the Folding Base at 28735 seconds.
# The paper has been checked for quality at 28735seconds.
# Folded Paper passed quality check.
# The paper 1039 has been handed over to the next station at 28741 seconds.
# The robot has returned to the start position at 28743seconds.
# Next Paper 1040 arrived at Station 1 at 28745 seconds.
# Operator started the process at 28747seconds.
# The Paper 1040 has been loaded into the robot at 28750 seconds.
# Paper not loaded properly. Adjusting...
# Adjustment completed.
# The Paper 1040 has been checked for loading errors at 28753 seconds.
# The paper 1040 has been loaded into the Folding Base at 28755 seconds.
# The paper 1040 has been checked for alignment at 28755 seconds.
# Paper misaligned. Aligning...
# Alignment completed.
# The paper 1040 has been folded at 28761 seconds.
# The paper 1040 has been unloaded from the Folding Base at 28764 seconds.
# The paper has been checked for quality at 28764seconds.
# Folded Paper passed quality check.
# The paper 1040 has been handed over to the next station at 28770 seconds.
# The robot has returned to the start position at 28772seconds.
# Next Paper 1041 arrived at Station 1 at 28776 seconds.
# Operator started the process at 28778seconds.
# The Paper 1041 has been loaded into the robot at 28780 seconds.
# Paper not loaded properly. Adjusting...
# Adjustment completed.
# The Paper 1041 has been checked for loading errors at 28782 seconds.
# The paper 1041 has been loaded into the Folding Base at 28785 seconds.
# The paper 1041 has been checked for alignment at 28785 seconds.
# Paper misaligned. Aligning...
# Alignment completed.
# The paper 1041 has been folded at 28792 seconds.
# The paper 1041 has been unloaded from the Folding Base at 28794 seconds.
# The paper has been checked for quality at 28794seconds.
# Folded Paper passed quality check.
# The paper 1041 has been handed over to the next station at 28798 seconds.

# %% [markdown]
# ## Results of the Simulation
# The outcomes of the simulation are presented in a detailed table, offering insights into various performance metrics. Following the tabular representation, there are two accompanying bar charts. The first chart visually depicts the total count of folded papers and defective papers, providing a comparative view of these key production aspects. The second bar chart illustrates a comparison of average times associated with different processes.

# %%
print ("The Simulation is ended and the results are shown below")
print ("The number of produced papers is "+str(workstation1.folded_papers-1)+".")
print ("the simulation duration is "+str(env.now)+"seconds.")
print ("The number of produced papers is "+str(workstation1.folded_papers-1)+".")
# Calculate the average folding time

produced_papers = len(paper_list)
simulation_time = 28800
average_process_time = simulation_time/produced_papers
average_folding1_time = workstation1.totalfolding1_time/produced_papers
average_folding2_time = workstation1.totalfolding2_time/produced_papers
average_folding_time = average_folding1_time + average_folding2_time
average_paper_loading_verification_time = workstation1.paper_loading_verification_time/produced_papers
average_paper_alignment_verification_time = workstation1.paper_alignment_verification_time/produced_papers
average_quality_check_time = workstation1.total_quality_check_time/produced_papers
average_operator_idle_time = workstation1.operator_idle_time/produced_papers

print ("The average process time of the produced papers is {:.2f} seconds.".format(average_process_time))
# After running the simulation, calculate and print the average folding 1 time
print ("The average Folding process time is {:.2f} seconds.".format(average_folding1_time))
print ("The average Quality check time is {:.2f} seconds.".format(average_quality_check_time))
print ("The average paper loading verification time is {:.2f} seconds.".format(average_paper_loading_verification_time))
print ("The average paper alignment verification time is {:.2f} seconds.".format(average_paper_alignment_verification_time))
print ("The number of defective papers is "+str(workstation1.defective_papers)+".")
print ("The average operator idle time is {:.2f} seconds.".format(average_operator_idle_time))

#The presented table provides a comprehensive summary of key performance metrics and 
# outcomes from a simulated production process. It includes essential information such as the total number of produced papers, the overall simulation duration, and various average times associated with different stages of the production workflow. 

from tabulate import tabulate

table_data = [
    ("Produced Papers", workstation1.folded_papers-1),
    ("Simulation Duration", f"{env.now} seconds"),
    ("Average Process Time (Cycle Time)", "{:.2f} seconds".format(average_process_time)),
    ("Average Folding  Time", "{:.2f} seconds".format(average_folding1_time)),
    ("Average Paper Loading Verification Time", "{:.2f} seconds".format(average_paper_loading_verification_time)),
    ("Average Paper Alignment Verification Time", "{:.2f} seconds".format(average_paper_alignment_verification_time)),
    ("Average Quality Check Time", "{:.2f} seconds".format(average_quality_check_time)),
    ("Defective Papers", workstation1.defective_papers),
    ("Average Operator Idle Time during the process", "{:.2f} seconds".format(average_operator_idle_time)
    ),
]


# Print the table
print(tabulate(table_data, headers=["Metric", "Value"], tablefmt="grid"))

# bar chart , Categories and corresponding average times
categories = ['Folded Papers ', 'Defective Papers ']
average_times = [produced_papers, workstation1.defective_papers]

import matplotlib.pyplot as plt
import numpy as np
# Plotting the bar chart
plt.bar(categories, average_times, color=['blue', 'green'])
plt.xlabel('Processes')
plt.ylabel('Number of Papers')
plt.title('Folded Papers and Defective Papers')
plt.show()
# Out:
# The Simulation is ended and the results are shown below
# The number of produced papers is 1040.
# the simulation duration is 28800seconds.
# The number of produced papers is 1040.
# The average process time of the produced papers is 30.70 seconds.
# The average Folding process time is 6.11 seconds.
# The average Quality check time is 6.38 seconds.
# The average paper loading verification time is 0.66 seconds.
# The average paper alignment verification time is 0.66 seconds.
# The number of defective papers is 104.
# The average operator idle time is 19.74 seconds.
# +-----------------------------------------------+---------------+
# | Metric                                        | Value         |
# +===============================================+===============+
# | Produced Papers                               | 1040          |
# +-----------------------------------------------+---------------+
# | Simulation Duration                           | 28800 seconds |
# +-----------------------------------------------+---------------+
# | Average Process Time (Cycle Time)             | 30.70 seconds |
# +-----------------------------------------------+---------------+
# | Average Folding  Time                         | 6.11 seconds  |
# +-----------------------------------------------+---------------+
# | Average Paper Loading Verification Time       | 0.66 seconds  |
# +-----------------------------------------------+---------------+
# | Average Paper Alignment Verification Time     | 0.66 seconds  |
# +-----------------------------------------------+---------------+
# | Average Quality Check Time                    | 6.38 seconds  |
# +-----------------------------------------------+---------------+
# | Defective Papers                              | 104           |
# +-----------------------------------------------+---------------+
# | Average Operator Idle Time during the process | 19.74 seconds |
# +-----------------------------------------------+---------------+

# %%
#This Bar chart that visually compares the average times for different processes.

import matplotlib.pyplot as plt
import numpy as np



# Categories and corresponding average times
categories = ['Folding ', 'Quality Check ','Loading Check', 'Alignment Check']
average_times = [average_folding1_time, average_quality_check_time, average_paper_loading_verification_time, average_paper_alignment_verification_time]

# Plotting the bar chart
plt.bar(categories, average_times, color=['blue', 'green', 'red', 'purple'])
plt.xlabel('Processes')
plt.ylabel('Average Time (seconds)')
plt.title('Comparison of Average Times for Different Processes')
plt.show()
