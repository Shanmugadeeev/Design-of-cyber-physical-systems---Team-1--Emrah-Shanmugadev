# %% [markdown]
# ## Design of Cyberphysical Systems - Project
#
# After creating the data structure, the following step involves writing code that captures the logic and sequence of the process in our process flow . Also we need to define the paper_generator on this step.
# Results :
# The outcomes of the simulation are presented in a detailed table, offering insights into various performance metrics. Following the tabular representation, there are two accompanying bar charts. The first chart visually depicts the total count of folded papers and defective papers, providing a comparative view of these key production aspects. The second bar chart illustrates a comparison of average times associated with different processes.
#
# # Paper Folding Processflow Simulation

# %% [markdown]
# The first step would be to implement the ressources along with its attributes and methods
# ## 1. Ressources

# %%
import simpy
import random

#Defining Resources (Paper  ,Robot , Operator ,Paper Loading Station)

#defining Paper 

class Paper:
    def __init__(self, env, workstation1):
        self.is_defective = False
        pass

class PaperLoadingstation (object):
    # Initally the paper laodingstation has 100 papers.
    def __init__(self,env):
        self.papers = simpy.PaperLoadingstation (env, init=100, capaciy = 100)

    def check_availability_paperloadingstation(self,operator):
        # check if there is enough paper on the Loading station

        # This takes between 1-3 seconds
         yield self.env.timeout(random.randint(1, 3))

         if self.paperloadingstation == 1:
           # if there are enough paper, return True
           # print("there are enough paper available ")
           return True
         else:
            print("There are not enough paper available on the station , please refill ")
            
            return False
         
    def pick_paper(self,operator,workstation1,Robot):
        while not self.env.process(self.check_availability_paperloadingstation(Robot)):
         yield self.env.timeout(1)
         yield self.pickup_paperloadingstation.get(1) & self.env.process(self.restock())  # & self.env.process(workstation3.pickup_paper(robot))
    
    def restock_paperloadingstation(self):
         #restock the paperdispenser , this takes between 15-25 seconds
          yield self.env.timeout(random.randint(5,10))
          #restock the paper dispenser
          yield self.pickup_paperdispenser.put(100)
          print("The paper dispenser has been restocked")

#defining Robot
    
class Robot(object):
   
    def __init__(self,env,workstation1):
        self.env = env
        
        self.workstation1 = workstation1
        self.robot = simpy.Resource(env,capacity= 1)
        

    #The calibration takes place as a first step, this will takes around 2-3 Seconds
    def actuate(self,workstation1):
        yield self.env.timeout(random.randint(2,3))
        
    #the paper is loaded into the robot
    def load_paper(self,paper,paperloadingstation):
        yield self.env.timeout(random.randint(2,3))
        
     #the paper is loaded into Folding Base by the  robot , where the folding operation takes place
    def load_paper_to_foldingbase(self,paper):
        yield self.env.timeout(random.randint(2,3)) 
        
    
    #the Folding operation takes place by the robot
    def fold_paper(self,paper):
        yield self.env.timeout(random.randint(4,7))
        
    #the paper is unloaded from the Folding Base by the robot
    def unload_paper_from_foldingbase(self,paper):
        yield self.env.timeout(random.randint(2,3))
        
    def return_to_start(self):
        yield self.env.timeout(random.randint(2, 3))
    
    #At the end ,hand over the folded paper to the next station for further operations
    def hand_over_paper(self,workstation2):
        yield self.env.timeout (random.randint(2,3))
        

#defining Operator
        

class Operator (object):
    def __init__(self,env,workstation1,folded_papers):
        self.env = env
        self.workstation1 = workstation1
        self.folded_papers = folded_papers
        
        self.quality_check_times = {'check1': []}
        self.total_idle_time = 0
        
        
    def adjust_paper_loading(self, paper):
        # Check if the paper is loaded properly
        if random.random() < 0.3:  # 30% chance of loading error
            print("Paper not loaded properly. Adjusting...")
            yield self.env.timeout(random.randint(1, 3))
            print("Adjustment completed.")
        else:
            print("Paper is loaded properly.")
        
        

    def quality_check_fold(self, paper):
        # Quality check after Folding Operation
        start_time = self.env.now
        yield self.env.timeout(random.randint(2, 3))
        end_time = self.env.now
        self.quality_check_times['check1'].append(end_time - start_time)

        # Assume a 10% chance of a defect
        if random.random() < 0.1:
            paper.is_defective = True

        if paper.is_defective:
            # If the paper is defective, send it to waste
            print("Folded Paper has a defect and goes to waste.")
            yield self.env.process(self.workstation1.WasteStation.dispose(paper))
            robot = Robot(self.env, self.workstation1)
            yield self.env.process(self.workstation1.workstation1_process(self, Paper(self.env, self.workstation1), robot))
            
        else:
            print("Folded Paper passed quality check.")
        
        
        self.idle_start_time = self.env.now
        
    def align_paper(self, paper):
        # Check if the paper is aligned properly
        if random.random() < 0.3:  # 30% chance of misalignment
            print("Paper misaligned. Aligning...")
            yield self.env.timeout(random.randint(1, 3))
            print("Alignment completed.")
        else:
            print("Paper is aligned properly.")
    
        

#defining Workstation2 
class Workstation2(object):
    def __init__(self,env):
        self.env = env
        
class WasteStation(object):
    def __init__(self, env):
        self.env = env

    def dispose(self,paper):
        # Waste disposal process
        yield self.env.timeout(random.randint(2, 3))
        print("Paper has been disposed of as waste.")

# %% [markdown]
# ## 2.Environment
# In the 2nd step we will implement the environment in which the simulation takes place.Here we will set up the ressources and the genereal process flow.

# %%
#Defining the workstatiion1

class WorkStation1(object):
    def __init__(self,env,paper_list,robot,Workstation2,operator,folded_papers):
        self.env = env
        self.folded_papers = folded_papers
        
        self.operator = operator(env,self, self.folded_papers )
        self.idle_start_time = 0
        
        self.robot = robot(env,self)
        self.workstation2 = Workstation2(env)
        
        self.WasteStation = WasteStation(env) 
         
        self.folded_papers = 0
        self.total_operation_time = 0
        self.totalfolding1_time = 0
        self.paper_loading_verification_time = 0
        self.paper_alignment_verification_time = 0
        self.totalfolding2_time = 0
        self.total_quality_check_time = 0
        self.defective_papers = 0
        self.operator_idle_time = 0
        self.start_idle_time = 0
        self.total_idle_time = 0       
        self.production_rate_data = []
        self.operation_times = []

    def workstation1_process(self,operator,paper,robot):
        
       #Track the time
        arrival_time=self.env.now
        yield self.env.process(self.robot.actuate(self))
        print ("Operator started the process at "+str(self.env.now)+"seconds.")
        #The paper is loaded into the robot
        operator.idle1_start_time = self.env.now 
        #the operator is idle during the paper loading process, and the time is recorded
        yield self.env.process(self.robot.load_paper(paper,PaperLoadingstation))
        print("The Paper " +str(self.folded_papers)+" has been loaded into the robot at "+str(self.env.now)+" seconds.")
        operator.idle1_end_time = self.env.now - operator.idle1_start_time
        

        #the error is checked by the operator
        paper_loading_verification_start_time = self.env.now
        yield self.env.process(self.operator.adjust_paper_loading(paper))
        print("The Paper " +str(self.folded_papers)+" has been checked for loading errors at "+str(self.env.now)+" seconds.")
        paper_loading_verification_end_time = self.env.now - paper_loading_verification_start_time
       
        

        #The paper is loaded into the Folding Base by the robot
        operator.idle2_start_time = self.env.now
        yield self.env.process(self.robot.load_paper_to_foldingbase(paper))
        print ("The paper " +str(self.folded_papers)+" has been loaded into the Folding Base at "+str(self.env.now)+" seconds.")
        operator.idle2_end_time = self.env.now - operator.idle2_start_time

        #the paper alignment is checked by the operator
        paper_alignment_verification_start_time = self.env.now
        print ("The paper " +str(self.folded_papers)+" has been checked for alignment at "+str(self.env.now)+" seconds.")
        yield self.env.process(self.operator.align_paper(paper))
               
        paper_alignment_verification_end_time = self.env.now - paper_alignment_verification_start_time
                
        #The Folding operation takes place by the robot , some steps are done by the operator
        folding1_start_time = self.env.now
        yield self.env.process(self.robot.fold_paper(paper))
        folding1_end_time = self.env.now - folding1_start_time
        print ("The paper " +str(self.folded_papers)+" has been folded at "+str(self.env.now)+" seconds.")

        #The paper is unloaded from the Folding Base by the robot
        operator.idle3_start_time = self.env.now
        yield self.env.process(self.robot.unload_paper_from_foldingbase(paper))
        print ("The paper " +str(self.folded_papers)+" has been unloaded from the Folding Base at "+str(self.env.now)+" seconds.")
        
        #Quality check 
        quality_check_start_time = self.env.now 
        print ("The paper has been checked for quality at "+str(self.env.now)+"seconds.")
        yield self.env.process(self.operator.quality_check_fold(paper))
        
        quality_check_end_time = self.env.now - quality_check_start_time
        if paper.is_defective:
            self.defective_papers += 1

        #the paper is handed over to the next station for further operations
        yield self.env.process(self.robot.hand_over_paper(Workstation2))
        print ("The paper "+str(self.folded_papers)+" has been handed over to the next station at "+str(self.env.now)+" seconds.")
        operator.idle3_end_time = self.env.now - operator.idle3_start_time

        
        #the robot returns to the start position
        operator.idle4_start_time = self.env.now
        yield self.env.process(self.robot.return_to_start())
        print ("The robot has returned to the start position at "+str(self.env.now)+"seconds.")
        operator.idle4_end_time = self.env.now - operator.idle4_start_time
        #the operator is idle during the paper loading process, and the time is recorded

        #Operation time
        operation_time = self.env.now - arrival_time
        #Total folding time
        totalfolding1_time = folding1_end_time 
        #operator idle time
        operator_idle_time = operator.idle1_end_time + operator.idle2_end_time + operator.idle3_end_time + operator.idle4_end_time
        # add the operator idle time to the list of operator idle times
        self.operator_idle_time += operator_idle_time     
                
        # add the paper loading verification time to the list of paper loading verification times
        self.paper_loading_verification_time += paper_loading_verification_end_time
        # add the paper alignment verification time to the list of paper alignment verification times
        self.paper_alignment_verification_time += paper_alignment_verification_end_time
        total_quality_check_time = quality_check_end_time
        self.total_quality_check_time += total_quality_check_time

        # add the production rate data to the list
        self.production_rate_data.append((self.env.now, self.folded_papers))

        
        # add the folding time to the list of folding times
        self.totalfolding1_time += totalfolding1_time
        
        
    
        # add the process time to the total production time
        self.total_operation_time += operation_time

        # count the produced papers
        self.folded_papers += 1

# %% [markdown]
# ## 3.Simulation
# In the third step we will run the simulation and therefore define the initial set of parameter to simulate.

# %%
def paper_generator(env, workstation1, paper_list):
    while True:
        interarrival_time = random.randint(2,5)

        paper = Paper(env, workstation1)
        paper_list.append(paper)

        operator = Operator(env, workstation1, workstation1.folded_papers)
        robot = Robot(env, workstation1)

        yield env.process(workstation1.workstation1_process(operator, paper,robot))

        yield env.timeout(interarrival_time)
        print("Next Paper " + str(workstation1.folded_papers) + " arrived at Station 1 at " + str(env.now) + " seconds.")
import simpy
env = simpy.Environment()

paper_list=[]
folded_papers=0
operator = Operator(env,WorkStation1,folded_papers)

workstation1=WorkStation1(env,paper_list,Robot,Workstation2,Operator,folded_papers)


print ("The number of produced papers is "+str(workstation1.folded_papers-1)+".")
print ("the simulation duration is "+str(env.now)+"seconds.")
env.process(paper_generator(env,workstation1,paper_list))
env.run(until=28800)
# Out:
# The number of produced papers is -1.
# the simulation duration is 0seconds.
# Operator started the process at 2seconds.
# The Paper 0 has been loaded into the robot at 5 seconds.
# Paper is loaded properly.
# The Paper 0 has been checked for loading errors at 5 seconds.
# The paper 0 has been loaded into the Folding Base at 7 seconds.
# The paper 0 has been checked for alignment at 7 seconds.
# Paper is aligned properly.
# The paper 0 has been folded at 13 seconds.
# The paper 0 has been unloaded from the Folding Base at 15 seconds.
# The paper has been checked for quality at 15seconds.
# Folded Paper passed quality check.
# The paper 0 has been handed over to the next station at 20 seconds.
# The robot has returned to the start position at 22seconds.
# Next Paper 1 arrived at Station 1 at 25 seconds.
# Operator started the process at 27seconds.
# The Paper 1 has been loaded into the robot at 29 seconds.
# Paper is loaded properly.
# The Paper 1 has been checked for loading errors at 29 seconds.
# The paper 1 has been loaded into the Folding Base at 32 seconds.
# The paper 1 has been checked for alignment at 32 seconds.
# Paper is aligned properly.
# The paper 1 has been folded at 37 seconds.
# The paper 1 has been unloaded from the Folding Base at 39 seconds.
# The paper has been checked for quality at 39seconds.
# Folded Paper passed quality check.
# The paper 1 has been handed over to the next station at 44 seconds.
# The robot has returned to the start position at 46seconds.
# Next Paper 2 arrived at Station 1 at 48 seconds.
# Operator started the process at 50seconds.
# The Paper 2 has been loaded into the robot at 52 seconds.
# Paper not loaded properly. Adjusting...
# Adjustment completed.
# The Paper 2 has been checked for loading errors at 55 seconds.
# The paper 2 has been loaded into the Folding Base at 58 seconds.
# The paper 2 has been checked for alignment at 58 seconds.
# Paper is aligned properly.
# The paper 2 has been folded at 63 seconds.
# The paper 2 has been unloaded from the Folding Base at 66 seconds.
# The paper has been checked for quality at 66seconds.
# Folded Paper passed quality check.
# The paper 2 has been handed over to the next station at 72 seconds.
# The robot has returned to the start position at 75seconds.
# Next Paper 3 arrived at Station 1 at 77 seconds.
# Operator started the process at 79seconds.
# The Paper 3 has been loaded into the robot at 82 seconds.
# Paper is loaded properly.
# The Paper 3 has been checked for loading errors at 82 seconds.
# The paper 3 has been loaded into the Folding Base at 85 seconds.
# The paper 3 has been checked for alignment at 85 seconds.
# Paper misaligned. Aligning...
# Alignment completed.
# The paper 3 has been folded at 92 seconds.
# The paper 3 has been unloaded from the Folding Base at 94 seconds.
# The paper has been checked for quality at 94seconds.
# Folded Paper passed quality check.
# The paper 3 has been handed over to the next station at 99 seconds.
# The robot has returned to the start position at 101seconds.
# Next Paper 4 arrived at Station 1 at 105 seconds.
# Operator started the process at 107seconds.
# The Paper 4 has been loaded into the robot at 109 seconds.
# Paper is loaded properly.
# The Paper 4 has been checked for loading errors at 109 seconds.
# The paper 4 has been loaded into the Folding Base at 112 seconds.
# The paper 4 has been checked for alignment at 112 seconds.
# Paper misaligned. Aligning...
# Alignment completed.
# The paper 4 has been folded at 121 seconds.
# The paper 4 has been unloaded from the Folding Base at 124 seconds.
# The paper has been checked for quality at 124seconds.
# Folded Paper passed quality check.
# The paper 4 has been handed over to the next station at 128 seconds.
# The robot has returned to the start position at 131seconds.
# Next Paper 5 arrived at Station 1 at 133 seconds.
# Operator started the process at 136seconds.
# The Paper 5 has been loaded into the robot at 139 seconds.
# Paper is loaded properly.
# The Paper 5 has been checked for loading errors at 139 seconds.
# The paper 5 has been loaded into the Folding Base at 141 seconds.
# The paper 5 has been checked for alignment at 141 seconds.
# Paper misaligned. Aligning...
# Alignment completed.
# The paper 5 has been folded at 148 seconds.
# The paper 5 has been unloaded from the Folding Base at 151 seconds.
# The paper has been checked for quality at 151seconds.
# Folded Paper passed quality check.
# The paper 5 has been handed over to the next station at 156 seconds.
# The robot has returned to the start position at 158seconds.
# Next Paper 6 arrived at Station 1 at 163 seconds.
# Operator started the process at 165seconds.
# The Paper 6 has been loaded into the robot at 168 seconds.
# Paper is loaded properly.
# The Paper 6 has been checked for loading errors at 168 seconds.
# The paper 6 has been loaded into the Folding Base at 171 seconds.
# The paper 6 has been checked for alignment at 171 seconds.
# Paper is aligned properly.
# The paper 6 has been folded at 178 seconds.
# The paper 6 has been unloaded from the Folding Base at 181 seconds.
# The paper has been checked for quality at 181seconds.
# Folded Paper passed quality check.
# The paper 6 has been handed over to the next station at 186 seconds.
# The robot has returned to the start position at 188seconds.
# Next Paper 7 arrived at Station 1 at 191 seconds.
# Operator started the process at 193seconds.
# The Paper 7 has been loaded into the robot at 196 seconds.
# Paper is loaded properly.
# The Paper 7 has been checked for loading errors at 196 seconds.
# The paper 7 has been loaded into the Folding Base at 198 seconds.
# The paper 7 has been checked for alignment at 198 seconds.
# Paper is aligned properly.
# The paper 7 has been folded at 203 seconds.
# The paper 7 has been unloaded from the Folding Base at 206 seconds.
# The paper has been checked for quality at 206seconds.
# Folded Paper passed quality check.
# The paper 7 has been handed over to the next station at 211 seconds.
# The robot has returned to the start position at 213seconds.
# Next Paper 8 arrived at Station 1 at 217 seconds.
# Operator started the process at 220seconds.
# The Paper 8 has been loaded into the robot at 223 seconds.
# Paper is loaded properly.
# The Paper 8 has been checked for loading errors at 223 seconds.
# The paper 8 has been loaded into the Folding Base at 225 seconds.
# The paper 8 has been checked for alignment at 225 seconds.
# Paper misaligned. Aligning...
# Alignment completed.
# The paper 8 has been folded at 234 seconds.
# The paper 8 has been unloaded from the Folding Base at 237 seconds.
# The paper has been checked for quality at 237seconds.
# Folded Paper passed quality check.
# The paper 8 has been handed over to the next station at 243 seconds.
# The robot has returned to the start position at 245seconds.
# Next Paper 9 arrived at Station 1 at 248 seconds.
# Operator started the process at 250seconds.
# The Paper 9 has been loaded into the robot at 252 seconds.
# Paper is loaded properly.
# The Paper 9 has been checked for loading errors at 252 seconds.
# The paper 9 has been loaded into the Folding Base at 254 seconds.
# The paper 9 has been checked for alignment at 254 seconds.
# Paper is aligned properly.
# The paper 9 has been folded at 261 seconds.
# The paper 9 has been unloaded from the Folding Base at 263 seconds.
# The paper has been checked for quality at 263seconds.
# Folded Paper passed quality check.
# The paper 9 has been handed over to the next station at 268 seconds.
# The robot has returned to the start position at 271seconds.
# Next Paper 10 arrived at Station 1 at 275 seconds.
# Operator started the process at 277seconds.
# The Paper 10 has been loaded into the robot at 280 seconds.
# Paper is loaded properly.
# The Paper 10 has been checked for loading errors at 280 seconds.
# The paper 10 has been loaded into the Folding Base at 282 seconds.
# The paper 10 has been checked for alignment at 282 seconds.
# Paper misaligned. Aligning...
# Alignment completed.
# The paper 10 has been folded at 290 seconds.
# The paper 10 has been unloaded from the Folding Base at 293 seconds.
# The paper has been checked for quality at 293seconds.
# Folded Paper passed quality check.
# The paper 10 has been handed over to the next station at 298 seconds.
# The robot has returned to the start position at 300seconds.
# Next Paper 11 arrived at Station 1 at 305 seconds.
# Operator started the process at 308seconds.
# The Paper 11 has been loaded into the robot at 311 seconds.
# Paper is loaded properly.
# The Paper 11 has been checked for loading errors at 311 seconds.
# The paper 11 has been loaded into the Folding Base at 313 seconds.
# The paper 11 has been checked for alignment at 313 seconds.
# Paper is aligned properly.
# The paper 11 has been folded at 319 seconds.
# The paper 11 has been unloaded from the Folding Base at 321 seconds.
# The paper has been checked for quality at 321seconds.
# Folded Paper passed quality check.
# The paper 11 has been handed over to the next station at 325 seconds.
# The robot has returned to the start position at 327seconds.
# Next Paper 12 arrived at Station 1 at 332 seconds.
# Operator started the process at 335seconds.
# The Paper 12 has been loaded into the robot at 338 seconds.
# Paper is loaded properly.
# The Paper 12 has been checked for loading errors at 338 seconds.
# The paper 12 has been loaded into the Folding Base at 341 seconds.
# The paper 12 has been checked for alignment at 341 seconds.
# Paper is aligned properly.
# The paper 12 has been folded at 345 seconds.
# The paper 12 has been unloaded from the Folding Base at 348 seconds.
# The paper has been checked for quality at 348seconds.
# Folded Paper passed quality check.
# The paper 12 has been handed over to the next station at 352 seconds.
# The robot has returned to the start position at 355seconds.
# Next Paper 13 arrived at Station 1 at 357 seconds.
# Operator started the process at 360seconds.
# The Paper 13 has been loaded into the robot at 362 seconds.
# Paper not loaded properly. Adjusting...
# Adjustment completed.
# The Paper 13 has been checked for loading errors at 364 seconds.
# The paper 13 has been loaded into the Folding Base at 366 seconds.
# The paper 13 has been checked for alignment at 366 seconds.
# Paper is aligned properly.
# The paper 13 has been folded at 370 seconds.
# The paper 13 has been unloaded from the Folding Base at 373 seconds.
# The paper has been checked for quality at 373seconds.
# Folded Paper passed quality check.
# The paper 13 has been handed over to the next station at 378 seconds.
# The robot has returned to the start position at 380seconds.
# Next Paper 14 arrived at Station 1 at 385 seconds.
# Operator started the process at 388seconds.
# The Paper 14 has been loaded into the robot at 391 seconds.
# Paper is loaded properly.
# The Paper 14 has been checked for loading errors at 391 seconds.
# The paper 14 has been loaded into the Folding Base at 394 seconds.
# The paper 14 has been checked for alignment at 394 seconds.
# Paper is aligned properly.
# The paper 14 has been folded at 401 seconds.
# The paper 14 has been unloaded from the Folding Base at 403 seconds.
# The paper has been checked for quality at 403seconds.
# Folded Paper passed quality check.
# The paper 14 has been handed over to the next station at 407 seconds.
# The robot has returned to the start position at 409seconds.
# Next Paper 15 arrived at Station 1 at 412 seconds.
# Operator started the process at 415seconds.
# The Paper 15 has been loaded into the robot at 417 seconds.
# Paper is loaded properly.
# The Paper 15 has been checked for loading errors at 417 seconds.
# The paper 15 has been loaded into the Folding Base at 420 seconds.
# The paper 15 has been checked for alignment at 420 seconds.
# Paper is aligned properly.
# The paper 15 has been folded at 424 seconds.
# The paper 15 has been unloaded from the Folding Base at 426 seconds.
# The paper has been checked for quality at 426seconds.
# Folded Paper passed quality check.
# The paper 15 has been handed over to the next station at 432 seconds.
# The robot has returned to the start position at 435seconds.
# Next Paper 16 arrived at Station 1 at 439 seconds.
# Operator started the process at 442seconds.
# The Paper 16 has been loaded into the robot at 445 seconds.
# Paper not loaded properly. Adjusting...
# Adjustment completed.
# The Paper 16 has been checked for loading errors at 447 seconds.
# The paper 16 has been loaded into the Folding Base at 449 seconds.
# The paper 16 has been checked for alignment at 449 seconds.
# Paper is aligned properly.
# The paper 16 has been folded at 453 seconds.
# The paper 16 has been unloaded from the Folding Base at 455 seconds.
# The paper has been checked for quality at 455seconds.
# Folded Paper passed quality check.
# The paper 16 has been handed over to the next station at 461 seconds.
# The robot has returned to the start position at 464seconds.
# Next Paper 17 arrived at Station 1 at 469 seconds.
# Operator started the process at 472seconds.
# The Paper 17 has been loaded into the robot at 474 seconds.
# Paper is loaded properly.
# The Paper 17 has been checked for loading errors at 474 seconds.
# The paper 17 has been loaded into the Folding Base at 477 seconds.
# The paper 17 has been checked for alignment at 477 seconds.
# Paper misaligned. Aligning...
# Alignment completed.
# The paper 17 has been folded at 483 seconds.
# The paper 17 has been unloaded from the Folding Base at 485 seconds.
# The paper has been checked for quality at 485seconds.
# Folded Paper passed quality check.
# The paper 17 has been handed over to the next station at 490 seconds.
# The robot has returned to the start position at 493seconds.
# Next Paper 18 arrived at Station 1 at 498 seconds.
# Operator started the process at 501seconds.
# The Paper 18 has been loaded into the robot at 503 seconds.
# Paper not loaded properly. Adjusting...
# Adjustment completed.
# The Paper 18 has been checked for loading errors at 504 seconds.
# The paper 18 has been loaded into the Folding Base at 507 seconds.
# The paper 18 has been checked for alignment at 507 seconds.
# Paper is aligned properly.
# The paper 18 has been folded at 514 seconds.
# The paper 18 has been unloaded from the Folding Base at 517 seconds.
# The paper has been checked for quality at 517seconds.
# Folded Paper passed quality check.
# The paper 18 has been handed over to the next station at 523 seconds.
# The robot has returned to the start position at 525seconds.
# Next Paper 19 arrived at Station 1 at 529 seconds.
# Operator started the process at 532seconds.
# The Paper 19 has been loaded into the robot at 534 seconds.
# Paper not loaded properly. Adjusting...
# Adjustment completed.
# The Paper 19 has been checked for loading errors at 535 seconds.
# The paper 19 has been loaded into the Folding Base at 537 seconds.
# The paper 19 has been checked for alignment at 537 seconds.
# Paper is aligned properly.
# The paper 19 has been folded at 544 seconds.
# The paper 19 has been unloaded from the Folding Base at 546 seconds.
# The paper has been checked for quality at 546seconds.
# Folded Paper passed quality check.
# The paper 19 has been handed over to the next station at 551 seconds.
# The robot has returned to the start position at 554seconds.
# Next Paper 20 arrived at Station 1 at 557 seconds.
# Operator started the process at 560seconds.
# The Paper 20 has been loaded into the robot at 562 seconds.
# Paper is loaded properly.
# The Paper 20 has been checked for loading errors at 562 seconds.
# The paper 20 has been loaded into the Folding Base at 564 seconds.
# The paper 20 has been checked for alignment at 564 seconds.
# Paper misaligned. Aligning...
# Alignment completed.
# The paper 20 has been folded at 573 seconds.
# The paper 20 has been unloaded from the Folding Base at 576 seconds.
# The paper has been checked for quality at 576seconds.
# Folded Paper passed quality check.
# The paper 20 has been handed over to the next station at 580 seconds.
# The robot has returned to the start position at 583seconds.
# Next Paper 21 arrived at Station 1 at 585 seconds.
# Operator started the process at 587seconds.
# The Paper 21 has been loaded into the robot at 590 seconds.
# Paper is loaded properly.
# The Paper 21 has been checked for loading errors at 590 seconds.
# The paper 21 has been loaded into the Folding Base at 592 seconds.
# The paper 21 has been checked for alignment at 592 seconds.
# Paper is aligned properly.
# The paper 21 has been folded at 596 seconds.
# The paper 21 has been unloaded from the Folding Base at 599 seconds.
# The paper has been checked for quality at 599seconds.
# Folded Paper passed quality check.
# The paper 21 has been handed over to the next station at 603 seconds.
# The robot has returned to the start position at 606seconds.
# Next Paper 22 arrived at Station 1 at 611 seconds.
# Operator started the process at 614seconds.
# The Paper 22 has been loaded into the robot at 616 seconds.
# Paper is loaded properly.
# The Paper 22 has been checked for loading errors at 616 seconds.
# The paper 22 has been loaded into the Folding Base at 618 seconds.
# The paper 22 has been checked for alignment at 618 seconds.
# Paper misaligned. Aligning...
# Alignment completed.
# The paper 22 has been folded at 627 seconds.
# The paper 22 has been unloaded from the Folding Base at 630 seconds.
# The paper has been checked for quality at 630seconds.
# Folded Paper passed quality check.
# The paper 22 has been handed over to the next station at 635 seconds.
# The robot has returned to the start position at 637seconds.
# Next Paper 23 arrived at Station 1 at 640 seconds.
# Operator started the process at 643seconds.
# The Paper 23 has been loaded into the robot at 645 seconds.
# Paper is loaded properly.
# The Paper 23 has been checked for loading errors at 645 seconds.
# The paper 23 has been loaded into the Folding Base at 647 seconds.
# The paper 23 has been checked for alignment at 647 seconds.
# Paper misaligned. Aligning...
# Alignment completed.
# The paper 23 has been folded at 655 seconds.
# The paper 23 has been unloaded from the Folding Base at 658 seconds.
# The paper has been checked for quality at 658seconds.
# Folded Paper passed quality check.
# The paper 23 has been handed over to the next station at 662 seconds.
# The robot has returned to the start position at 664seconds.
# Next Paper 24 arrived at Station 1 at 669 seconds.
# Operator started the process at 672seconds.
# The Paper 24 has been loaded into the robot at 674 seconds.
# Paper is loaded properly.
# The Paper 24 has been checked for loading errors at 674 seconds.
# The paper 24 has been loaded into the Folding Base at 677 seconds.
# The paper 24 has been checked for alignment at 677 seconds.
# Paper misaligned. Aligning...
# Alignment completed.
# The paper 24 has been folded at 684 seconds.
# The paper 24 has been unloaded from the Folding Base at 686 seconds.
# The paper has been checked for quality at 686seconds.
# Folded Paper passed quality check.
# The paper 24 has been handed over to the next station at 691 seconds.
# The robot has returned to the start position at 694seconds.
# Next Paper 25 arrived at Station 1 at 696 seconds.
# Operator started the process at 698seconds.
# The Paper 25 has been loaded into the robot at 700 seconds.
# Paper not loaded properly. Adjusting...
# Adjustment completed.
# The Paper 25 has been checked for loading errors at 702 seconds.
# The paper 25 has been loaded into the Folding Base at 704 seconds.
# The paper 25 has been checked for alignment at 704 seconds.
# Paper misaligned. Aligning...
# Alignment completed.
# The paper 25 has been folded at 711 seconds.
# The paper 25 has been unloaded from the Folding Base at 713 seconds.
# The paper has been checked for quality at 713seconds.
# Folded Paper passed quality check.
# The paper 25 has been handed over to the next station at 719 seconds.
# The robot has returned to the start position at 722seconds.
# Next Paper 26 arrived at Station 1 at 727 seconds.
# Operator started the process at 729seconds.
# The Paper 26 has been loaded into the robot at 732 seconds.
# Paper is loaded properly.
# The Paper 26 has been checked for loading errors at 732 seconds.
# The paper 26 has been loaded into the Folding Base at 734 seconds.
# The paper 26 has been checked for alignment at 734 seconds.
# Paper is aligned properly.
# The paper 26 has been folded at 738 seconds.
# The paper 26 has been unloaded from the Folding Base at 741 seconds.
# The paper has been checked for quality at 741seconds.
# Folded Paper has a defect and goes to waste.
# Paper has been disposed of as waste.
# Operator started the process at 748seconds.
# The Paper 26 has been loaded into the robot at 751 seconds.
# Paper is loaded properly.
# The Paper 26 has been checked for loading errors at 751 seconds.
# The paper 26 has been loaded into the Folding Base at 753 seconds.
# The paper 26 has been checked for alignment at 753 seconds.
# Paper misaligned. Aligning...
# Alignment completed.
# The paper 26 has been folded at 760 seconds.
# The paper 26 has been unloaded from the Folding Base at 763 seconds.
# The paper has been checked for quality at 763seconds.
# Folded Paper passed quality check.
# The paper 26 has been handed over to the next station at 769 seconds.
# The robot has returned to the start position at 772seconds.
# The paper 27 has been handed over to the next station at 775 seconds.
# The robot has returned to the start position at 777seconds.
# Next Paper 28 arrived at Station 1 at 779 seconds.
# Operator started the process at 781seconds.
# The Paper 28 has been loaded into the robot at 783 seconds.
# Paper is loaded properly.
# The Paper 28 has been checked for loading errors at 783 seconds.
# The paper 28 has been loaded into the Folding Base at 786 seconds.
# The paper 28 has been checked for alignment at 786 seconds.
# Paper is aligned properly.
# The paper 28 has been folded at 790 seconds.
# The paper 28 has been unloaded from the Folding Base at 792 seconds.
# The paper has been checked for quality at 792seconds.
# Folded Paper passed quality check.
# The paper 28 has been handed over to the next station at 797 seconds.
# The robot has returned to the start position at 800seconds.
# Next Paper 29 arrived at Station 1 at 803 seconds.
# Operator started the process at 805seconds.
# The Paper 29 has been loaded into the robot at 808 seconds.
# Paper is loaded properly.
# The Paper 29 has been checked for loading errors at 808 seconds.
# The paper 29 has been loaded into the Folding Base at 810 seconds.
# The paper 29 has been checked for alignment at 810 seconds.
# Paper is aligned properly.
# The paper 29 has been folded at 814 seconds.
# The paper 29 has been unloaded from the Folding Base at 817 seconds.
# The paper has been checked for quality at 817seconds.
# Folded Paper passed quality check.
# The paper 29 has been handed over to the next station at 823 seconds.
# The robot has returned to the start position at 826seconds.
# Next Paper 30 arrived at Station 1 at 828 seconds.
# Operator started the process at 830seconds.
# The Paper 30 has been loaded into the robot at 832 seconds.
# Paper is loaded properly.
# The Paper 30 has been checked for loading errors at 832 seconds.
# The paper 30 has been loaded into the Folding Base at 835 seconds.
# The paper 30 has been checked for alignment at 835 seconds.
# Paper is aligned properly.
# The paper 30 has been folded at 842 seconds.
# The paper 30 has been unloaded from the Folding Base at 844 seconds.
# The paper has been checked for quality at 844seconds.
# Folded Paper passed quality check.
# The paper 30 has been handed over to the next station at 849 seconds.
# The robot has returned to the start position at 852seconds.
# Next Paper 31 arrived at Station 1 at 857 seconds.
# Operator started the process at 860seconds.
# The Paper 31 has been loaded into the robot at 863 seconds.
# Paper not loaded properly. Adjusting...
# Adjustment completed.
# The Paper 31 has been checked for loading errors at 865 seconds.
# The paper 31 has been loaded into the Folding Base at 868 seconds.
# The paper 31 has been checked for alignment at 868 seconds.
# Paper is aligned properly.
# The paper 31 has been folded at 874 seconds.
# The paper 31 has been unloaded from the Folding Base at 877 seconds.
# The paper has been checked for quality at 877seconds.
# Folded Paper passed quality check.
# The paper 31 has been handed over to the next station at 883 seconds.
# The robot has returned to the start position at 885seconds.
# Next Paper 32 arrived at Station 1 at 888 seconds.
# Operator started the process at 891seconds.
# The Paper 32 has been loaded into the robot at 894 seconds.
# Paper is loaded properly.
# The Paper 32 has been checked for loading errors at 894 seconds.
# The paper 32 has been loaded into the Folding Base at 897 seconds.
# The paper 32 has been checked for alignment at 897 seconds.
# Paper is aligned properly.
# The paper 32 has been folded at 904 seconds.
# The paper 32 has been unloaded from the Folding Base at 906 seconds.
# The paper has been checked for quality at 906seconds.
# Folded Paper has a defect and goes to waste.
# Paper has been disposed of as waste.
# Operator started the process at 914seconds.
# The Paper 32 has been loaded into the robot at 917 seconds.
# Paper is loaded properly.
# The Paper 32 has been checked for loading errors at 917 seconds.
# The paper 32 has been loaded into the Folding Base at 919 seconds.
# The paper 32 has been checked for alignment at 919 seconds.
# Paper is aligned properly.
# The paper 32 has been folded at 926 seconds.
# The paper 32 has been unloaded from the Folding Base at 929 seconds.
# The paper has been checked for quality at 929seconds.
# Folded Paper passed quality check.
# The paper 32 has been handed over to the next station at 934 seconds.
# The robot has returned to the start position at 936seconds.
# The paper 33 has been handed over to the next station at 939 seconds.
# The robot has returned to the start position at 942seconds.
# Next Paper 34 arrived at Station 1 at 947 seconds.
# Operator started the process at 949seconds.
# The Paper 34 has been loaded into the robot at 951 seconds.
# Paper not loaded properly. Adjusting...
# Adjustment completed.
# The Paper 34 has been checked for loading errors at 953 seconds.
# The paper 34 has been loaded into the Folding Base at 955 seconds.
# The paper 34 has been checked for alignment at 955 seconds.
# Paper is aligned properly.
# The paper 34 has been folded at 962 seconds.
# The paper 34 has been unloaded from the Folding Base at 964 seconds.
# The paper has been checked for quality at 964seconds.
# Folded Paper has a defect and goes to waste.
# Paper has been disposed of as waste.
# Operator started the process at 972seconds.
# The Paper 34 has been loaded into the robot at 975 seconds.
# Paper is loaded properly.
# The Paper 34 has been checked for loading errors at 975 seconds.
# The paper 34 has been loaded into the Folding Base at 977 seconds.
# The paper 34 has been checked for alignment at 977 seconds.
# Paper is aligned properly.
# The paper 34 has been folded at 982 seconds.
# The paper 34 has been unloaded from the Folding Base at 984 seconds.
# The paper has been checked for quality at 984seconds.
# Folded Paper passed quality check.
# The paper 34 has been handed over to the next station at 989 seconds.
# The robot has returned to the start position at 992seconds.
# The paper 35 has been handed over to the next station at 994 seconds.
# The robot has returned to the start position at 996seconds.
# Next Paper 36 arrived at Station 1 at 998 seconds.
# Operator started the process at 1001seconds.
# The Paper 36 has been loaded into the robot at 1004 seconds.
# Paper not loaded properly. Adjusting...
# Adjustment completed.
# The Paper 36 has been checked for loading errors at 1007 seconds.
# The paper 36 has been loaded into the Folding Base at 1009 seconds.
# The paper 36 has been checked for alignment at 1009 seconds.
# Paper misaligned. Aligning...
# Alignment completed.
# The paper 36 has been folded at 1016 seconds.
# The paper 36 has been unloaded from the Folding Base at 1018 seconds.
# The paper has been checked for quality at 1018seconds.
# Folded Paper passed quality check.
# The paper 36 has been handed over to the next station at 1023 seconds.
# The robot has returned to the start position at 1026seconds.
# Next Paper 37 arrived at Station 1 at 1031 seconds.
# Operator started the process at 1034seconds.
# The Paper 37 has been loaded into the robot at 1036 seconds.
# Paper is loaded properly.
# The Paper 37 has been checked for loading errors at 1036 seconds.
# The paper 37 has been loaded into the Folding Base at 1039 seconds.
# The paper 37 has been checked for alignment at 1039 seconds.
# Paper is aligned properly.
# The paper 37 has been folded at 1045 seconds.
# The paper 37 has been unloaded from the Folding Base at 1047 seconds.
# The paper has been checked for quality at 1047seconds.
# Folded Paper passed quality check.
# The paper 37 has been handed over to the next station at 1051 seconds.
# The robot has returned to the start position at 1053seconds.
# Next Paper 38 arrived at Station 1 at 1056 seconds.
# Operator started the process at 1059seconds.
# The Paper 38 has been loaded into the robot at 1061 seconds.
# Paper is loaded properly.
# The Paper 38 has been checked for loading errors at 1061 seconds.
# The paper 38 has been loaded into the Folding Base at 1064 seconds.
# The paper 38 has been checked for alignment at 1064 seconds.
# Paper is aligned properly.
# The paper 38 has been folded at 1071 seconds.
# The paper 38 has been unloaded from the Folding Base at 1073 seconds.
# The paper has been checked for quality at 1073seconds.
# Folded Paper passed quality check.
# The paper 38 has been handed over to the next station at 1077 seconds.
# The robot has returned to the start position at 1079seconds.
# Next Paper 39 arrived at Station 1 at 1084 seconds.
# Operator started the process at 1086seconds.
# The Paper 39 has been loaded into the robot at 1089 seconds.
# Paper is loaded properly.
# The Paper 39 has been checked for loading errors at 1089 seconds.
# The paper 39 has been loaded into the Folding Base at 1091 seconds.
# The paper 39 has been checked for alignment at 1091 seconds.
# Paper misaligned. Aligning...
# Alignment completed.
# The paper 39 has been folded at 1100 seconds.
# The paper 39 has been unloaded from the Folding Base at 1103 seconds.
# The paper has been checked for quality at 1103seconds.
# Folded Paper passed quality check.
# The paper 39 has been handed over to the next station at 1107 seconds.
# The robot has returned to the start position at 1109seconds.
# Next Paper 40 arrived at Station 1 at 1112 seconds.
# Operator started the process at 1115seconds.
# The Paper 40 has been loaded into the robot at 1117 seconds.
# Paper is loaded properly.
# The Paper 40 has been checked for loading errors at 1117 seconds.
# The paper 40 has been loaded into the Folding Base at 1120 seconds.
# The paper 40 has been checked for alignment at 1120 seconds.
# Paper is aligned properly.
# The paper 40 has been folded at 1126 seconds.
# The paper 40 has been unloaded from the Folding Base at 1128 seconds.
# The paper has been checked for quality at 1128seconds.
# Folded Paper passed quality check.
# The paper 40 has been handed over to the next station at 1133 seconds.
# The robot has returned to the start position at 1136seconds.
# Next Paper 41 arrived at Station 1 at 1139 seconds.
# Operator started the process at 1141seconds.
# The Paper 41 has been loaded into the robot at 1144 seconds.
# Paper is loaded properly.
# The Paper 41 has been checked for loading errors at 1144 seconds.
# The paper 41 has been loaded into the Folding Base at 1146 seconds.
# The paper 41 has been checked for alignment at 1146 seconds.
# Paper is aligned properly.
# The paper 41 has been folded at 1150 seconds.
# The paper 41 has been unloaded from the Folding Base at 1152 seconds.
# The paper has been checked for quality at 1152seconds.
# Folded Paper passed quality check.
# The paper 41 has been handed over to the next station at 1157 seconds.
# The robot has returned to the start position at 1159seconds.
# Next Paper 42 arrived at Station 1 at 1164 seconds.
# Operator started the process at 1166seconds.
# The Paper 42 has been loaded into the robot at 1169 seconds.
# Paper is loaded properly.
# The Paper 42 has been checked for loading errors at 1169 seconds.
# The paper 42 has been loaded into the Folding Base at 1171 seconds.
# The paper 42 has been checked for alignment at 1171 seconds.
# Paper is aligned properly.
# The paper 42 has been folded at 1177 seconds.
# The paper 42 has been unloaded from the Folding Base at 1179 seconds.
# The paper has been checked for quality at 1179seconds.
# Folded Paper passed quality check.
# The paper 42 has been handed over to the next station at 1184 seconds.
# The robot has returned to the start position at 1187seconds.
# Next Paper 43 arrived at Station 1 at 1189 seconds.
# Operator started the process at 1191seconds.
# The Paper 43 has been loaded into the robot at 1193 seconds.
# Paper not loaded properly. Adjusting...
# Adjustment completed.
# The Paper 43 has been checked for loading errors at 1196 seconds.
# The paper 43 has been loaded into the Folding Base at 1199 seconds.
# The paper 43 has been checked for alignment at 1199 seconds.
# Paper is aligned properly.
# The paper 43 has been folded at 1204 seconds.
# The paper 43 has been unloaded from the Folding Base at 1207 seconds.
# The paper has been checked for quality at 1207seconds.
# Folded Paper passed quality check.
# The paper 43 has been handed over to the next station at 1211 seconds.
# The robot has returned to the start position at 1213seconds.
# Next Paper 44 arrived at Station 1 at 1215 seconds.
# Operator started the process at 1217seconds.
# The Paper 44 has been loaded into the robot at 1219 seconds.
# Paper is loaded properly.
# The Paper 44 has been checked for loading errors at 1219 seconds.
# The paper 44 has been loaded into the Folding Base at 1222 seconds.
# The paper 44 has been checked for alignment at 1222 seconds.
# Paper is aligned properly.
# The paper 44 has been folded at 1229 seconds.
# The paper 44 has been unloaded from the Folding Base at 1232 seconds.
# The paper has been checked for quality at 1232seconds.
# Folded Paper has a defect and goes to waste.
# Paper has been disposed of as waste.
# Operator started the process at 1239seconds.
# The Paper 44 has been loaded into the robot at 1242 seconds.
# Paper is loaded properly.
# The Paper 44 has been checked for loading errors at 1242 seconds.
# The paper 44 has been loaded into the Folding Base at 1244 seconds.
# The paper 44 has been checked for alignment at 1244 seconds.
# Paper is aligned properly.
# The paper 44 has been folded at 1251 seconds.
# The paper 44 has been unloaded from the Folding Base at 1254 seconds.
# The paper has been checked for quality at 1254seconds.
# Folded Paper passed quality check.
# The paper 44 has been handed over to the next station at 1259 seconds.
# The robot has returned to the start position at 1261seconds.
# The paper 45 has been handed over to the next station at 1264 seconds.
# The robot has returned to the start position at 1267seconds.
# Next Paper 46 arrived at Station 1 at 1269 seconds.
# Operator started the process at 1272seconds.
# The Paper 46 has been loaded into the robot at 1274 seconds.
# Paper is loaded properly.
# The Paper 46 has been checked for loading errors at 1274 seconds.
# The paper 46 has been loaded into the Folding Base at 1276 seconds.
# The paper 46 has been checked for alignment at 1276 seconds.
# Paper is aligned properly.
# The paper 46 has been folded at 1281 seconds.
# The paper 46 has been unloaded from the Folding Base at 1283 seconds.
# The paper has been checked for quality at 1283seconds.
# Folded Paper passed quality check.
# The paper 46 has been handed over to the next station at 1288 seconds.
# The robot has returned to the start position at 1290seconds.
# Next Paper 47 arrived at Station 1 at 1293 seconds.
# Operator started the process at 1296seconds.
# The Paper 47 has been loaded into the robot at 1298 seconds.
# Paper is loaded properly.
# The Paper 47 has been checked for loading errors at 1298 seconds.
# The paper 47 has been loaded into the Folding Base at 1301 seconds.
# The paper 47 has been checked for alignment at 1301 seconds.
# Paper misaligned. Aligning...
# Alignment completed.
# The paper 47 has been folded at 1309 seconds.
# The paper 47 has been unloaded from the Folding Base at 1312 seconds.
# The paper has been checked for quality at 1312seconds.
# Folded Paper passed quality check.
# The paper 47 has been handed over to the next station at 1316 seconds.
# The robot has returned to the start position at 1318seconds.
# Next Paper 48 arrived at Station 1 at 1320 seconds.
# Operator started the process at 1323seconds.
# The Paper 48 has been loaded into the robot at 1326 seconds.
# Paper is loaded properly.
# The Paper 48 has been checked for loading errors at 1326 seconds.
# The paper 48 has been loaded into the Folding Base at 1329 seconds.
# The paper 48 has been checked for alignment at 1329 seconds.
# Paper misaligned. Aligning...
# Alignment completed.
# The paper 48 has been folded at 1338 seconds.
# The paper 48 has been unloaded from the Folding Base at 1340 seconds.
# The paper has been checked for quality at 1340seconds.
# Folded Paper passed quality check.
# The paper 48 has been handed over to the next station at 1346 seconds.
# The robot has returned to the start position at 1348seconds.
# Next Paper 49 arrived at Station 1 at 1351 seconds.
# Operator started the process at 1354seconds.
# The Paper 49 has been loaded into the robot at 1357 seconds.
# Paper not loaded properly. Adjusting...
# Adjustment completed.
# The Paper 49 has been checked for loading errors at 1359 seconds.
# The paper 49 has been loaded into the Folding Base at 1361 seconds.
# The paper 49 has been checked for alignment at 1361 seconds.
# Paper is aligned properly.
# The paper 49 has been folded at 1367 seconds.
# The paper 49 has been unloaded from the Folding Base at 1369 seconds.
# The paper has been checked for quality at 1369seconds.
# Folded Paper passed quality check.
# The paper 49 has been handed over to the next station at 1374 seconds.
# The robot has returned to the start position at 1376seconds.
# Next Paper 50 arrived at Station 1 at 1379 seconds.
# Operator started the process at 1381seconds.
# The Paper 50 has been loaded into the robot at 1383 seconds.
# Paper not loaded properly. Adjusting...
# Adjustment completed.
# The Paper 50 has been checked for loading errors at 1386 seconds.
# The paper 50 has been loaded into the Folding Base at 1388 seconds.
# The paper 50 has been checked for alignment at 1388 seconds.
# Paper misaligned. Aligning...
# Alignment completed.
# The paper 50 has been folded at 1394 seconds.
# The paper 50 has been unloaded from the Folding Base at 1397 seconds.
# The paper has been checked for quality at 1397seconds.
# Folded Paper passed quality check.
# The paper 50 has been handed over to the next station at 1403 seconds.
# The robot has returned to the start position at 1406seconds.
# Next Paper 51 arrived at Station 1 at 1411 seconds.
# Operator started the process at 1414seconds.
# The Paper 51 has been loaded into the robot at 1416 seconds.
# Paper is loaded properly.
# The Paper 51 has been checked for loading errors at 1416 seconds.
# The paper 51 has been loaded into the Folding Base at 1419 seconds.
# The paper 51 has been checked for alignment at 1419 seconds.
# Paper is aligned properly.
# The paper 51 has been folded at 1423 seconds.
# The paper 51 has been unloaded from the Folding Base at 1425 seconds.
# The paper has been checked for quality at 1425seconds.
# Folded Paper passed quality check.
# The paper 51 has been handed over to the next station at 1430 seconds.
# The robot has returned to the start position at 1432seconds.
# Next Paper 52 arrived at Station 1 at 1434 seconds.
# Operator started the process at 1436seconds.
# The Paper 52 has been loaded into the robot at 1438 seconds.
# Paper is loaded properly.
# The Paper 52 has been checked for loading errors at 1438 seconds.
# The paper 52 has been loaded into the Folding Base at 1441 seconds.
# The paper 52 has been checked for alignment at 1441 seconds.
# Paper is aligned properly.
# The paper 52 has been folded at 1446 seconds.
# The paper 52 has been unloaded from the Folding Base at 1449 seconds.
# The paper has been checked for quality at 1449seconds.
# Folded Paper passed quality check.
# The paper 52 has been handed over to the next station at 1454 seconds.
# The robot has returned to the start position at 1457seconds.
# Next Paper 53 arrived at Station 1 at 1460 seconds.
# Operator started the process at 1463seconds.
# The Paper 53 has been loaded into the robot at 1465 seconds.
# Paper not loaded properly. Adjusting...
# Adjustment completed.
# The Paper 53 has been checked for loading errors at 1468 seconds.
# The paper 53 has been loaded into the Folding Base at 1471 seconds.
# The paper 53 has been checked for alignment at 1471 seconds.
# Paper is aligned properly.
# The paper 53 has been folded at 1478 seconds.
# The paper 53 has been unloaded from the Folding Base at 1480 seconds.
# The paper has been checked for quality at 1480seconds.
# Folded Paper passed quality check.
# The paper 53 has been handed over to the next station at 1486 seconds.
# The robot has returned to the start position at 1489seconds.
# Next Paper 54 arrived at Station 1 at 1492 seconds.
# Operator started the process at 1495seconds.
# The Paper 54 has been loaded into the robot at 1498 seconds.
# Paper is loaded properly.
# The Paper 54 has been checked for loading errors at 1498 seconds.
# The paper 54 has been loaded into the Folding Base at 1500 seconds.
# The paper 54 has been checked for alignment at 1500 seconds.
# Paper is aligned properly.
# The paper 54 has been folded at 1504 seconds.
# The paper 54 has been unloaded from the Folding Base at 1506 seconds.
# The paper has been checked for quality at 1506seconds.
# Folded Paper passed quality check.
# The paper 54 has been handed over to the next station at 1511 seconds.
# The robot has returned to the start position at 1514seconds.
# Next Paper 55 arrived at Station 1 at 1516 seconds.
# Operator started the process at 1518seconds.
# The Paper 55 has been loaded into the robot at 1521 seconds.
# Paper is loaded properly.
# The Paper 55 has been checked for loading errors at 1521 seconds.
# The paper 55 has been loaded into the Folding Base at 1523 seconds.
# The paper 55 has been checked for alignment at 1523 seconds.
# Paper is aligned properly.
# The paper 55 has been folded at 1529 seconds.
# The paper 55 has been unloaded from the Folding Base at 1532 seconds.
# The paper has been checked for quality at 1532seconds.
# Folded Paper passed quality check.
# The paper 55 has been handed over to the next station at 1538 seconds.
# The robot has returned to the start position at 1541seconds.
# Next Paper 56 arrived at Station 1 at 1543 seconds.
# Operator started the process at 1546seconds.
# The Paper 56 has been loaded into the robot at 1549 seconds.
# Paper is loaded properly.
# The Paper 56 has been checked for loading errors at 1549 seconds.
# The paper 56 has been loaded into the Folding Base at 1551 seconds.
# The paper 56 has been checked for alignment at 1551 seconds.
# Paper is aligned properly.
# The paper 56 has been folded at 1557 seconds.
# The paper 56 has been unloaded from the Folding Base at 1560 seconds.
# The paper has been checked for quality at 1560seconds.
# Folded Paper passed quality check.
# The paper 56 has been handed over to the next station at 1564 seconds.
# The robot has returned to the start position at 1566seconds.
# Next Paper 57 arrived at Station 1 at 1568 seconds.
# Operator started the process at 1571seconds.
# The Paper 57 has been loaded into the robot at 1574 seconds.
# Paper is loaded properly.
# The Paper 57 has been checked for loading errors at 1574 seconds.
# The paper 57 has been loaded into the Folding Base at 1577 seconds.
# The paper 57 has been checked for alignment at 1577 seconds.
# Paper is aligned properly.
# The paper 57 has been folded at 1582 seconds.
# The paper 57 has been unloaded from the Folding Base at 1585 seconds.
# The paper has been checked for quality at 1585seconds.
# Folded Paper passed quality check.
# The paper 57 has been handed over to the next station at 1591 seconds.
# The robot has returned to the start position at 1594seconds.
# Next Paper 58 arrived at Station 1 at 1599 seconds.
# Operator started the process at 1602seconds.
# The Paper 58 has been loaded into the robot at 1604 seconds.
# Paper is loaded properly.
# The Paper 58 has been checked for loading errors at 1604 seconds.
# The paper 58 has been loaded into the Folding Base at 1606 seconds.
# The paper 58 has been checked for alignment at 1606 seconds.
# Paper misaligned. Aligning...
# Alignment completed.
# The paper 58 has been folded at 1614 seconds.
# The paper 58 has been unloaded from the Folding Base at 1616 seconds.
# The paper has been checked for quality at 1616seconds.
# Folded Paper passed quality check.
# The paper 58 has been handed over to the next station at 1620 seconds.
# The robot has returned to the start position at 1622seconds.
# Next Paper 59 arrived at Station 1 at 1625 seconds.
# Operator started the process at 1627seconds.
# The Paper 59 has been loaded into the robot at 1629 seconds.
# Paper is loaded properly.
# The Paper 59 has been checked for loading errors at 1629 seconds.
# The paper 59 has been loaded into the Folding Base at 1631 seconds.
# The paper 59 has been checked for alignment at 1631 seconds.
# Paper is aligned properly.
# The paper 59 has been folded at 1636 seconds.
# The paper 59 has been unloaded from the Folding Base at 1639 seconds.
# The paper has been checked for quality at 1639seconds.
# Folded Paper passed quality check.
# The paper 59 has been handed over to the next station at 1644 seconds.
# The robot has returned to the start position at 1646seconds.
# Next Paper 60 arrived at Station 1 at 1650 seconds.
# Operator started the process at 1653seconds.
# The Paper 60 has been loaded into the robot at 1655 seconds.
# Paper is loaded properly.
# The Paper 60 has been checked for loading errors at 1655 seconds.
# The paper 60 has been loaded into the Folding Base at 1657 seconds.
# The paper 60 has been checked for alignment at 1657 seconds.
# Paper misaligned. Aligning...
# Alignment completed.
# The paper 60 has been folded at 1665 seconds.
# The paper 60 has been unloaded from the Folding Base at 1667 seconds.
# The paper has been checked for quality at 1667seconds.
# Folded Paper passed quality check.
# The paper 60 has been handed over to the next station at 1673 seconds.
# The robot has returned to the start position at 1676seconds.
# Next Paper 61 arrived at Station 1 at 1678 seconds.
# Operator started the process at 1681seconds.
# The Paper 61 has been loaded into the robot at 1684 seconds.
# Paper not loaded properly. Adjusting...
# Adjustment completed.
# The Paper 61 has been checked for loading errors at 1687 seconds.
# The paper 61 has been loaded into the Folding Base at 1689 seconds.
# The paper 61 has been checked for alignment at 1689 seconds.
# Paper is aligned properly.
# The paper 61 has been folded at 1693 seconds.
# The paper 61 has been unloaded from the Folding Base at 1695 seconds.
# The paper has been checked for quality at 1695seconds.
# Folded Paper passed quality check.
# The paper 61 has been handed over to the next station at 1700 seconds.
# The robot has returned to the start position at 1702seconds.
# Next Paper 62 arrived at Station 1 at 1705 seconds.
# Operator started the process at 1707seconds.
# The Paper 62 has been loaded into the robot at 1710 seconds.
# Paper not loaded properly. Adjusting...
# Adjustment completed.
# The Paper 62 has been checked for loading errors at 1713 seconds.
# The paper 62 has been loaded into the Folding Base at 1715 seconds.
# The paper 62 has been checked for alignment at 1715 seconds.
# Paper is aligned properly.
# The paper 62 has been folded at 1720 seconds.
# The paper 62 has been unloaded from the Folding Base at 1722 seconds.
# The paper has been checked for quality at 1722seconds.
# Folded Paper passed quality check.
# The paper 62 has been handed over to the next station at 1726 seconds.
# The robot has returned to the start position at 1728seconds.
# Next Paper 63 arrived at Station 1 at 1730 seconds.
# Operator started the process at 1733seconds.
# The Paper 63 has been loaded into the robot at 1735 seconds.
# Paper is loaded properly.
# The Paper 63 has been checked for loading errors at 1735 seconds.
# The paper 63 has been loaded into the Folding Base at 1738 seconds.
# The paper 63 has been checked for alignment at 1738 seconds.
# Paper is aligned properly.
# The paper 63 has been folded at 1744 seconds.
# The paper 63 has been unloaded from the Folding Base at 1747 seconds.
# The paper has been checked for quality at 1747seconds.
# Folded Paper passed quality check.
# ...
# Paper is aligned properly.
# The paper 1022 has been folded at 28240 seconds.
# The paper 1022 has been unloaded from the Folding Base at 28243 seconds.
# The paper has been checked for quality at 28243seconds.
# Folded Paper passed quality check.
# The paper 1022 has been handed over to the next station at 28249 seconds.
# The robot has returned to the start position at 28251seconds.
# The paper 1023 has been handed over to the next station at 28253 seconds.
# The robot has returned to the start position at 28255seconds.
# Next Paper 1024 arrived at Station 1 at 28258 seconds.
# Operator started the process at 28260seconds.
# The Paper 1024 has been loaded into the robot at 28262 seconds.
# Paper is loaded properly.
# The Paper 1024 has been checked for loading errors at 28262 seconds.
# The paper 1024 has been loaded into the Folding Base at 28265 seconds.
# The paper 1024 has been checked for alignment at 28265 seconds.
# Paper is aligned properly.
# The paper 1024 has been folded at 28271 seconds.
# The paper 1024 has been unloaded from the Folding Base at 28273 seconds.
# The paper has been checked for quality at 28273seconds.
# Folded Paper passed quality check.
# The paper 1024 has been handed over to the next station at 28278 seconds.
# The robot has returned to the start position at 28280seconds.
# Next Paper 1025 arrived at Station 1 at 28284 seconds.
# Operator started the process at 28286seconds.
# The Paper 1025 has been loaded into the robot at 28288 seconds.
# Paper is loaded properly.
# The Paper 1025 has been checked for loading errors at 28288 seconds.
# The paper 1025 has been loaded into the Folding Base at 28291 seconds.
# The paper 1025 has been checked for alignment at 28291 seconds.
# Paper misaligned. Aligning...
# Alignment completed.
# The paper 1025 has been folded at 28299 seconds.
# The paper 1025 has been unloaded from the Folding Base at 28301 seconds.
# The paper has been checked for quality at 28301seconds.
# Folded Paper passed quality check.
# The paper 1025 has been handed over to the next station at 28307 seconds.
# The robot has returned to the start position at 28310seconds.
# Next Paper 1026 arrived at Station 1 at 28314 seconds.
# Operator started the process at 28317seconds.
# The Paper 1026 has been loaded into the robot at 28320 seconds.
# Paper not loaded properly. Adjusting...
# Adjustment completed.
# The Paper 1026 has been checked for loading errors at 28323 seconds.
# The paper 1026 has been loaded into the Folding Base at 28325 seconds.
# The paper 1026 has been checked for alignment at 28325 seconds.
# Paper misaligned. Aligning...
# Alignment completed.
# The paper 1026 has been folded at 28334 seconds.
# The paper 1026 has been unloaded from the Folding Base at 28336 seconds.
# The paper has been checked for quality at 28336seconds.
# Folded Paper passed quality check.
# The paper 1026 has been handed over to the next station at 28340 seconds.
# The robot has returned to the start position at 28342seconds.
# Next Paper 1027 arrived at Station 1 at 28346 seconds.
# Operator started the process at 28348seconds.
# The Paper 1027 has been loaded into the robot at 28350 seconds.
# Paper is loaded properly.
# The Paper 1027 has been checked for loading errors at 28350 seconds.
# The paper 1027 has been loaded into the Folding Base at 28352 seconds.
# The paper 1027 has been checked for alignment at 28352 seconds.
# Paper is aligned properly.
# The paper 1027 has been folded at 28359 seconds.
# The paper 1027 has been unloaded from the Folding Base at 28361 seconds.
# The paper has been checked for quality at 28361seconds.
# Folded Paper passed quality check.
# The paper 1027 has been handed over to the next station at 28366 seconds.
# The robot has returned to the start position at 28369seconds.
# Next Paper 1028 arrived at Station 1 at 28372 seconds.
# Operator started the process at 28374seconds.
# The Paper 1028 has been loaded into the robot at 28376 seconds.
# Paper not loaded properly. Adjusting...
# Adjustment completed.
# The Paper 1028 has been checked for loading errors at 28378 seconds.
# The paper 1028 has been loaded into the Folding Base at 28380 seconds.
# The paper 1028 has been checked for alignment at 28380 seconds.
# Paper misaligned. Aligning...
# Alignment completed.
# The paper 1028 has been folded at 28388 seconds.
# The paper 1028 has been unloaded from the Folding Base at 28390 seconds.
# The paper has been checked for quality at 28390seconds.
# Folded Paper passed quality check.
# The paper 1028 has been handed over to the next station at 28394 seconds.
# The robot has returned to the start position at 28396seconds.
# Next Paper 1029 arrived at Station 1 at 28398 seconds.
# Operator started the process at 28400seconds.
# The Paper 1029 has been loaded into the robot at 28402 seconds.
# Paper is loaded properly.
# The Paper 1029 has been checked for loading errors at 28402 seconds.
# The paper 1029 has been loaded into the Folding Base at 28404 seconds.
# The paper 1029 has been checked for alignment at 28404 seconds.
# Paper misaligned. Aligning...
# Alignment completed.
# The paper 1029 has been folded at 28410 seconds.
# The paper 1029 has been unloaded from the Folding Base at 28412 seconds.
# The paper has been checked for quality at 28412seconds.
# Folded Paper has a defect and goes to waste.
# Paper has been disposed of as waste.
# Operator started the process at 28419seconds.
# The Paper 1029 has been loaded into the robot at 28422 seconds.
# Paper not loaded properly. Adjusting...
# Adjustment completed.
# The Paper 1029 has been checked for loading errors at 28423 seconds.
# The paper 1029 has been loaded into the Folding Base at 28425 seconds.
# The paper 1029 has been checked for alignment at 28425 seconds.
# Paper is aligned properly.
# The paper 1029 has been folded at 28432 seconds.
# The paper 1029 has been unloaded from the Folding Base at 28434 seconds.
# The paper has been checked for quality at 28434seconds.
# Folded Paper passed quality check.
# The paper 1029 has been handed over to the next station at 28440 seconds.
# The robot has returned to the start position at 28443seconds.
# The paper 1030 has been handed over to the next station at 28446 seconds.
# The robot has returned to the start position at 28448seconds.
# Next Paper 1031 arrived at Station 1 at 28451 seconds.
# Operator started the process at 28453seconds.
# The Paper 1031 has been loaded into the robot at 28455 seconds.
# Paper is loaded properly.
# The Paper 1031 has been checked for loading errors at 28455 seconds.
# The paper 1031 has been loaded into the Folding Base at 28457 seconds.
# The paper 1031 has been checked for alignment at 28457 seconds.
# Paper is aligned properly.
# The paper 1031 has been folded at 28463 seconds.
# The paper 1031 has been unloaded from the Folding Base at 28466 seconds.
# The paper has been checked for quality at 28466seconds.
# Folded Paper passed quality check.
# The paper 1031 has been handed over to the next station at 28472 seconds.
# The robot has returned to the start position at 28474seconds.
# Next Paper 1032 arrived at Station 1 at 28476 seconds.
# Operator started the process at 28479seconds.
# The Paper 1032 has been loaded into the robot at 28482 seconds.
# Paper not loaded properly. Adjusting...
# Adjustment completed.
# The Paper 1032 has been checked for loading errors at 28483 seconds.
# The paper 1032 has been loaded into the Folding Base at 28486 seconds.
# The paper 1032 has been checked for alignment at 28486 seconds.
# Paper is aligned properly.
# The paper 1032 has been folded at 28493 seconds.
# The paper 1032 has been unloaded from the Folding Base at 28496 seconds.
# The paper has been checked for quality at 28496seconds.
# Folded Paper passed quality check.
# The paper 1032 has been handed over to the next station at 28501 seconds.
# The robot has returned to the start position at 28503seconds.
# Next Paper 1033 arrived at Station 1 at 28506 seconds.
# Operator started the process at 28508seconds.
# The Paper 1033 has been loaded into the robot at 28511 seconds.
# Paper is loaded properly.
# The Paper 1033 has been checked for loading errors at 28511 seconds.
# The paper 1033 has been loaded into the Folding Base at 28513 seconds.
# The paper 1033 has been checked for alignment at 28513 seconds.
# Paper is aligned properly.
# The paper 1033 has been folded at 28519 seconds.
# The paper 1033 has been unloaded from the Folding Base at 28522 seconds.
# The paper has been checked for quality at 28522seconds.
# Folded Paper passed quality check.
# The paper 1033 has been handed over to the next station at 28527 seconds.
# The robot has returned to the start position at 28530seconds.
# Next Paper 1034 arrived at Station 1 at 28533 seconds.
# Operator started the process at 28536seconds.
# The Paper 1034 has been loaded into the robot at 28539 seconds.
# Paper not loaded properly. Adjusting...
# Adjustment completed.
# The Paper 1034 has been checked for loading errors at 28541 seconds.
# The paper 1034 has been loaded into the Folding Base at 28543 seconds.
# The paper 1034 has been checked for alignment at 28543 seconds.
# Paper is aligned properly.
# The paper 1034 has been folded at 28548 seconds.
# The paper 1034 has been unloaded from the Folding Base at 28550 seconds.
# The paper has been checked for quality at 28550seconds.
# Folded Paper passed quality check.
# The paper 1034 has been handed over to the next station at 28554 seconds.
# The robot has returned to the start position at 28556seconds.
# Next Paper 1035 arrived at Station 1 at 28561 seconds.
# Operator started the process at 28563seconds.
# The Paper 1035 has been loaded into the robot at 28566 seconds.
# Paper is loaded properly.
# The Paper 1035 has been checked for loading errors at 28566 seconds.
# The paper 1035 has been loaded into the Folding Base at 28569 seconds.
# The paper 1035 has been checked for alignment at 28569 seconds.
# Paper misaligned. Aligning...
# Alignment completed.
# The paper 1035 has been folded at 28575 seconds.
# The paper 1035 has been unloaded from the Folding Base at 28578 seconds.
# The paper has been checked for quality at 28578seconds.
# Folded Paper passed quality check.
# The paper 1035 has been handed over to the next station at 28583 seconds.
# The robot has returned to the start position at 28585seconds.
# Next Paper 1036 arrived at Station 1 at 28590 seconds.
# Operator started the process at 28593seconds.
# The Paper 1036 has been loaded into the robot at 28596 seconds.
# Paper is loaded properly.
# The Paper 1036 has been checked for loading errors at 28596 seconds.
# The paper 1036 has been loaded into the Folding Base at 28598 seconds.
# The paper 1036 has been checked for alignment at 28598 seconds.
# Paper is aligned properly.
# The paper 1036 has been folded at 28603 seconds.
# The paper 1036 has been unloaded from the Folding Base at 28605 seconds.
# The paper has been checked for quality at 28605seconds.
# Folded Paper passed quality check.
# The paper 1036 has been handed over to the next station at 28610 seconds.
# The robot has returned to the start position at 28612seconds.
# Next Paper 1037 arrived at Station 1 at 28617 seconds.
# Operator started the process at 28620seconds.
# The Paper 1037 has been loaded into the robot at 28623 seconds.
# Paper is loaded properly.
# The Paper 1037 has been checked for loading errors at 28623 seconds.
# The paper 1037 has been loaded into the Folding Base at 28626 seconds.
# The paper 1037 has been checked for alignment at 28626 seconds.
# Paper is aligned properly.
# The paper 1037 has been folded at 28632 seconds.
# The paper 1037 has been unloaded from the Folding Base at 28635 seconds.
# The paper has been checked for quality at 28635seconds.
# Folded Paper passed quality check.
# The paper 1037 has been handed over to the next station at 28639 seconds.
# The robot has returned to the start position at 28641seconds.
# Next Paper 1038 arrived at Station 1 at 28644 seconds.
# Operator started the process at 28647seconds.
# The Paper 1038 has been loaded into the robot at 28649 seconds.
# Paper is loaded properly.
# The Paper 1038 has been checked for loading errors at 28649 seconds.
# The paper 1038 has been loaded into the Folding Base at 28651 seconds.
# The paper 1038 has been checked for alignment at 28651 seconds.
# Paper misaligned. Aligning...
# Alignment completed.
# The paper 1038 has been folded at 28660 seconds.
# The paper 1038 has been unloaded from the Folding Base at 28662 seconds.
# The paper has been checked for quality at 28662seconds.
# Folded Paper passed quality check.
# The paper 1038 has been handed over to the next station at 28667 seconds.
# The robot has returned to the start position at 28670seconds.
# Next Paper 1039 arrived at Station 1 at 28673 seconds.
# Operator started the process at 28675seconds.
# The Paper 1039 has been loaded into the robot at 28678 seconds.
# Paper is loaded properly.
# The Paper 1039 has been checked for loading errors at 28678 seconds.
# The paper 1039 has been loaded into the Folding Base at 28681 seconds.
# The paper 1039 has been checked for alignment at 28681 seconds.
# Paper is aligned properly.
# The paper 1039 has been folded at 28685 seconds.
# The paper 1039 has been unloaded from the Folding Base at 28688 seconds.
# The paper has been checked for quality at 28688seconds.
# Folded Paper passed quality check.
# The paper 1039 has been handed over to the next station at 28694 seconds.
# The robot has returned to the start position at 28697seconds.
# Next Paper 1040 arrived at Station 1 at 28701 seconds.
# Operator started the process at 28703seconds.
# The Paper 1040 has been loaded into the robot at 28706 seconds.
# Paper not loaded properly. Adjusting...
# Adjustment completed.
# The Paper 1040 has been checked for loading errors at 28708 seconds.
# The paper 1040 has been loaded into the Folding Base at 28710 seconds.
# The paper 1040 has been checked for alignment at 28710 seconds.
# Paper is aligned properly.
# The paper 1040 has been folded at 28714 seconds.
# The paper 1040 has been unloaded from the Folding Base at 28717 seconds.
# The paper has been checked for quality at 28717seconds.
# Folded Paper passed quality check.
# The paper 1040 has been handed over to the next station at 28722 seconds.
# The robot has returned to the start position at 28724seconds.
# Next Paper 1041 arrived at Station 1 at 28728 seconds.
# Operator started the process at 28731seconds.
# The Paper 1041 has been loaded into the robot at 28734 seconds.
# Paper is loaded properly.
# The Paper 1041 has been checked for loading errors at 28734 seconds.
# The paper 1041 has been loaded into the Folding Base at 28737 seconds.
# The paper 1041 has been checked for alignment at 28737 seconds.
# Paper misaligned. Aligning...
# Alignment completed.
# The paper 1041 has been folded at 28745 seconds.
# The paper 1041 has been unloaded from the Folding Base at 28748 seconds.
# The paper has been checked for quality at 28748seconds.
# Folded Paper passed quality check.
# The paper 1041 has been handed over to the next station at 28753 seconds.
# The robot has returned to the start position at 28756seconds.
# Next Paper 1042 arrived at Station 1 at 28760 seconds.
# Operator started the process at 28763seconds.
# The Paper 1042 has been loaded into the robot at 28766 seconds.
# Paper is loaded properly.
# The Paper 1042 has been checked for loading errors at 28766 seconds.
# The paper 1042 has been loaded into the Folding Base at 28768 seconds.
# The paper 1042 has been checked for alignment at 28768 seconds.
# Paper misaligned. Aligning...
# Alignment completed.
# The paper 1042 has been folded at 28776 seconds.
# The paper 1042 has been unloaded from the Folding Base at 28778 seconds.
# The paper has been checked for quality at 28778seconds.
# Folded Paper passed quality check.
# The paper 1042 has been handed over to the next station at 28783 seconds.
# The robot has returned to the start position at 28786seconds.
# Next Paper 1043 arrived at Station 1 at 28791 seconds.
# Operator started the process at 28794seconds.
# The Paper 1043 has been loaded into the robot at 28796 seconds.
# Paper is loaded properly.
# The Paper 1043 has been checked for loading errors at 28796 seconds.
# The paper 1043 has been loaded into the Folding Base at 28799 seconds.
# The paper 1043 has been checked for alignment at 28799 seconds.
# Paper misaligned. Aligning...

# %% [markdown]
# ## Results of the Simulation
# The outcomes of the simulation are presented in a detailed table, offering insights into various performance metrics. Following the tabular representation, there are two accompanying bar charts. The first chart visually depicts the total count of folded papers and defective papers, providing a comparative view of these key production aspects. The second bar chart illustrates a comparison of average times associated with different processes.

# %%
print ("The Simulation is ended and the results are shown below")
print ("The number of produced papers is "+str(workstation1.folded_papers-1)+".")
print ("the simulation duration is "+str(env.now)+"seconds.")
print ("The number of produced papers is "+str(workstation1.folded_papers-1)+".")
# Calculate the average folding time

produced_papers = len(paper_list)
simulation_time = 28800
average_process_time = simulation_time/produced_papers
average_folding1_time = workstation1.totalfolding1_time/produced_papers
average_folding2_time = workstation1.totalfolding2_time/produced_papers
average_folding_time = average_folding1_time + average_folding2_time
average_paper_loading_verification_time = workstation1.paper_loading_verification_time/produced_papers
average_paper_alignment_verification_time = workstation1.paper_alignment_verification_time/produced_papers
average_quality_check_time = workstation1.total_quality_check_time/produced_papers
average_operator_idle_time = workstation1.operator_idle_time/produced_papers

print ("The average process time of the produced papers is {:.2f} seconds.".format(average_process_time))
# After running the simulation, calculate and print the average folding 1 time
print ("The average Folding process time is {:.2f} seconds.".format(average_folding1_time))
print ("The average Quality check time is {:.2f} seconds.".format(average_quality_check_time))
print ("The average paper loading verification time is {:.2f} seconds.".format(average_paper_loading_verification_time))
print ("The average paper alignment verification time is {:.2f} seconds.".format(average_paper_alignment_verification_time))
print ("The number of defective papers is "+str(workstation1.defective_papers)+".")
print ("The average operator idle time is {:.2f} seconds.".format(average_operator_idle_time))

#The presented table provides a comprehensive summary of key performance metrics and 
# outcomes from a simulated production process. It includes essential information such as the total number of produced papers, the overall simulation duration, and various average times associated with different stages of the production workflow. 

from tabulate import tabulate

table_data = [
    ("Produced Papers", workstation1.folded_papers-1),
    ("Simulation Duration", f"{env.now} seconds"),
    ("Average Process Time (Cycle Time)", "{:.2f} seconds".format(average_process_time)),
    ("Average Folding  Time", "{:.2f} seconds".format(average_folding1_time)),
    ("Average Paper Loading Verification Time", "{:.2f} seconds".format(average_paper_loading_verification_time)),
    ("Average Paper Alignment Verification Time", "{:.2f} seconds".format(average_paper_alignment_verification_time)),
    ("Average Quality Check Time", "{:.2f} seconds".format(average_quality_check_time)),
    ("Defective Papers", workstation1.defective_papers),
    ("Average Operator Idle Time during the process", "{:.2f} seconds".format(average_operator_idle_time)
    ),
]


# Print the table
print(tabulate(table_data, headers=["Metric", "Value"], tablefmt="grid"))

# bar chart , Categories and corresponding average times
categories = ['Folded Papers ', 'Defective Papers ']
average_times = [produced_papers, workstation1.defective_papers]

import matplotlib.pyplot as plt
import numpy as np
# Plotting the bar chart
plt.bar(categories, average_times, color=['blue', 'green'])
plt.xlabel('Processes')
plt.ylabel('Number of Papers')
plt.title('Folded Papers and Defective Papers')
plt.show()
# Out:
# The Simulation is ended and the results are shown below
# The number of produced papers is 1042.
# the simulation duration is 28800seconds.
# The number of produced papers is 1042.
# The average process time of the produced papers is 30.25 seconds.
# The average Folding process time is 6.04 seconds.
# The average Quality check time is 5.63 seconds.
# The average paper loading verification time is 0.64 seconds.
# The average paper alignment verification time is 0.69 seconds.
# The number of defective papers is 92.
# The average operator idle time is 19.13 seconds.
# +-----------------------------------------------+---------------+
# | Metric                                        | Value         |
# +===============================================+===============+
# | Produced Papers                               | 1042          |
# +-----------------------------------------------+---------------+
# | Simulation Duration                           | 28800 seconds |
# +-----------------------------------------------+---------------+
# | Average Process Time (Cycle Time)             | 30.25 seconds |
# +-----------------------------------------------+---------------+
# | Average Folding  Time                         | 6.04 seconds  |
# +-----------------------------------------------+---------------+
# | Average Paper Loading Verification Time       | 0.64 seconds  |
# +-----------------------------------------------+---------------+
# | Average Paper Alignment Verification Time     | 0.69 seconds  |
# +-----------------------------------------------+---------------+
# | Average Quality Check Time                    | 5.63 seconds  |
# +-----------------------------------------------+---------------+
# | Defective Papers                              | 92            |
# +-----------------------------------------------+---------------+
# | Average Operator Idle Time during the process | 19.13 seconds |
# +-----------------------------------------------+---------------+

# %%
#This Bar chart that visually compares the average times for different processes.

import matplotlib.pyplot as plt
import numpy as np



# Categories and corresponding average times
categories = ['Folding ', 'Quality Check ','Loading Check', 'Alignment Check']
average_times = [average_folding1_time, average_quality_check_time, average_paper_loading_verification_time, average_paper_alignment_verification_time]

# Plotting the bar chart
plt.bar(categories, average_times, color=['blue', 'green', 'red', 'purple'])
plt.xlabel('Processes')
plt.ylabel('Average Time (seconds)')
plt.title('Comparison of Average Times for Different Processes')
plt.show()
